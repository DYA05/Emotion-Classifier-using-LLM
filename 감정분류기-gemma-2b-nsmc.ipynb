# %% [markdown]
# # Gemma-2b NSMC Finetuning

# %% [markdown]
# ## 0. 미션
# 참조
# - 정보: https://cloud.google.com/vertex-ai/docs/generative-ai/open-models/use-gemma?hl=ko
# - 2b: https://huggingface.co/google/gemma-2b
# - 2b instruction tuning: https://huggingface.co/google/gemma-1.1-2b-it
# - 7b: https://huggingface.co/google/gemma-7b
# - 7b instruction tuning: https://huggingface.co/google/gemma-1.1-7b-it
# - nsmc: https://github.com/e9t/nsmc
#
# 미션
# * 구글에서 공개한 gemma-2b-it를 활용하여 문장의 감정을 긍정/부정으로 예측하는 감정분류 데이터셋인 nmsc를 fine-tuning을 해 보면서 LLM 동작 방법과 fine-tuning 방법을 학습한다.

# %% [markdown]
# ## 1. 라이브러리 설치 (최초 한번만 실행)
# - 라이브러리는 colab이 최초 실행 또는 종료 후 실행된 경우 한번만 실행하면 됩니다.
# - GPU 메모리 부족등의 이유로 colab 세션을 다시 시작한 경우는 설치할 필요 없습니다.
# - colab 세션을 다시 시작하려면 '런타임' >> '세션 다시 시작'을 선택하세요.

# %%
# !pip install -q -U transformers==4.38.2
# !pip install -q -U datasets==2.18.0
# !pip install -q -U bitsandbytes==0.42.0
# !pip install -q -U peft==0.9.0
# !pip install -q -U trl==0.7.11
# !pip install -q -U accelerate==0.27.2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 76.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.1+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.2.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 17.1 MB/s eta 0:00:00

# %% [markdown]
# ## 2. 구글 드라이브 연결 (최초 한번만 실행)
# - 구글 드라이브는 데이터 저장 및 학습 결과를 저장하기 위해서 사용합니다.
# - 구글 드라이브는 colab이 최초 실행 또는 종료 후 실행된 경우 한번 만 연결하면 됩니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## *3. 환경 (매번 필수 실행)
# - 환경은 colab 세션을 처음 시작하거나 다시 시작한 경우 실행되어야 합니다.
# - 프로젝트 진행에 필요한 환경을 설정합니다.

# %% [markdown]
# ### 3.1. 라이브러리 Import

# %%
import os
import pandas as pd
from tqdm.auto import tqdm

import torch
from datasets import Dataset
from transformers import (AutoTokenizer,
                          AutoModelForCausalLM,
                          BitsAndBytesConfig,
                          pipeline,
                          TrainingArguments)
from peft import (LoraConfig,
                  PeftModel)
from trl import SFTTrainer

# %% [markdown]
# ### 3.2. HuggingFace login
# - 이번 프로젝트는 HuggingFace 로그인 해야만 진행이 가능합니다.
# - HuggingFace 계정이 없다면 아래 URL에 접속해서 가입하시기 바랍니다.
#   - https://huggingface.co/
# - HuggingFace 로그인을 위해서 아래 URL에 접속해서 'User Access Token'을 생성하고 복사해서 Token에 입력하세요.
#   - https://huggingface.co/settings/tokens

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# access token을 복사하세요.
HF_TOKEN = ""

# %% [markdown]
# ### 3.3. 환경정보 설정
# - WORKSPACE
#   - 학습 데이터 및 학습결과를 저장하기 위한 경로입니다.
#   - 필요할 경우 적당한 경로로 변경할 수 있습니다.
#   - 경로를 변경 할 경우 전체 경로에 공백이 포함되지 않도록 주의해 주세요.
# - MODEL_ID
#   - 이번 프로젝트를 위한 LLM 입니다.
#   - 구글에서 공개한 gemma-2b를 Instruction tunned한 버전입니다.
#   - https://huggingface.co/google/gemma-2b-it

# %%
WORKSPACE = '/content/drive/MyDrive/nlp-project'
MODEL_ID = 'google/gemma-1.1-2b-it'

# %% [markdown]
# ## 4. Gemma understanding (재시작 필요)
# - Gemma의 동작 및 사용 방법을 이해하기 위한 과정입니다.
# - 이 과정을 시작하기 전 colab 세션을 다시 시작하세요.
# - colab 세션을 다시 시작해야 하는 이유는 LLM의 model의 크기가 너무 크기 때문에 GPU의 메모리를 초기화 하기 위해서 입니다.

# %% [markdown]
# ### 4.1. model load with 4 bits
# - 2B token을 가진 gemma를 그냥 로딩할 경우는 약 9G의 GPU vRAM이 필요합니다.
# - 4bit 양자화를 할 경우 2.2G의 GPU vRAM 필요.

# %%
# declare 4 bits quantize
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16
)
# load 4 bits model
model = AutoModelForCausalLM.from_pretrained(MODEL_ID,
                                             device_map='auto',
                                             quantization_config=quantization_config,
                                             token=HF_TOKEN)
# load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID,
                                          add_special_tokens=True,
                                          token=HF_TOKEN)
tokenizer.padding_side = 'right'
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/618 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]

# %% [markdown]
# ### 4.2. pipeline
# - https://huggingface.co/docs/transformers/main_classes/pipelines
# - huggingface에서 inference를 쉽게 하기 위해 정의한 라이브러리.

# %%
pipe = pipeline("text-generation",
                model=model,
                tokenizer=tokenizer,
                max_new_tokens=512)
pipe

# %% [markdown]
# ### 4.3. gemma prompt
# - https://huggingface.co/google/gemma-1.1-2b-it
# - 아래와 같은 형식이 gemma의 prompt 형식 입니다.
# ```
# <bos><start_of_turn>user
# {content}<end_of_turn>
# <start_of_turn>model
# ```
# - NSMC 추론을 위한 프롬프트를 생성하는 과정입니다.

# %%
doc = """엄청나게 즐거운 시간이었습니다. 강추!!!"""

# %%
messages = [
    {
        "role": "user",
        "content": "다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:\n\n{}".format(doc)
    }
]
prompt = pipe.tokenizer.apply_chat_template(messages,
                                            tokenize=False,
                                            add_generation_prompt=True)

# %%
print(prompt)
# Out:
# <bos><start_of_turn>user
# 다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:
#
# 엄청나게 즐거운 시간이었습니다. 강추!!!<end_of_turn>
# <start_of_turn>model

# %% [markdown]
# ### 4.4. gemma inference
# - 이전 단계에서 생성한 prompt를 이용해 추론하고 결과를 확인하는 과장입니다.

# %%
outputs = pipe(
    prompt,
    do_sample=True,
    temperature=0.2,
    top_k=50,
    top_p=0.95,
    add_special_tokens=True
)
outputs
# Out:
# [{'generated_text': '<bos><start_of_turn>user\n다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:\n\n엄청나게 즐거운 시간이었습니다. 강추!!!<end_of_turn>\n<start_of_turn>model\n긍정으로 분류합니다.\n\n영화는 긍정적인 요소를 제공하는 것으로 알려져 있습니다.'}]

# %%
print(outputs[0]["generated_text"])
# Out:
# <bos><start_of_turn>user
# 다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:
#
# 엄청나게 즐거운 시간이었습니다. 강추!!!<end_of_turn>
# <start_of_turn>model
# 긍정으로 분류합니다.
#
# 영화는 긍정적인 요소를 제공하는 것으로 알려져 있습니다.

# %%
print(outputs[0]["generated_text"][len(prompt):])
# Out:
# 긍정으로 분류합니다.
#
# 영화는 긍정적인 요소를 제공하는 것으로 알려져 있습니다.

# %% [markdown]
# ### 4.5. gemma chat
# - chatbot 형식의 감정분류 예 입니다.

# %%
def gen_prompt(pipe, doc):
    messages = [
        {
            "role": "user",
            "content": "다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:\n\n{}".format(doc)
        }
    ]
    prompt = pipe.tokenizer.apply_chat_template(messages,
                                                tokenize=False,
                                                add_generation_prompt=True)
    return prompt

# %%
def gen_response(pipe, doc):
    prompt = gen_prompt(pipe, doc)

    outputs = pipe(
        prompt,
        do_sample=True,
        temperature=0.2,
        top_k=50,
        top_p=0.95,
        add_special_tokens=True
    )
    return outputs[0]["generated_text"][len(prompt):]

# %%
doc = input('문장 > ')
doc = doc.strip()
result = gen_response(pipe, doc)
print(f'감정 > {result}\n\n')
# Out:
# 문장 > 흥미로운 영화
# 감정 > 긍정으로 분류합니다.
#
# 이 영화는 흥미로운 내용과 흥미로운 장면을 제공합니다.

# %% [markdown]
# ### 4.6. 기존 모델 성능평가
# - 6에서 다운받은 test 데이터 사용

# %%
df_test = pd.read_csv(os.path.join(WORKSPACE, "nsmc", "test.tsv"),
                      sep='\t')
df_test
# Out:
#             id                                           document  label
# 0      6270596                                                굳 ㅋ      1
# 1      9274899                               GDNTOPCLASSINTHECLUB      0
# 2      8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3      6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4      6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# ...        ...                                                ...    ...
# 49995  4608761          오랜만에 평점 로긴했네ㅋㅋ 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함      1
# 49996  5308387       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따 OOOO      0
# 49997  9072549                 그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다      0
# 49998  5802125     절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네      0
# 49999  6070594                                         마무리는 또 왜이래      0
#
# [50000 rows x 3 columns]

# %%
# 평가 데이터셋 생성
def make_dataset(df, sample=-1):
    df = df[['document', 'label']]
    if sample > 0:
        df = df.sample(sample)
    dataset = Dataset.from_pandas(df)
    return dataset

test_dataset = make_dataset(df_test)
test_dataset
# Out:
# Dataset({
#     features: ['document', 'label'],
#     num_rows: 50000
# })

# %%
# 평가를 위한 prompt
def gen_test_prompt(example):
    prompt_list = []
    for i in range(len(example['document'])):
        doc = example['document'][i]
        prompt_list.append(r"""<bos><start_of_turn>user
다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:

{}<end_of_turn>
<start_of_turn>model
""".format(doc))
    return prompt_list

# %%
test_dataset
# Out:
# Dataset({
#     features: ['document', 'label'],
#     num_rows: 50000
# })

# %%
# prompt 확인
prompt = gen_test_prompt(test_dataset[1:])[0]
print(prompt)
# Out:
# <bos><start_of_turn>user
# 다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:
#
# GDNTOPCLASSINTHECLUB<end_of_turn>
# <start_of_turn>model

# %%
# pipeline 정의
pipe = pipeline("text-generation",
                model=model,
                tokenizer=tokenizer,
                max_new_tokens=10)

# %%
outputs = pipe(
        prompt,
        do_sample=True,
        temperature=0.2,
        top_k=50,
        top_p=0.95,
        add_special_tokens=True
    )

# %%
total_sample_cnt, total_correct_cnt = 0, 0
for example in test_dataset.iter(1):
    label = '긍정' if example['label'][0] == 1 else '부정'

    prompt = gen_test_prompt(example)
    outputs = pipe(
        prompt,
        do_sample=True,
        temperature=0.2,
        top_k=50,
        top_p=0.95,
        add_special_tokens=True
    )
    pred = outputs[0][0]['generated_text'][len(prompt[0]):]
    total_sample_cnt += 1
    total_correct_cnt += 1 if pred.find(label) > -1 else 0

    print(f'{total_sample_cnt}.', example['document'][0], ":", pred)
    print('-' * 20)

    if total_sample_cnt >= 1000: break
print(f"Test Accuracy: {total_correct_cnt} / {total_sample_cnt} = {total_correct_cnt/total_sample_cnt:.4f}")
# Out:
# 1. 굳 ㅋ : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 2. GDNTOPCLASSINTHECLUB : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 3. 뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아 : 부정으로 분류합니다.
#
# 평점
# --------------------
# 4. 지루하지는 않은데 완전 막장임... 돈주고 보기에는.... : 긍정적인 분류:
# - 지루
# --------------------
# 5. 3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠?? : 부정으로 분류합니다.
#
# 3D
# --------------------
# 6. 음악이 주가 된, 최고의 음악영화 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 7. 진정한 쓰레기 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 8. 마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다 : 부정.
#
# 영화는 로봇디자인
# --------------------
# 9. 갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다 : **부정**
#
# 영화는 개판되
# --------------------
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# 10. 이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네.. : 긍정.
#
# 이별의 아픔 뒤
# --------------------
# 11. 괜찮네요오랜만포켓몬스터잼밌어요 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 12. 한국독립영화의 한계 그렇게 아버지가 된다와 비교됨 : 부정.
#
# 이 문장은 한국 독
# --------------------
# 13. 청춘은 아름답다 그 아름다움은 이성을 흔들어 놓는다. 찰나의 아름다움을 잘 포착한 섬세하고 아름다운 수채화같은 퀴어영화이다. : 긍정
#
# 이 영화는 아름답고
# --------------------
# 14. 눈에 보이는 반전이었지만 영화의 흡인력은 사라지지 않았다. : 긍정.
#
# 영화는 반전적인 요
# --------------------
# 15. "스토리, 연출, 연기, 비주얼 등 영화의 기본 조차 안된 영화에 무슨 평을 해. 이런 영화 찍고도 김문옥 감독은 ""내가 영화 경력이 몇OO인데 조무래기들이 내 영화를 평론해?"" 같은 마인드에 빠져있겠지?" : **부정**
#
# 영화의 기본 조
# --------------------
# 16. 소위 ㅈ문가라는 평점은 뭐냐? : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 17. 최고!!!!!!!!!!!!!!!! : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 18. 발연기 도저히 못보겠다 진짜 이렇게 연기를 못할거라곤 상상도 못했네 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 19. 나이스 : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 20. 별 재미도없는거 우려먹어 .... 챔프에서 방송 몇번했더라 ? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 21. '13일의 금요일', '나이트메어'시리즈와 함께 가장 많은 시리즈를 양산해냈던 헬레이저 시리즈의 첫편. 작가의 상상력이 돋보이는 작품이며, 갈고리로 사지찢는 고어씬은 지금보더라도 상당히 잔인하고 충격적이다. : **부정**
#
# 작가의 상상
# --------------------
# 22. 나름 교훈돋기는 하지만 어쩔수없이 저평점 받을수밖에 없는 저질섹스코미디 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 23. 꽤 재밌게 본 영화였다! : 긍정
#
# 이 영화는 꽤 재밌
# --------------------
# 24. 민주화 시대의 억눌린 영혼의 관음적인 욕구 분출.인상적이다. : 긍정.
#
# 이 문장은 억
# --------------------
# 25. 일본 천황이 미국으로부터 받은 면죄부의 긴박한 과정을 루즈하고 지저분하게 늘어놓았다. : 부정.
#
# 이 문장은 천황
# --------------------
# 26. 괜히 나올 때 어미 알 건드려서 긁어 부스름 만들었다는 분이 저 아래 보이던데, 영화 제대로 안 봤네. 알이 딱 까지면서 새끼가 나오려 했음. 그냥 가면 그 놈 한테 당했을 것임. 한 놈, 두 놈 막 나올 게 뻔했으니 작살낼 수 밖에 없었다. : **부정**
#
# 영화 제대로 안
# --------------------
# 27. 50번은 봤네요어쩜 이렇게 잘만들었을까 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 28. 실화라서더욱아름답고찡하네요...많이울었어요벌써4년이란시간이흘렀네요 : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 29. 이건뭐 노답이네 80~90년대 어린이 영화좀 보고 본받아라! : 긍정적인 분류:
# 이건뭐
# --------------------
# 30. 지금까지 본 영화중 마음이 가장 따뜻해지는 영화. : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 31. 너무너무 재밌다 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 32. 안보면 후회ㅠㅠ... : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 33. 평점1점도 주기싫어지는 영화 배우나 감독이라는 사람이나 영화판에서 안봐으면 한다 그리고 평점알바생들 너무 티난다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 34. 정말,진짜,표현할수 없는 영화... : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 35. 엉성한 액션에, 시나리오는 왜그러지.. 막판에 대동단결?? : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 36. 101, 102.. 103은 못나올것 같다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 37. ....재미가없어요 시간이 아깝고 : 부정.
#
# 영화는 재미이 없
# --------------------
# 38. 북괴는 우리의 주적일뿐이다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 39. ㅋㅋㅋ 난생처음 로그인하고 평점남기네요.. 개빡쳐서.. 알바들 속지마세요 이런 ㄱ ㅐ같은 시간낭비가. 아놔진짜평점 마이너스 별오만개 : 부정으로 분류합니다.
#
# 문장
# --------------------
# 40. 셰익스피어는 셰익스피어고 이영화는 이영화. : 긍정.
#
# 이 영화는 셰익
# --------------------
# 41. EBS 한국영화특선 해서 봤다.Biff 개막작 선정되서 왤까 궁금 했었는데 봐도 이율 모르겠다... : 부정
#
# 이 문장은 영화 리뷰
# --------------------
# 42. 뭐야??라는 말 밖에는... : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 43. 이게 영화야? : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 44. 애니는 일본이 갑인듯. : 부정.
#
# 이 문장은 애니
# --------------------
# 45. 롭 코헨의 몰락의 OO점 : 긍정
#
# 이 영화는 롭 코헨
# --------------------
# 46. 감동적이다.... : 긍정적으로 분류합니다.
#
# 이 영화
# --------------------
# 47. 은빛날개의 조종사 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 48. 마음이1을보신분들은 이해하시겟지만 2는망장입니다 졸작이죠 솔직히말해선;; 그이유는 예를들면 엽기적인그녀는 긴시간을두고 코메디 멜로를 그렷습니다 하지만 이영화는 단시간 10분안에 모든것을 소화하려는 욕심 코믹하다 3분채안돼갑자기 생뚱맞게 슬픈음악이깔리고 : **긍정**
#
# - 영화는 이해하
# --------------------
# 49. 이런스타일 액션영화 굿굿!! : 긍정
#
# 이런스타일 액션
# --------------------
# 50. 제임스 헷필드 50먹고 더 파워풀해졌어ㅋㅋㅋㅋ : 긍정으로 분류합니다.
#
# 제임
# --------------------
# 51. 돈만있으면 내가 이것보단 더잘만들겠따 ㅋ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 52. 레이토와 다미앙의 시원한 액션은 어디갔나 ㅁㅊ : 긍정
#
# 이 문장은 레이토와
# --------------------
# 53. 내 참, 이딴 걸 드라마라고.... 그냥 이건 세계보건기구에서 발암물질로 올려야 한다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 54. 아 극장에서 아무 기대없이 들어갔다가 감탄하면서 보고 나왔는데. 2001년도 였구나 그 때가. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 55. 아이디어가 아주 좋다 재밌다 : 긍정으로 분류합니다.
#
# 아이디어
# --------------------
# 56. 난 재밌던데 평점 왜케 낮지 ``; : 부정.
#
# 영화 리뷰에서 평점
# --------------------
# 57. 역사얘기보다 영화배우, 감독들들에게 더 관심이 간다 : **부정**
#
# 이 문장은 영화
# --------------------
# 58. 몇년만에 아메리칸조크보고 웃어보는거지. 하아이맛이야바로 : 긍정적인 문장입니다.
#
# 이 영화
# --------------------
# 59. 재밌다! 내용도 신선하고 의미도있으며 연기도 좋고 영상도좋다~~ : 긍정적인 분류입니다.
#
# 이 문
# --------------------
# 60. 여름이면 한결같이 생각나는 드라마 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 61. 콩콩~~~~ㅋㄲㅈㅁ : 긍정
#
# 콩콩~~~~ㅋㄲㅈㅁ
# --------------------
# 62. ...으...뭐 의도는 좋아봤자 전달이 돼야지; : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 63. 아빠가 낚여서 본적 있다나 슈래기 영화 : 긍정
#
# 아빠가 낚여서
# --------------------
# 64. """결혼은 현실이에요 징징징"" 성현아 벗겨놓고 이 정도 얘기 밖에 못 하냐." : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 65. 엠비씨 무비채널에서 봤는데 또 봐도 엄청 잼나네여 .. : 긍정적인 분류:
# 엠비씨
# --------------------
# 66. 어우.. 이게 진짜 무서웠어요?? 진짜로? 시간 아까웠습니다. : 부정으로 분류합니다.
#
# 이게
# --------------------
# 67. 몇번을 봐도 볼때마다 재밌다 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 68. 재미있게 잘봤습니다 후속편을 기다리게 만드네요 : 긍정적인 분류: 재미있게
# --------------------
# 69. 결말 뻔히 알면서 보는데도 너무 슬프고 많이 울었음. : 부정으로 분류합니다.
#
# 결말
# --------------------
# 70. 한번본적은업지만재미있을것같다 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 71. 성경에 보면 지나치게 의인도 되지 말고 지혜롭게 되지도 말라고 했다. 주인공의 지나친 착한남자 컴플렉스는 결국 모든걸 엉망으로 만들었다.직장에서 해고되고 부인에게 거부당하고,그 모든 터전을 잃을만큼 불륜으로 생긴 아이를 보러가는게 그리 중요했을까??? : **부정**
#
# 이 문장은 주
# --------------------
# 72. 미친놈들 집합소네 연출력 빵점, 스토리 빵점. 구성빵점 : 긍정적인 분류:
# - 영화리
# --------------------
# 73. 하...작은 그림보고 기대했는데..수염..눈색깔도 뭐..이건 뭐 원작 비충실..ㄹㄹ : 부정적인 문장입니다.
#
# 이 문
# --------------------
# 74. 볼 거 없을때 봐도 재미 없는 영화! : 부정.
#
# 이 문장은 영화가
# --------------------
# 75. 관객모독 관객모독 관객모독 관객모독 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 76. 이런내용완전좋다ㅠㅜㅜㅜ : 긍정으로 분류합니다.
#
# 이런
# --------------------
# 77. 쇼타군 넘 좋아 돈키호테 대박 재밌음 : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 78. 참 대단한것 같습니다천...재..? : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 79. 볼만함 : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 80. 제시카 알바가 벗고 달려드는데 쌩까는게 말이 되냐? : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 81. 솔직히 이건 C급 그 이하의 영화이긴 함 ㅎㅎ; : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 82. 개성있는 몬스터들과 귀여운 여자아이가 만나 뿜어내는 매력에 퐁당 빠졌다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 83. 제목이 찰지구나ㅋㅋㅋ : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 84. 1956년 작품이라는게 믿기지가 않을정도로 디테일하다! 안소니 퀸의 명연기 또한 물론~ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 85. 아찔한 사랑 줄다리기??? : 긍정
#
# 이 영화는 아름다운
# --------------------
# 86. 재미있었다! 또봐야징ㅎ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 87. 중간에 화면이 좀 끊기는것 빼곤 넘 좋았어요~ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 88. 이 영화를 말하는데 긴 단어는 필요없다. 재수없는 졸작 이거면 충분하다. : 긍정.
#
# 영화를 말하는데
# --------------------
# 89. 최고최고! 바다까지! 4차원 고양이 로봇 도라에몽과 함께하는 진구와 친구들의 미지 탐험 이야기!우주꺼지 갔음 좋겠당~ : 긍정적인 문장입니다.
#
# 영화는
# --------------------
# 90. 완전 잼없음.. : 부정.
#
# 이 문장은 영화 리
# --------------------
# 91. 로코 굉장히 즐겨보는데, 이 영화는 좀 별로였다. 뭔가 사랑도 개그도 억지스런 느낌.. : **부정**
#
# 이 영화는 긍
# --------------------
# 92. 후속작 계획은 없나요..? ㅜ : 부정.
#
# 이 영화는 후속작
# --------------------
# 93. 엔딩때까지 음성 넣은 것은 오버의 극치다 : 부정으로 분류합니다.
#
# 엔딩
# --------------------
# 94. 단 두마디 '감동' : 긍정
#
# 이 영화는 감동적인 역
# --------------------
# 95. 뭘 만든 건가? : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 96. 전기톱은못들고다니는데 엔진톱이겠죠 : 긍정
#
# 이 문장은 전기톱
# --------------------
# 97. 완전 재밌엇는데 왜 평점이?? : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 98. 제임스 완이 내 목표임 ㄷ : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 99. 1점고 아깝다. 개막장 영화의 원조라고나 할까.아내와 사별한 지 얼마나 지났다고 딴 여자들 만나고 다니다가 결국 맥 라이언한테 꽂힌 톰 행크스나약혼자 두고 톰 행크스랑 썸 타다가 결국엔 약혼자 버리고 톰행크스한테 쪼르르 달려가는 맥 라이언이나. : **부정**
#
# 영화는 개막장
# --------------------
# 100. 가끔 문득 생각나서 다시보는 영화..색감이 정말 예술이죠 강렬하고 화려하고..츠지야안나의 너무도 아름답던 리즈시절도 볼 수 있고.. : 긍정
#
# 영화는 색감과 화려
# --------------------
# 101. 걸작은 몇안되고 졸작들만 넘쳐난다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 102. 이렇게 지겨울수가 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 103. ost... 정말 좋았어요. 영화 자체도.. 의문은 남지만 ㅎㅎ : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 104. 펑퍼짐한 건빵바지(카고)를 입고 오도바이탈때 입는 잠바 같은 것을 입은 주인공겸 감독이 앞차기 옆차기 뒷차기 앞돌려차기등의 기술을 구사해 악당을 소탕하는 영화 주먹질도 하지만 앞차기와 옆차기의 비중이 크다 : **부정**
#
# 영화는 앞차기
# --------------------
# 105. 솔직히 생각보다 재밌어서 놀랐다... 이거 개봉하고 낸린줄도 모르고...ㅠ ㅠ 이제서야 봤네... 정말 두 사람의 커플댄스는... 명장면이다... 생각할수록 아쉽다... 단순 sm상업영화라고 생각하기엔... 두 사람의 춤이 너무 인상적이다... : **긍정**
#
# 영화는 개봉하고
# --------------------
# 106. 이거 평점보니까 알바고용하는데 제작비보다 많이들어갔겠어요 정말 재미라고는 찾아볼 수 없고 특히 마지막에 여자애가 경상도사람이 들으면 코웃음 칠만큼 어색한 사투리로 엄마한테 말할때는 그나마 잡히던 감정도 깨져버렸습니다 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 107. TV시리즈중에는 단연 최고乃 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 108. 글쌔....슬프지만 너무 짜여진듯한 : 부정.
#
# 글passen이 너무
# --------------------
# 109. 여기서 땡칠이 얘낳지 안나? : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 110. 너무재밌음ㅠㅠ뭐랄까 굉장히 따뜻한 느낌? : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 111. 견자단나오는 영화중에 제일 노잼 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 112. 재밌기만한데;;왜이렇게욕을하셍휴ㅠㅠ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 113. 실제 사실은 어땠는지 모르겠으나 의로운 협객으로서 김두한이 거지패에서 종로 최고의 주먹으로 평정하는 초기 모습을 잘 보여 줌. 배경음악이 영상과 잘 어울린다는 느낌. 참고로 황정민이 우미관 지배인으로 나와서 유명하기도 한 영화. : **긍정**
#
# 영화의 의도를
# --------------------
# 114. 재밌는데? 자막읽기 힘들었지만 영어권사람들이 보면 더 몰입될듯 공간이 한정되있지만 상상만으로도 충분히재미나고 생각할게 많은영화 바이러스가 언어라는게 참신한듯 바이러수를 소문 괴담 선동 찌라시 언론플레이 등과 대입해서 생각해보면 재밌을듯 : **긍정**
#
# 영화 리뷰는 영화
# --------------------
# 115. 괜찮아요~ : 긍정으로 분류합니다.
#
# 영화 리
# --------------------
# 116. 내가 극장가서 본 영화중 제일 쓰레기 같았다 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 117. . : 본 문장은 긍정적인 평가
# --------------------
# 118. 피는 물보다 진하다. 이 한마디로 모든게 표현되는 영화. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 119. 이뿌고 따뜻한 애니였어요 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 120. 너무 좋았음 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 121. 어렷을때 보고 박준형에 배신감을ㅋㅋㅋㅋ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 122. 차인표 말투 적응안돼, 송선미 이쁘다 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 123. 과소평가! 확실히 재밌고 유쾌함 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 124. 훌륭한 작가와 뛰어난 연출진이 만나, 훌륭하고 뛰어난 한 편의 드라마가 만들어졌다. : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 125. 신선한 소재로 식상한 영화를 만들었어..유치한건 둘째치고 재밋게라도 만들던가.. : 긍정적인 분류:
# 영화는 신
# --------------------
# 126. 다시봐도 정말 최고군요 잭 바우어 형님이 여기 나왔었다니 처음 볼땐 못 느꼈던 또하나의 재미 : 긍정.
#
# 영화는 긍정적인
# --------------------
# 127. 이런 쓰레기영화좀 만들지마라 진짜 재미없다ㅡㅡ : 부정으로 분류합니다.
#
# 이런
# --------------------
# 128. 정말 가슴아픈영화....질리지도 않는영화....몇번을봐도...음악도 너무 좋아요...OST도 구해 들었다는... : 긍정적인 분류:
#
# - 영화의
# --------------------
# 129. 영화도 못만들었지만 이건 탄생하지 말았어야할 그자체로 쓰레기임.. : 부정으로 분류합니다.
#
# 영화는
# --------------------
# 130. 정말 재밋어요...다들 연기도 잘하고 볼만해요...~~~ : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 131. 신기록 갱신인가..간닷 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 132. 오시이 마모루는 영화를 통해 책을 넘어서려 한다. : 긍정.
#
# 이 문장은 영화를
# --------------------
# 133. 데어데블보다 못한 졸작. CG는 훌륭하지만 악마 인형탈쓰고 나오는게 웃기고 인물 관계나 스토리가 너무 뻔함. 시간이 아까움. 짧은 러닝타임이 고마울 정도. : **부정**
#
# CG와 악마 인
# --------------------
# 134. 마트라는 폐쇄된 공간속에서 그안에 갇힌 사람들의 심리변화가 인상적이네요. 결말이 인상적입니다. : **긍정**
#
# 본 문장은 영화
# --------------------
# 135. 차인표 연기는 너무 현실적이여서 마음에 와닿는다 왕초드라마를볼때도 난 연기를하는건지 진짜 실제로 그러는건지 몰랐다 이영화 내용이 쥐어짜는스토리지만 차인표라는 배우때문에 영화가살았다 너무 현실적인 연기력이다 대단하다 눈물한방울 흘리지않았지만 마음이아팠다 : **긍정**
#
# - 차인표 연
# --------------------
# 136. 이게뭐야엉엉 본시리즈말고 그냥나왔다면 이정도는안줬겠지만 본이라는 이름을 달고왔으니 엉엉 : 부정으로 분류합니다.
#
# 이게
# --------------------
# 137. 스토리가 신선하다. 재미있다. 좋다. : 긍정적으로 분류합니다.
#
# 스토
# --------------------
# 138. 재밌었다.진저 너무 무서버~ㅠ : 긍정.
#
# 영화는 진저의 무
# --------------------
# 139. 아직까지 잊지 못하는 영화. 제목부터 마음에 잔잔하게 와 닿는다. 영화 장면중에 소낙비를 피해놀라 달려 가는 부분은 정말 ☆어느 멋진날~☆ 햇살 비춰진 행복한 빗속을 달리듯 느껴졌었다 : **긍정**
#
# 영화 장면은 소
# --------------------
# 140. 지루하지않고 가볍게 볼수있는 코믹 스릴러 영화네요저는 잔인하고 무거운 스릴러 영화보다 오히려 좋았습니다 : 긍정적인 분류입니다.
#
# 이 영화
# --------------------
# 141. 김민이 너무 어설픔 졸작 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 142. 화면 어지럽고 엉성함과 지루함의 연속임. : 부정.
#
# 영화는 어지럽고
# --------------------
# 143. 영화 다보고 평점 읽는것이 이영화 최고의 재미 ㅋ : **긍정**
#
# 영화 다보고 평
# --------------------
# 144. 정말 재밌게 잘봤습니다! : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 145. 예수쟁이들 좀 제발 인터넷에서 안 봤으면... : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 146. 작가의 예리함과 필력에 박수를 보냅니다. 진보한 드라마란 바로 이런 것 시청률 의식하지마시고 앞으로도 좋은내용 부탁드립니다 : **긍정**
#
# 작가의 예리
# --------------------
# 147. 작품성을 떠나서 보고 나면 너무너무 찝찝해 지는 영화.. : 부정.
#
# 작품성을 떠
# --------------------
# 148. 초중학생 수준의 단조로운 대사와 지루하고 재미 없는 영화. : 부정.
#
# 영화는 초중학생
# --------------------
# 149. 2012년도에 참으로 억지스럽네 미국을 욕해라 뭐 이런건가? ㅋㅋ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 150. 1편이 오억만배 재밌는 영화 2편도 나름대로는 재밌지만... : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 151. 다시 봐도 수작이다. 미국 국수주의라 뭐라는 시점도 있겠으나 전쟁물 중에 손가락안에 꼽을정도로 잘만들어 졌다. 스토리 라인은 뻔하나 그 뻔한걸 너무 잘 살렸다. 언제 봐도 다시봐도 재미 있다. 10년이 지난 영화가.. : **긍정**
#
# 이 영화는 전쟁
# --------------------
# 152. 클럽과 사건의 연결이 전혀안된다. 섹스클럽얘기는 흥미거리일뿐 스토리연관이 없다. : 부정으로 분류합니다.
#
# 본 문
# --------------------
# 153. 다니엘,,미쉘페이퍼,,마틴스콜세지~~ 쵝오 : 긍정적인 문장:
# - 영화 리
# --------------------
# 154. 탕웨이..이제껏 관심없었는데 이번 영화를 계기로 너무좋다..ㅠㅠ : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 155. 간만에 참 유쾌하게 웃은듯... : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 156. 액션이 진짜 꽤 괜찮았다. ㅎ : 부정.
#
# 문장은 액션
# --------------------
# 157. 무슨 말이 더 필요한가 .. 아마 이 영화보고 법무관 또는 법조인이 되고싶다 라고 생각을 품엇던 사람이 있을듯 : **긍정**
#
# 이 영화보고 법
# --------------------
# 158. 개노답이다진짜 돈아까움 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 159. 죠스보다더재밌음bb : 긍정
#
# 이 영화는 죠스보다
# --------------------
# 160. 두말할필요없다 이건 보지마 시간이 남으면 집에서 발닦고 잠이나 자라 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 161. 굿 : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 162. 마지막 도서카드에 그려진 모습을 보고 우는 이츠키의 모습을 보고 저도 울었습니다... 지금 본지 3달은 지난거 같은데 아직도 그 모습을 떠올리면 먹먹해지네요 : **부정**
#
# 이 문장은 이
# --------------------
# 163. 완전한 삶은 없다 그저 하나씩 배워나갈뿐. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 164. 어라이즈 시리즈 중에 그나마 나은 2편. 4편보면 진짜 노잼이라 욕밖에 안나오는데 그래도 이건 조금이나마 볼만한편. 극장판 주제에 오프닝은 1부터 4까지 애프터이펙트만 처바르고 바뀌질 않는데 예산이 모자란건지 감독이 미친건지 모르겠다 : **긍정**
#
# * 영화리뷰는
# --------------------
# 165. 이야~ 미키루크 나오는 홈보이 영화를 다 아는 분들이 계시네~ 이야 놀라울뿐..... : 부정.
#
# 이 영화는 미키루
# --------------------
# 166. 팬이긴한데 이건 안봤네요ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ몰라 나도 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 167. 케이블에서 우연히 보게 된 월광보합 때문에 깔깔 거리고 웃다가 선리기연 마지막 장면에서 일생소애가 흘러나오는데 눈물이...되돌릴 수 없는 시간이 가장 아프게 와닿았다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 168. 보고싶다 기대 만발 싸랑해 키르아 ♥ : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 169. 심심할때 보면 딱 좋은 영화 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 170. 별로 재미 없는데.....왜 7점이지? : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 171. 노인들의 섹스 외엔 보여줄 게 없는 영화. 영활까? : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 172. 멀 말하고자하는지 아직도 이해가....공포도 아니여서 실망;ㅁ; : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 173. 역시 영화를 볼 때도 도덕성을 버려 둘 수는 없네요 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 174. 그리스의 아름다운 풍경을 감상하면서 달달한 로맨스를 즐길 수 있는 영화! 보는내내 흐뭇한 미소를 지으며 봤다ㅎㅎㅎ : **긍정**
#
# 영화는 그리스의
# --------------------
# 175. OO어썸!! : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 176. 조쉬나와서 바꾸먼.. 이건 뭐병- _-정신줄을 놓은건가 드팔마 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 177. 종교인이 아님에도 그 인간적인 고뇌가 느껴진다. 숭고한 감동!! : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 178. 수고요! 수고 수고 ㅅㄱ : 긍정적인 문장입니다.
#
# 이 영화
# --------------------
# 179. 한회 한회 보면서 총체적으로 발연기다. 중량급 연기자들도 모두 하향 평준화되는듯. 작가의 생각도 너무 어이업슴. 일일극 치고는 최악으로 평점 1점도 아깝다. : **부정**
#
# 이 문장은 영화
# --------------------
# 180. 전작에 비해 훨씬 스토리도 고급스러웠고, 무엇보다 이번편에서도 역시 간지나는 액션신은 스타뎀 성님이 도맡아 하시는거보고 더욱 좋았다. : 긍정
#
# 이 영화는 전작에 비
# --------------------
# 181. 아! 희망이란,,, 미래란,,, : 긍정
#
# 아! 희망이란
# --------------------
# 182. 먼지낀 회색초콜릿같은 맛의 영화랄까요 : 긍정
#
# 영화는 맛있는 액
# --------------------
# 183. 아주 진짜 영화를 찍어라, 영화를 찍어...ㅉㅉ : 긍정적인 분류:
# - 영화를
# --------------------
# 184. 이게 뭐가 다들 재밌다는거지 ㅋㅋㅋ 마지막 반전이 가장 최악이었는데... : 부정으로 분류합니다.
#
# 이게
# --------------------
# 185. b급 액션의 진수.. 깨알같은 까메오들과.. 잔웃음.. 거기다가 엠버 허드의 ㅎㄷㄷ한 몸매 어느영화에서나 빛을 발한다. : 긍정
#
# 이 문장은 액션
# --------------------
# 186. 어릴때 감동적으로 본 영화라 잊지 못합니다. 라스트장면에서 이불 뒤집어쓰고 울었던 기억이...꼭 다시 보고 싶습니다. 파일 좀 보내주세요. dodadan@naver.com : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 187. 두 주인공의 관계와 로맨스는 어색하고, 요술인지 마법인지.. 뭘하는건지 : **부정**
#
# 이 문장은 두
# --------------------
# 188. 왜 헤라클레스의 인물묘사를 저따위로 했을까? : 부정으로 분류합니다.
#
# 헤라
# --------------------
# 189. 뭐야이거 무서워 : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 190. 오다기리 죠의 배바지가 기억에 남네요 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 191. 카메라로 이렇게까지..아름답다 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 192. 이게영화냐?첫장면부터 역겨웠다 분위기있는척앵글잡으면 괜찮은영화인거같지?허세덩어리 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 193. 지상최고의 드라마? 이정도면 될까 ? : 긍정적으로 분류합니다.
#
# 이 영화
# --------------------
# 194. 사랑이 무엇인지 알려주는 영화 : 긍정
#
# 이 영화는 사랑의 중요성
# --------------------
# 195. 미국 당시의 시대흐름과 개개인들의 인간승리응 보여준 영화.. 좌절하고 힘들때보면.. 용기를 주는 영화 : **긍정**
#
# 이 영화는 미국 당
# --------------------
# 196. 3점이 제일 적어서 3점 준다 : 본 문장은 긍정으로 분류
# --------------------
# 197. 재미따!시간가는지 몰랐어 ㅋㅋ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 198. 기대안해서 그런가.. 조카랑 너무 재밌게 봤다.나니아,샤크보다 : 긍정적인 분류:
# - 조카
# --------------------
# 199. 소품은 잘 만들었는데 연기를 너무 못하네요... 몰입이 안됨-_-; 엑기스만 보고 끝냄.... 내가 본 영화중에 최악이다... : 부정
#
# 이 문장은 영화의
# --------------------
# 200. 신날 것 없는 애니. : 긍정
#
# 이 영화는 신날 것 없는
# --------------------
# 201. 여성성의 한계에 갖힌 탈출의 덫 : 긍정
#
# 이 문장은 여성성의
# --------------------
# 202. 정말 이건 대박임 걍 잼슴 : 긍정
#
# 이 영화는 대박으로 평
# --------------------
# 203. 도가 지나친 신앙심의 말로. 종교인에게도 비종교인에게도 전하는 메세지가 뚜렷해서 좋음. 강추~!! : **긍정**
#
# 이 문장은 종
# --------------------
# 204. ㅋㅋ 귀여워 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 205. 내 기억에 너무 잼있었떤듯 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 206. 우와 신기하다!! 나 진심 시사회보고 평점쓴거삭제당함!!! : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 207. 순수함을 말하고있다. 자연스럽게 대화만으로 서로가 끌리는 사이.... 자연스러운 만남, 영적 소통, 하루뿐인 아쉬움을 공감하며. 이들의 반년 후의 모습이 설레이며 궁금해졌다. : **긍정**
#
# 이 문장은 순
# --------------------
# 208. 무섭지라도 않으면 끔찍하기라도 하던가 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 209. 요요비치 나옴...발코니에서 아래를 내려다 보는 일행중 한명으로 등장함 상영 1시간 10분쯤 10초 즈음해서..영화는 형편없음. 야하지도 않고,. : 부정
#
# 영화는 형편없음을
# --------------------
# 210. 20년이 지나도 여전하구나~~ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 211. 남자 조낸 찌질한 연기 잘함...보는 내가 답답해요..그동안 봐온 독립영화중 좀글네요 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 212. 젊음과 열정 격정과 두려움..그 모든 것이 묻어나는 영화.. : 긍정적인 분류:
# - 영화는
# --------------------
# 213. 어라~게임 영화가 아니네~ : 부정으로 분류합니다.
#
# 영화는
# --------------------
# 214. 엄정화 다시보기 연기굿 : 긍정
#
# 이 영화는 엄정화
# --------------------
# 215. 이렇게 불쾌한 내용을 왜 보게한거냐 : 부정으로 분류합니다.
#
# 이렇
# --------------------
# 216. 이거 다운하려는데 청소년 관람 불가라고 뜸 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 217. 공산사회주의의 잔인함을 느끼게 해주는 영화 북한에 비하면 암것도 아니지만 : 부정으로 분류합니다.
#
# 북한
# --------------------
# 218. 다시보고싶다 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 219. 왜 이렇게 다들 스토리에 불만이지....... 이야기에는 다 원형이 있다. 이 영화는 그 원형이 되는 스토리 안에서 예술을 한거고... 그걸 가지고 진부하다고 하면 대체 뭘 본건지.. : **긍정**
#
# 이 영화는 이야기
# --------------------
# 220. 글쎄 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 221. 역시 팀 버튼. : 긍정
#
# 이 영화는 팀 버튼의
# --------------------
# 222. 노다메는 유치한게매력인데 욕하는새뀌들 드라마부터 보고와 : 긍정.
#
# 노다메는 영화에서
# --------------------
# 223. 애매하네... : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 224. 저만 별로였던가요 ㅠㅠ 그냥 그랬어요 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 225. -,.ㅡ 허접스런 영화,스토리도 시대착오적인..3류 코미디 : 부정.
#
# 영화는 시대착오
# --------------------
# 226. 이 영화를 보고난후 극장 영사실을 유심히 보게 되었다. ^^ : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 227. 많이무겁지도, 그렇다고 가볍지도않아요. 진짜 보기좋은 성장영화 : 긍정.
#
# 영화는 긍정적인
# --------------------
# 228. 터지고 깨뜨리고 박어 : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 229. 매주 이것만 기다리로있어요ㅠ너무 재밌어요♥소변 사랑합니당 : 긍정적인 분류:
# - 영화의
# --------------------
# 230. 맥가이버 머리 유행했을때 인기폭발 -_-; : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 231. 완전쓰레기군 . 하고 보는데 생각보다 생각없이 잘 봣다. 그래서 2점준다. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 232. 이건뭐 차라리 19세면노출을더하던가 이건뭐 망 : 부정으로 분류합니다.
#
# 이건
# --------------------
# 233. 보면 볼수록 나도 저 회사에서 일하면서 잘하고 싶단 생각이 만들게 하는 드라마. 캐스팅도 아주 완벽한 듯 합니다. : 긍정으로 분류합니다.
#
# 본 문
# --------------------
# 234. 개잼남..포르x는 중요부분만 챙겨보지만 이건 오직 정주행함..ㅋ : 부정.
#
# 이 문장은 개잼
# --------------------
# 235. 전 재미나게 봤는데..달튼의 능글한 매력과 젊은 시절 페넬로페를 본 것으로도 10점 : 긍정적인 분류입니다.
#
# 이 문
# --------------------
# 236. 공포영화야 이게?ㄷㄷ : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 237. 농담과 장난끼만으로 영화를 만들기엔 무리가 있어 보인다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 238. 외계인이 징그럽지만 SF는 재밌다!ㅋㅋ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 239. 세븐을 생각하면서 봤다가 큰코다친 영화, 모건프리먼의 연기는 좋았으나.. : 부정.
#
# 세븐을 생각하면서
# --------------------
# 240. 이토준지 원작의 영화화는 대체.. : 긍정
#
# 이 영화는 대체로 영화
# --------------------
# 241. 척보기에도 흥행에 실패하겠고만.. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 242. 나름 대중성 있는 만화작품을 이렇게 이런 태도로 취급하다. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 243. 중년의 나이라면 한 번쯤은 봐야 할 영화 : 긍정적인 분류:
# - 영화의
# --------------------
# 244. 감동... : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 245. 일본스타일 공포영화를 시도한듯한느낌. 깜짝깜짝놀래키는것밖에없는 일회용 공포영화 : **긍정**
#
# 영화는 일본스타일
# --------------------
# 246. 아, 이거! 어릴 때 봐서 잘 기억은 안 나짖만 재밌었던 것 같음. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 247. 영화 바람을 재밌게 본사람이라면 추천합니다. 가벼운마음으로 보기 좋은영화에요 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 248. 훌륭하다. 초한지 얼른 읽어보고 다시 봐야겠다. 연출 훌륭하다 껄껄 한신의 토사구팽은 슬펐다 : 긍정적인 문장입니다.
#
# "훌
# --------------------
# 249. 적은돈으로 나름 최선을 다해 만든 듯, 한하유가 마음에 들어서 10점 : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 250. 연애인더빙도 참고 다참았지만 이건진짜 못참겠다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 251. 정신없는 여자주인공보느라고 어지럽다. 스토리도 완전 어거지;; : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 252. 뭔가 스토리가 이상함 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 253. 이 영화에 별점 하나 주는 사람들과 같이 살고있다는게 끔찍하다 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 254. 돈걱정 제로인 비현실적인 사람들, 비현실적 세상 설정 : 긍정
#
# 이 문장은 비현실
# --------------------
# 255. -- : 본 문장은 긍정적인 평가
# --------------------
# 256. 책으로 먼저 접한, 폭풍의 언덕.21살 이었던, 내게 사랑의 그 진한밀도를 알게 해준. : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 257. 서브남주들이 더 빛나 보이고 주인공 같았던 영화. 벤자민과 지지가 나올 때가 더 즐거웠다. 특히 지지. 여주보다 더 예쁨! : 긍정.
#
# 이 문장은 영화를
# --------------------
# 258. 1편보다는 더짜임새가있네요..그렇지만 개인적으로 로버트쇼에 더눈독이가네요..... : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 259. 평점9점 이상은 뭐냐 애니보고 그런말이 나오나 보자 : 긍정으로 분류합니다.
#
# 평점
# --------------------
# 260. 현실은 이러하다 : 긍정으로 분류합니다.
#
# 이러
# --------------------
# 261. 첫장면보고 영화 재미있겠구나 했는데...너무 지루하네요 지난과거를 회상하는건데 너무 지루하고 재미없습니다..감동도 없고 시간남아돌아도 다른영화 보시는게 좋을것 같아요.. : **부정**
#
# 영화의 첫장면
# --------------------
# 262. 조금만 집중해서 보면 엄청 심오한 영화다..! : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 263. 탕웨이... 정말 매력적인 여자... : 긍정.
#
# 이 문장은 탕
# --------------------
# 264. 세분 비구니들이 꼭 자기자신을 찾기를 간절히 바랍니다.약간의 눈물은 흘렸지만 잔잔한 그들의 모습에서 나의 삶을 뒤돌아본 너무나좋은 느낌의 다큐였습니다. 진심으로 이런 분들의 삶을 으원하며 감독님의 열정에 감사 드립니다. : **긍정**
#
# 이 문장은 영화
# --------------------
# 265. 부산엔 언제 개봉해요? : 부정.
#
# 영화는 부정적인 내용
# --------------------
# 266. 어떻게든 감싸줄려고 노력을 하는구나 : **긍정**
#
# 이 문장은 감
# --------------------
# 267. 완전 잼다ㅋㅋㅋㅋ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 268. 이거 끝날때까지 먼가 기대했는데 아무것도 없었네요 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 269. 완전 대박 ㅠㅠ 후회없는 영화에요♡꺅꺅꺅 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 270. 디박!! 대박!!잼씀 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 271. 제가 본 애니메이션 영화중에 명작입니다 : 긍정.
#
# 영화리뷰는 영화를
# --------------------
# 272. 마수리와 비교하면 한 없이 작아지는 컴미 : 긍정
#
# 이 문장은 마수리
# --------------------
# 273. 이젠 양동근은 믿고보는 배우가 아니게 되어버렸다. : 부정으로 분류합니다.
#
# 이젠
# --------------------
# 274. 진짜 졸잼.. 와 마지막 결말 너무맘에들음 ㅠㅠ 진짜 재밌었음!! : 긍정.
#
# 영화는 긍정적인
# --------------------
# 275. 감명깊고 재밌다.굿!!!!!!!!!!!!! : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 276. 나는 다르게 생각하는데... 여기서 너구리에서 인간으로 변신해서 살아가는 사람들은 우리 사회의 소수자들을 상징하는 것 같다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 277. 2시간이 아깝다. 내용도 단순 재미도 감동도 볼거리도 없다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 278. 지금까지 나온 드라마 중 최고였습니다. 100점 만점! : 긍정적인 분류입니다.
#
# 이 문
# --------------------
# 279. 정말 초딩을 위해서 만든거 스토리 쓰레기 벨런스쓰레기 액션쓰레기 : 긍정적인 분류:
# - 영화 리
# --------------------
# 280. 굿~~재밋다~~봐도봐도 잼따 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 281. 연기자들 지혼자 날라가는 연기 압권 : 긍정.
#
# 이 문장은 연기
# --------------------
# 282. 보고울음 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 283. 배우 이민호와 김희선의 어울리지 않을것 같은 어울림이 묘한 매력으로 다가오는 신의 ^^ 타임스립드라마의 최고봉이라 할 수 있답니다. 잔잔하게 애잔한 신의의 매력으로 풍덩 빠져보심이 어떨런지 ^^ 내인생 최고의 드라마였습니다. 적극 추천합니다. : **긍정**
#
# 영화는 긍정
# --------------------
# 284. 이딴 영화가 평점이 왜이리 높은거지..; 케이블에서도 볼가치가 없는 영화.. : 부정.
#
# 이딴 영화는 평점
# --------------------
# 285. 평점 높아서 1 준다ㅋㅋㅋ 정말 재미가 없다.. 지루하고 너무 뻔하고.. : 부정.
#
# 평점과 내용 모두
# --------------------
# 286. 그냥 강지환 아깝다.... : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 287. 군인이 가져아할 것 , 그것을 모두 담아서 표현한 영화이다.이 나라를 위해 죽어서 기쁘다. : **긍정**
#
# 이 영화는 군인
# --------------------
# 288. 영국에도 팍팍한 탄광노동자의 삶이 있구나. 자신의 재능을 발휘할 수 있는 삶을 찾아가는 소년은 행복하다. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 289. 재미가 없다. : 부정.
#
# 이 문장은 영화 리
# --------------------
# 290. 기타케이스에서 총 나오는 씬만 해도 이미 8점은 된다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 291. 더지니어스2 보다 훨났다 : 긍정
#
# 더지니어스는 더
# --------------------
# 292. """이정진,님 정말 비운의 배우라는 생각이!.." : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 293. 살아가는데 한번쯤은 봐주는게 인생에 대한 의리인 영화 : 긍정적으로 분류합니다.
#
# 이 영화
# --------------------
# 294. 3d를 그냥 보니까 좀... : 부정.
#
# 문장은 3d
# --------------------
# 295. 진짜 재밌게 봤다 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 296. 글쎄 돈 주고는 다신 안 보겠어 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 297. 삼순이보다가 궁금해서 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 298. 판타스틱 4 vs 협녀 둘중 하나만 본다고하면 고문이 따로없다. : 긍정으로 분류합니다.
#
# 판타
# --------------------
# 299. 재미있습니다...ㅋ 좀 황당하고 유머러스하고 엉뚱하지만 유쾌하게 보았네요~ 더불어 음악도 좋았습니다~^^ : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 300. 볼만하다... : 긍정
#
# 이 문장은 영화를
# --------------------
# 301. 재미있는데여 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 302. 이거 완전 재밌게봤는데..평점 왜이리 낮음??ㅠ : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 303. 당신은 지금 행복합니까 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 304. 빌어먹을 내가 이제껏 본영화중에 가장 루즈한 영화다. 말도 안돼고, 웃기지도 않고, 빌어먹을 내시간 다잡아 쳐먹고, : 부정.
#
# 영화는 긍정적인
# --------------------
# 305. 졸다니...ㅠ그냥생물들소개..스토리無 3d어지럽고 나레이션오글오글..ㅋㅋㅋ애기영화 : 긍정.
#
# 영화는 긍정적인
# --------------------
# 306. 시즌 4.5.6강추.. 사만다 완젼 웃겨.ㅋㅋㅋ : 긍정적인 분류:
# - 시즌
# --------------------
# 307. 이야기가 전개되는 과정에서 흥미를 유발하지 못한채 시간만 흘러가는군 : 부정으로 분류합니다.
#
# 이야
# --------------------
# 308. 가슴 깊이 울림을 주는 감동적인 영화다.마지막 자막이 올라 갈때까지 흐르는 눈물...이런 아름다운 영화를 이제야 감상하다니...케빈 코스트너,클린트 이스트우드 감독님...존경합니다~~^^ : 긍정적인 분류입니다.
#
# 영화는
# --------------------
# 309. 지나고 보면 다 아무것도 아닐일인데..시간이 준 지혜를 전달해준 영화 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 310. 여주인공이..꽤 괜찮은얼굴^-^ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 311. 진짜 포스터만 멋짐,. 보다가끔. 주연들은 넘 좋지만,ㅠ : **부정**
#
# 영화 리뷰에서 주
# --------------------
# 312. 히 액스멘의 부활이 완벽하다 : 긍정
#
# 이 문장은 액스
# --------------------
# 313. 재미있어요 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 314. 대한민국 해군으로써 dj를 혐오하는건 최대다수의 행복을 죽은 젊은이들의 목숨과 그들 가족의 슬픔보다 중하게여겼기때문이다. 손바닥으로 하늘을 가린다고 하늘이 가려지는게 아니다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 315. 좀 주인공이 짜증났음 마지막도 그렇고 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 316. 거인만 불쌍해...보는내내 속이 불편함. 아 짜증나 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 317. 아오이 유우 맨앞에 한 5분 나오나? 아~~ 이 속았다는 느낌. : 긍정적인 분류:
# 아오이
# --------------------
# 318. 이영화를보고 느낀건.. 개나소나 누구나 영화감독이 될수있다는것이다... 원작을 이렇게 망쳐놓다니.... : 긍정
#
# 이 영화를보고 느낀
# --------------------
# 319. 몰입도 제로 뱀파이어가 피 조금 흘려서 자살하는 꼴에 늑대인간과 뱀파이어라는 초자연적인 존재의 총격전은 왜 하필 소재가 늑대인간대 뱀파이어인지도 모르겠는 작품 : 부정
#
# 이 문장은 늑대
# --------------------
# 320. 논스톱,뉴논스톱,논스톱3,논스톱,4,논스톱5,레인보우로망스 : 긍정적인 분류: 논스톱
# --------------------
# 321. 댓글들 덕분에 영화 보다가 빠르게 포기함 댓글에 참으로 감사함 내 아까운 시간 아껴서....오광록씨 연기연습좀 더하셔야할듯.... : 부정적인 문장입니다.
#
# 댓글들
# --------------------
# 322. 하감독님 21세기는 순정영화도 시가 아니라 긴장감과 메시지가 있어야 먹힌 답니다. : 긍정적인 분류:
#
# 하감독
# --------------------
# 323. 잔잔하게... 오래 기억남네요... 우리시대 보통의 가족의 모습이 솔직하게 담겨있네요. 한소녀의 성장기도요 : 긍정적인 분류입니다.
#
# 본 문
# --------------------
# 324. 재밌습니다. 이만하면 최근 본 상업영화중 순위권에 랭크될만 하네요. : 긍정.
#
# 이 영화는 영화리뷰
# --------------------
# 325. 홍콩영화를 어줍잖게 흉내내고 있는 기절초풍하게 하는 싸구려 무비 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 326. 나탈리아 와아.... 바람핀거였어..... 확실한 영상이 나왓음 했는데.... : 긍정적인 분류:
# - 영화 리
# --------------------
# 327. 이상은땜에 극장에서 봤었지만 최악의 영화였던걸로 기억함.. : 부정으로 분류합니다.
#
# 이상
# --------------------
# 328. '반딧불의 무덤'처럼 불편하게 만드는 진정한 이국적감성 : 긍정으로 분류합니다.
#
# '반
# --------------------
# 329. 존재조차 몰랐던 영화!! noraism 한테 맞구 나한테 와라.. : 긍정적인 분류:
# 영화는
# --------------------
# 330. 후.. : 본 문장은 긍정적인 평가
# --------------------
# 331. 사람의 인생을 한 그림에서 알 수없다는 것. 겉 으로만 알고 있는 것과 진정으로 느끼고 알고 있는 것은 분명히 느낌이 다르니까. 밴 애플렉과 션. 윌은 복 받은 사람 : **긍정**
#
# 영화는 사람의 인
# --------------------
# 332. 스토리. 캐릭터. 표현력. 영상미. : **긍정**
#
# * 스토리:
# --------------------
# 333. 티비드라마보다 못한영화.그 시대엔 티비드라마가 한국영화보다 더 재미있었다. : 부정.
#
# 이 문장은 티비
# --------------------
# 334. 힐러리를 사랑하는 남자아이밖에 생각이 안나요..ㅋ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 335. 스토리도 정말 별거없구 엄청 지루함. : 부정으로 분류합니다.
#
# 스토
# --------------------
# 336. 쓰레기 드라마. 오정.세만 빛났다. : 긍정.
#
# 이 문장은 영화의
# --------------------
# 337. 와 포스터도 같넼ㅋㅋㅋ : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 338. 이건 클래식을 위한 드라마도, 청춘들의 성장 드라마도 아닌 주제를 알 수 없는 드라마가 되어 버렸다. 클래식계의 현실을 고발하기 위한 드라마인가? 심각한 드라마다. 부채도사는 어디로..ㅠㅠ : **부정**
#
# 이 드라마는 클
# --------------------
# 339. 좋아요..^.^ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 340. 쾌락의 정점을 찍은 그들의 삶을 보고 우리는 또 다른 쾌락을 느낀다. 그들이 추하다 생각하지만 결국 우리도 돈을 추구하고 누구나 부유한 삶은 한번쯤 상상 해본다는거..감독한테 엿먹은거 같다. : **긍정**
#
# 영화는 쾌락
# --------------------
# 341. 개인적으로 미식축구를 다시 생각하게 만든 감동적인 영화군요-_-;; : 긍정적인 문장입니다.
#
# 영화는
# --------------------
# 342. 의외로 재밌던 영화 지루하지 않은 사극 멜로였다 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 343. 캐릭터들이 하나같이 짜증유발 매력적인 캐릭터가 없다 할아버지 빼고~ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 344. 엔딩 임팩트가 약하다..통쾌했으면 좋았을 걸.. : 부정으로 분류합니다.
#
# 엔딩
# --------------------
# 345. 역시 박신양..마지막이 쫌...; : 긍정적인 문장입니다.
#
# 영화 리
# --------------------
# 346. 주연배우 너무 지겹고,,, 너무 무리한 압축... 으으으윽 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 347. 같은 상처를 공유하기에 부담스럽고 피하고만 싶은 어머니, 가족이란,,, : 부정으로 분류합니다.
#
# 문장
# --------------------
# 348. 문제아라고 쏘아부쳤던 아이들의 속내. 재빠르고 영리하고 의리있는 시릴 / 다르덴은 이렇게 엉망인 가운데에도 진심의 작은 마음이 지켜갈 수 있는 것에 대해 꾸준히 이야기해주네. 극적이지 않게 직조하는 능력에 감탄 ?@non : 긍정적인 문장입니다.
#
# 문장
# --------------------
# 349. 유치해....더 사실적으로 만들지.. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 350. 흑역사네 ㅋㅋㅋㅋㅋ : 긍정.
#
# 이 문장은 영화 리
# --------------------
# 351. 꽃 빨아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 진짜 짱이었어요 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 352. 별로다. : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 353. 전라도의 모든것을 보여주는 영화!! : 긍정
#
# 이 영화는 전라도의
# --------------------
# 354. 뻔한 스토리, 조잡한 효과... : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 355. 1억2천만불에 제작했지만 수익은 4백만불만 먹고 망한 전세계 2위로 망한 영화 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 356. 기분 나빠서 못보겠다. 두치 때문에 저게 두치냐 ,ㅡㅡ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 357. 수채화같은 영상과 가슴을 울리는 음악이 조화된 잊지못할 명작 : 긍정적인 분류입니다.
#
# 이 영화
# --------------------
# 358. 가장 싫어하는 신파 스릴러 ㅠㅠㅠ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 359. 뭐지..? 이영화는? : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 360. 재밌었음 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 361. 아버지와 소원해졌다면 이런 영화 한편쯤 보는것도 괜찮을듯 싶다. : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 362. 감독이 살아서 요즘 개독들 보면 아마 기가 막힐 듯. : 부정.
#
# 이 문장은 감독
# --------------------
# 363. 말로는 설명할 수 없는 놀랍고 감동적인 영화 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 364. 나가사와 마사미도 그렇고 이 시리즈 너무 좋다 그냥~ : 긍정으로 분류합니다.
#
# 이 시
# --------------------
# 365. 기대안했는데 너무 잼나다 연기짱~ 내용두 탄탄하고 강추~ : 긍정적인 분류:
# - 기대
# --------------------
# 366. 현실적이고 재밌게 꾸며주세요너무 막장은 싫고요인물들의 성격,행동이 일관됬으면 좋겠네요무조건 재미만 추구안했음 좋겠습니다 : **긍정적**
#
# 현실적이고
# --------------------
# 367. 조로아크가 조로아를 간절히 바라는것이 느껴지네요.. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 368. 정종철,박준형등 이무리의 사람들이 나오는 영화는 크게 성공 안한듯?... : 긍정적으로 분류bilir.
#
# 이 영화
# --------------------
# 369. 아진짜...바보요괴들 귀요미잼잼잼ㅋㅋ이 바보요괴들 그립다 ....또보고싶다♡감동도잇구! : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 370. 나름 머리좋고 학식이 높다는 경제학자들이 어떻게 서민들의 생활을 파괴하면서까지 돈을 벌어가는지에 대해 적나라에게 설명해주는 뜻깊은 영화. : **부정**
#
# 이 영화는 서민
# --------------------
# 371. 간만에 원하는 영화가 나왔네요 : 긍정적으로 분류합니다.
#
# 영화는
# --------------------
# 372. 진짜 말이 필요없는 드라마네요 난 왜 작년에 이걸몰랐지..?? 진짜 영화같은 색감과 명품연기자들..인생 드라마가 될거같아요 : **긍정**
#
# 이 문장은 영화
# --------------------
# 373. 괜찮은데 좋아요..우리나라 만화영화발전을 위해서.. 내용재밌는데요 순수만화 : **긍정**
#
# 영화는 괜찮
# --------------------
# 374. 참신한 소재지만 어슬픈 마무리때문에 실화인줄 알았네 : 부정으로 분류합니다.
#
# 본 문
# --------------------
# 375. 재미있어요 너무나도재밌어요 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 376. 반전에 반전, 감독도 지켰는지 대충 얼머무리면서 마무리, 쫑났다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 377. 인생을 다시한번 생각하게 하는 영화...여운이 남는 영화 : 긍정적으로 분류합니다.
#
# 이 영화
# --------------------
# 378. (밑에 분) 그래 난 사람 아니다. ㅎㅎ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 379. 한채영 스탈좋은 거 인정 그러나 언제나 느끼지만 얼굴은.그닥...모두들 책을 읽어대시는구만 ㅋㅋㅋㅋ 내가 본 한국영화중 최악의 연기조합. 연출수준은 학생영화. 이걸 개봉했다는게 놀랍다.이보다 같은해에 나온 해변으로 가다가 훨 나음. : **부정**
#
# 이 문장은 영화
# --------------------
# 380. 이거 왜 재방안해주나요...!!! : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 381. 와 아저씨 조인성도보고 능력있으신분이셨네.. 아무튼 전 서울고 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 382. 툭툭끊기는재미와,어울리지않는대사로멋있게보일라는오도방정. : 긍정.
#
# 이 문장은 긍
# --------------------
# 383. 진-하게 여운이 남는영화 : 긍정
#
# 이 영화는 진정한 감
# --------------------
# 384. 쉬리에서 한 10년은 퇴보한 방화 수준의 망작 : 부정.
#
# 이 문장은 쉬
# --------------------
# 385. 소간지 짱!! : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 386. 5점정도가 적당한 영화...역시 안졸리나는 액숑이다 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 387. 완전 짱임. 한번 보면 폐인됨,.ㅋㅋㅋ : 긍정.
#
# 이 문장은 짱
# --------------------
# 388. 줄거리만 읽어도 대충 감이오는 스토리와 결말이라 기대안하고 봤는데 역시 예상대로였지만 재밌게봤다훈훈해서 좋달까~~ : 긍정적인 분류:
# - 줄거
# --------------------
# 389. 대박 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 390. 조음 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 391. 제발 이런 쓰레기영화 만들지말자 국가적낭비다... : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 392. 어줍잖게 예술가의 고뇌 인양 포장해서 입생로랑에 대해 사기치지마라 지루한 영화는 참을수 있지만 겉멋만 잔득 들어가고 내실은 텅비었으면서 예술인척 하는게 더 봐주기 짜증난다. 올드함과 진부함 그리고 건질것 하나도 없는 대사들의 향연 : **부정**
#
# 영화는 예술가
# --------------------
# 393. 오타루에 와서 다시보는 러브레터. 학교다닐때는 큰 감흥없이 봤는데, 지금 다시 보니 너무 좋다.지금 내리는 큰눈이 그치면 밖으로 나가 다시 느껴봐야지~ㅎ : **긍정**
#
# 이 문장은 영화
# --------------------
# 394. 공포영화인지, 웃길려고하는건지 알수없다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 395. 공허하게 담배피기 - 빌리 밥 숀튼. : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 396. 30대 여자의 노처녀 히스테리에 열등감이 더해지면 어떻게 되는지를 보여주는 영화. 골때리고 끝내주게 웃겨준다 : **부정**
#
# 영화는 긍정
# --------------------
# 397. 재밌어요. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 398. ..대체 내용이 왜 이렇게 이어지는건가 싶었다 ㅡㅡ; : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 399. 브로큰 : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 400. 포스터가 약간 거북하다... : 긍정
#
# 포스터는 영화의 예술
# --------------------
# 401. 유다인이란 배우를 알게 해준 영화 : 긍정
#
# 유다인은 영화리뷰
# --------------------
# 402. 소설 원작 잘 재현해낸거 같아요 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 403. 보다나옴...대사가 온통 노래 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 404. 은행털이 들이 보여주는 몸개그 열전. : 긍정.
#
# 영화는 은행털이
# --------------------
# 405. 정말 오랜만이다...이런 감정...ㅠ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 406. 손현주 짱 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 407. 훈훈한 내용이지만 스토리가 다소 억지스럽고 부족하다. : 부정.
#
# 훈훈한 내용은 좋
# --------------------
# 408. 무언가 잊고 살았다는 느낌을 준 영화 이제 생각을 좀 바꿔야 할거 같음 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 409. 또 뻔한결말 또 뻔한 시걸의 영화 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 410. 혼자 북치고 장구치다가 관객 우롱하면서 끝난다. : 부정.
#
# 이 문장은 영화의
# --------------------
# 411. 천하의 슈렉도 속편이 거듭되다보니 힘이 떨어지는군 : 부정.
#
# 천하의 슈렉
# --------------------
# 412. 주군의태양+파스타 내용은 뻔하지만 재미있다 : 긍정으로 분류합니다.
#
# 주군
# --------------------
# 413. 여자주인공이이해가안됐다남자여자순수한사람여자는양심때문에죽음을평점높다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 414. 시대를 너무 앞서간 영화 ! : 부정.
#
# 이 영화는 시대를
# --------------------
# 415. 박중훈은 괜찮았다 근데 아직 넘 어색하고 꽝이었다 : 부정으로 분류합니다.
#
# 문장
# --------------------
# 416. 반담 영화 중에 꼽는 작품/ 네이버 평점의 신뢰도는 땅에 떨어졌다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 417. 이건 당연히 9점줘야함 ㅇㅇ : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 418. 본지 오래되어서 기억이 잘 안나지만, 야한장면이 부족했던 걸로 기억.. : 부정.
#
# 본지 오래되어서
# --------------------
# 419. 주저리주저리 떠들다 결국 산으로 가는 이야기 : 긍정적인 문장입니다.
#
# 주저
# --------------------
# 420. 매력적인 구석이 있으나 엄청난 자의식 과잉에 질식할 것 같다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 421. 할말을 잃고 봣다...내시간이 아까웠.... : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 422. 헐 : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 423. tv 전기세가 아깝다!!! : 긍정.
#
# 영화 리뷰에서 "tv
# --------------------
# 424. 너무 지루하다. 잠 와 죽는 줄 알았다. 아흠. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 425. 우리에게 행복을 가져다 주는 이들보다 끔찍한 이들이 더 많은 게 현실이다. 우리를 행복하게 해주는 사람들과 함께 하는 것도 중요하지만 그보다 더 중요한 것은 나 스스로 행복해져야 한다는 것이다. 스스로 행복한 사람이 타인도 행복하게 만들 수 있다. : **긍정**
#
# 이 문장은 나
# --------------------
# 426. 간결하고 지적이며 몰입도가 대단한영화 : 긍정
#
# 영화는 간결하고 지적
# --------------------
# 427. 진짜 이병훈 사극중에서 제일 재미없었던 드라마이었던듯 : 부정으로 분류합니다.
#
# 이 드
# --------------------
# 428. 블랙코미디의 진수! 그러나 찌질이들의 위악이 역겨워 별 한점만 주련다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 429. 가슴찡한 웃음뒤에 숨겨진 찡함... 독특한 재미가 있네요 : 긍정적인 분류입니다.
#
# 이 문
# --------------------
# 430. 평점이 왜케 낮아. 이거 짱인데 : 부정으로 분류합니다.
#
# 평점
# --------------------
# 431. 스팟 출연진이 화려하지만 멍청하고 허영심만 가득찬 아마추어의 무개념 자기 배설用 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 432. 입양을 바라보는 냉정하고도 따뜻한 시선에 감탄했다. : 긍정.
#
# 이 문장은 입양
# --------------------
# 433. 알바들아 흥해라ㅡㅡ : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 434. CG나 연기가 현시대에 많이 뒤떨어지는게 흠이지만 SF의 시초로서 슈퍼맨의 위상을 고려하면 9점.. : 부정.
#
# 이 문장은 CG나
# --------------------
# 435. 전 너무재미있었음 성유리의 어색한 연기?/ ㅋ : 긍정.
#
# 이 문장은 영화 리
# --------------------
# 436. 지금보면 삼류영화에요~지루함 : 긍정
#
# 이 영화는 삼류 영화의
# --------------------
# 437. 일본영화를좋아하는이유 : 긍정
#
# 영화는 일본의 문화와 풍
# --------------------
# 438. ㅋ 연기, 시나리오, 연출 제대로 된게 하나도 음슴 ㅋㅋ 보는 내내 비웃음 나온다 진짜 ㅋㅋㅋㅋ난 로멘틱코메딘줄 알았네 ㅋㅋ : 긍정적인 문장입니다.
#
# 영화 리
# --------------------
# 439. 하얀노파 그냥 웃지요 ㅋㅋㅋㅋㅋㅋㅋ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 440. 자극적이기 위해 끼운 억지스런 장면들. 속보이는 뻔한 계산.연출성은 그렇다치고 감독의 인격수준이 바닥. : 긍정적인 평가
#
# 이 문장은
# --------------------
# 441. 갠적으로 1편보다 더 재밌었쏘 : 긍정
#
# 이 문장은 영화를
# --------------------
# 442. 이스트우드 뿐 아니라 애드 해리스의 연기도 잊혀지지 않는다. : 긍정.
#
# 이스트우드와 애
# --------------------
# 443. 고은정혼자자나체한은정 혼자 잘 난체 언제쯤 크다재미없는 이야기 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 444. 이것도 알바있나 개봉전이 8.5야.. 와 0점 못줘서 1점준다 : 부정으로 분류합니다.
#
# 이것
# --------------------
# 445. 사람들이 일상을 대할땐 언제나 신경적이고 지루하하는 경향이 심하다. 삶이란 생각보다 길고 어려운 난간에 봉착하기 마련이기때문인것같다그렇게일상에지내다보면소중한감성을잊고살아오는것같다 이영화를 보고도쿄가가진메트로폴리탄이가진 뒷편 잊고지내던감성이 살아난듯하다 : **긍정**
#
# 영화를 보고도쿄
# --------------------
# 446. 엑소시스트의 먹칠해준 영화 : 긍정
#
# 엑소시스트는 영화의
# --------------------
# 447. 별 반갑지 않은 감독의 시끌벌쩍 : 부정.
#
# 이 시끌벌쩍은
# --------------------
# 448. 완전 .잼잇엇어요!!! 정말.현재의 나를 보는 듯한느낌 : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 449. 이런 쓰레기 한쿡영화는 돈주고 봐주면 절댜 안된다! : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 450. 이게 뭐? 재밌어?! 마지막이라면 그렇다 쳐도 이건 첨부터 여자를 지키는 영화라고 하는데 그런건 나오지도 않고 반전주의 의식을 볼수도 없음 결론적으로 애로영화 노잼 : **긍정**
#
# 이 영화는 재밌
# --------------------
# 451. 상어매니아 기대를 가장 충족시키는 영화라고 생각한다 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 452. 이걸 반전이라고? 미치겠구만..내시간 돌려줘!! : 긍정으로 분류합니다.
#
# 이걸
# --------------------
# 453. 6년연애..여자가 다른 남자에게 흔들린것만 빼면 정말 100%공감하는 제얘기..해피엔딩은 될수 없다는.. : **긍정**
#
# 영화는 긍정
# --------------------
# 454. 공감불가 저런 OOO기들은 다죽여야 하는데 : 부정.
#
# 이 문장은 OOO기
# --------------------
# 455. 눈물로 마무리 짓게 되는 영화 : 긍정
#
# 영화는 눈물로 마무
# --------------------
# 456. 10점으로 이 영화를 표현하기엔 턱없이 부족하다 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 457. 사이코패스 ....- : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 458. 불쌍한 펭귄맨 맥스의 무표정이 제일무섭다 : 부정으로 분류합니다.
#
# 문장
# --------------------
# 459. 1점주는 OOO들은 흰둥이똥구멍이나 핧으라지. 쓰레기들.. : 부정.
#
# 이 문장은 OOO들은
# --------------------
# 460. 베트남전의 폐해에 대해 보여주는 점보다 미국식 패권주의가 느껴짐. 무조건 미국이 전쟁에 참여해 정의의 편이라는 점을 부각시키는 것은 옳지 않다고 봄. 전쟁영화치고 짜릿한 스릴이나 감동 또는 재미도 별로. : **부정**
#
# 이 문장은 미국
# --------------------
# 461. 포스터에 있네요. 보지 않고 판단하지 마라. : 긍정으로 분류합니다.
#
# 포스터
# --------------------
# 462. 평보고 만원결제하고봤는데.. ㅡㅡ; 신랑 보다잠들고 돈아까워서 끝까지보긴했는데.. 평점주는것도 알바있단거 첨알았네요.. 걍 개인기 맘비우고보려고해도 유부녀랑 아무렇지않게 사랑에빠지고.. 그걸 미화시키고.. ㅡㅡ;; 어의없음! : **부정**
#
# 이 문장은 영화
# --------------------
# 463. tv 전기세가 아깝다 캬악 퉷!!! : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 464. 후반부에 펑펑 울었다ㅠㅠ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 465. 있을수 없는 이야기... 인정할수 없는 결론... : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 466. 해리포터 전 시리즈중에 제일 인물 심리묘사나 구체적인 이야기, 그리고 어린애들 영화같지 않은 진지함과 진중함도 느꼈던 편. 갠적으론 파트2의 화려함보다는 파트1의 느낌이 더 좋은것 같다 : **긍정**
#
# * 인물 심리
# --------------------
# 467. 정말 이런 영화가 개봉되다니 믿어지지 않음.처음으로 영화평점을 매기게 한 영화. 무슨 생각으로 수입했는지???? : 부정으로 분류합니다.
#
# 영화평
# --------------------
# 468. 재미없다 진심으로 솔직히 재미없다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 469. d : 본 문장은 긍정적인 평가
# --------------------
# 470. 내생애 최악의 공포영화 공포영화가 무서워야되는데 웃김.. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 471. 참 좋은 영화....! : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 472. 오리지날이다.. : 긍정
#
# 이 문장은 영화를
# --------------------
# 473. 최고의 드라마 김태희랑 OST가 너무좋다 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 474. 너무 재미 있네요 ^0^ : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 475. 이건 뭐 그냥... : 긍정으로 분류합니다.
#
# 이건
# --------------------
# 476. 최고의 영화다.이 영화를 본 후 앞으로 영화를 잘 선택해야 한다는 충고를 얻었다 : **긍정**
#
# 이 영화는 영화를
# --------------------
# 477. 법은강한자에게만 평등하고정의는 없다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 478. 작품성이고 뭐고 도무지 : 긍정
#
# 이 영화는 작품성이
# --------------------
# 479. 진짜 만나기 힘든 명품 드라마! 배우며 작가, 모두 최고! : 긍정적인 분류입니다.
#
# 이 문
# --------------------
# 480. 별로 : 본 문장은 긍정적인 평가
# --------------------
# 481. 이 영화를 이제서야 보게 되다니..명작으로 불러질만 한데 제목이 아쉽다 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 482. 이렇게 못 만들기가 더 어렵겠다. 초딩 학예회급 연기력을 선보인 이요원은 모구 게다가 황정민 딸로 나온 아주머니는 모냐? 감독이나 제작진은 몰보구 캐스팅들을한 거냐? 한심한 영화네... 네이버두 별점 0개 할 수 있게 해주세요 : **부정**
#
# 이 영화는 긍
# --------------------
# 483. 글쎄 좀 쌩뚱맞다고 해야하나.... 이입도 안되고.. 인내심을 요한다.. : 긍정적인 문장입니다.
#
# 이입
# --------------------
# 484. 발전하게 없네여~ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 485. 난꽤 재밌었음 배우연기가 오지니까 : 부정. 배우연기가 오지 않
# --------------------
# 486. 시나리오작가 상 줘라 두번줘라 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 487. 감독이 무슨 이야기를 하고싶은지 모르겠다 복선이 너무 많다 장치가 너무 많다 목잡하고 답답하다 여주인공의 감정과잉이 보는이로 하여금 실소를 머금게한다 : **부정**
#
# 이 문장은 감
# --------------------
# 488. 죄송하지만 빨리 끝나고 다른 드라마 좀 했음 좋겠네요 왜케 길어요 넘 재미없어요. : **부정**
#
# 이 문장은
# --------------------
# 489. 이건 100퍼 킬링 타임용 ㅋㅋ : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 490. 오빠들더멋잇어졋어요ㅎㅎ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 491. 영화 보다 잔건 처음... : 긍정
#
# 영화는 잔건의 첫
# --------------------
# 492. 어디하나 흠잡을 곳 없는 최고의 영화 : 긍정
#
# 이 영화는 영화 감독의
# --------------------
# 493. 별점이 굉장히 높네요. 그럴만한 가치가 있는영화.. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 494. 여기 티모시 스펄이라는 배우나오지 않나요? 배우 목록에 없어서 영화에서 밥으로 나온 그사람 없음 배우목록에 첨부점요 영화는 좋아요 : **긍정**
#
# 영화에서 밥으로
# --------------------
# 495. 평점 처음달아보게만드는데 내인생에서 베스트b급아류작인듯 : 긍정적인 분류입니다.
#
# 이 문
# --------------------
# 496. 킬링타임용 그 이상 그 이하도 아님 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 497. 감정이입 되더라구요.. 이렇게 심하게 영화가 제가 된 적은 없었는데.. 저에게 해당되는 이야기는 아닐지라도, 가슴 찡했습니다.. : **긍정**
#
# 영화는 감정이
# --------------------
# 498. 군인들도 자더라ㅎㅎㅎㅎ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 499. 캡틴 듀브아 나올 때마다 너무 웃겼다. 줄리안이랑 곰의 러브스토리도 재밌었고 무엇보다 서커스씬은 노래 firework와 어울려 환상적이었다. : 긍정적인 문장:
# - 캡
# --------------------
# 500. 아오 초등학교 2학년떄 존 나게 무섭게 봤다 ㄷㄷ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 501. 아재미때까리진짜없네 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 502. 좋은 스릴러 소재로 왜 엉성한 멜로를 만들었을까? : 긍정적으로 분류합니다.
#
# 이 문
# --------------------
# 503. 권선징악이라는 진부한 스토리..하지만 드라마 중반부까진 10점 주어도 괜찮을듯한 연출 스토리 연기력. 후반부 갈수록 누구나 예상가능한 권선징악결론이겠지만 왜인지..예상못할 훌륭한 반전 하나정도 나오지 않을까하는 개인적인생각입니다. 암튼 난 꿀잼ㅋㅋ : **부정**
#
# - 드라마 중반
# --------------------
# 504. 김승우는 연기를 몇년했는데도 연기가 늘지를 않는구나.황정민이나 송강호한테 가서 좀 배우고와라.발연기 대단하다. : 부정
#
# 이 문장은 김승우
# --------------------
# 505. bad : 부정.
#
# 이 문장은 영화의
# --------------------
# 506. 애기때 극장에서 엉엉 울었던기억 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 507. 처음에 이 아이가 크리스천베일임을 알아보고 매우 깜짝놀랐다. 역시 명배우의 이름답게 어릴 때부터 재능을 가지고 계셨구나... 어린아이가 본 시선으로 전쟁이 아닌, 때 묻지 않은 순수함과 호기심을 풀어낸게 멋지다. : 긍정
#
# 이 아이는 크리스천베
# --------------------
# 508. 요즘 비디오가계가 없어서 힘들죠?ㅠ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 509. 캐릭터의 개인기는 좋지만 시나리오를 하루만에 썼네. : 부정.
#
# 캐릭터의 개인기
# --------------------
# 510. 별한개도 아깝다 이런영화에 돈을쓰다니 돈이남아도냐? : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 511. 어설픈 연출과 빗나간 주제의식이 적절하게 섞여있다 : 부정.
#
# 어설픈 연출과
# --------------------
# 512. 빨갱이는 빨갱이일뿐.. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 513. 공유 짱짱맨 ♥＼(^0^*)/ : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 514. 환희님비롯,신인배우들 연기 기대이상이구요, 아름다운 영상에 콘서트 보는 것 같아요. OST곡들 모두 좋아요. : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 515. 두뇌와 가슴이 없이 눈으로만 보는 무지한 사람들에게는 지루하고 돈만 날릴영화겠지. 그런부류는 그냥 치고받고하는 헐리욷 쓰레기 영화나 보길. 왜 이런영화를 돈들이고 시간 낭비하며 보러갔는지 이해가 안감. 명화를 보며 만화만도 남도 못한 쓰레기라 할게지 : **부정**
#
# 영화는 지루하고
# --------------------
# 516. 낚았다 히데오의 조금? 그런 영화 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 517. 다시는 보고싶지 않은 영화 : 부정.
#
# 이 영화는 긍정
# --------------------
# 518. 평점에 낚인 영화 .... : 본 문장은 긍정으로 분류
# --------------------
# 519. 개봉 하고 .. 순식간에 내려가서 망한 영화라고만 알고 있다가 한번 본 후로는 괜찮은 영화라고 생각이 들더군요 ~ 어떤분은 허구라고 하는대... 실제로 있던일인대 무슨 허구입니까... : **긍정**
#
# 영화는 순식간
# --------------------
# 520. 흥미롭고 가슴 뭉클해요. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 521. 평점보고 봤다가 내용도 노잼이고 웃긴것도 아닌 유치한 개그나 치고있고 액션이 쩌는것도 아닌 80년대 액션을 보여주고 20분 보다가 짜증나서 넘겨가면서 보다가 꺼버렸음. 지금 궁금한건 저기 나온 딸래미 여자애 분명히 AV에서 본거같은데 누군지 기억이안나 : **부정**
#
# 평점보고 내용
# --------------------
# 522. 제목도 그렇고 정말로 짜증이 나는 영화였다 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 523. 이런 찝찝함이라니.... : 긍정으로 분류합니다.
#
# 이런
# --------------------
# 524. 솔직히 재미는 있자나... : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 525. 잘만들었다고 보기에는 그다지..특이한 취향을가진 사람들의 행복찾기..? : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 526. 드라마 왜 이리 재미없는 이야기 : **부정**
#
# 드라마 이리의
# --------------------
# 527. 1점보다 더 이하주고싶다 : 부정.
#
# 이 문장은 영화 리
# --------------------
# 528. 라이언 필립이 왜 못 뜨는지 확실히 알려준 영화. : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 529. 잘보고있어여진자,,, ㅠㅠㅠ부럽다 : 부정으로 분류합니다.
#
# 문장
# --------------------
# 530. 와 여러번봐도 재밌다. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 531. 솔직히 아닌것은 아니다 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 532. 스페인 영화기도 하고 맨 마지막 씬은 결코 잊을 수 없다 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 533. 감독의 상상력과 작품성이 우수했던 작품이라 생각됩니다. 현실과 환상의 세계를 헤엄치는 미스터리 다시 한번 재감상을 통해 미스터리 작품의 세계로 빠져들고 싶습니다. : **긍정**
#
# 작품의 감독
# --------------------
# 534. 이거 감독하고 출연배우빼곤 아무도 끝까지 못본다던 그 유명한영화? : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 535. 이거 KBS2 TV에서 한거쟎아요.. : 긍정
#
# 이 영화는 KBS2 TV에서
# --------------------
# 536. 감동이 살아있어!^ : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 537. 케이블에서 할때마다봄.조쉬하트넷 멋있음 : 긍정.
#
# 영화 리뷰에서 케이블
# --------------------
# 538. 좋아요 다시 보고 싶은 영화 : 긍정
#
# 영화는 긍정적인 요
# --------------------
# 539. 정말 정말 할일없을때 시간때우기도 재미없었네 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 540. 재미없다..보지마라.. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 541. 스토리가 스릴있고 훈훈하다 : 긍정.
#
# 스토리는 스릴있
# --------------------
# 542. 지루하다. 2차 대전의 화려한 전투씬을 기대했는데동네 아줌마들의 친목 도모라니...임팩트와 감동이 없다.물론 이런 내용을 좋아하는 사람도 있겠지만 나는 땡. 2점 : 부정.
#
# 이 영화는 화려한
# --------------------
# 543. 오늘 엘지유플러스로 장화,홍련이란 영화를 보았을떄무섭고 감동 적이었어요 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 544. 색다른 코난 시리즈 인 듯 ~~~♥ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 545. 1회부터 지금까지쭈욱~~넘잼있어요~오늘강우창이 넘나빠ㅠㅠ순금이는우짜라꼬ㅠㅠ : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 546. 정화누나!!!!전생에 나라를 구하셨습니다!!!정화누나 너무 좋아하는데~~~요즘은 너무 부러워요~~~크크크~~~ : **긍정**
#
# 정화누나가
# --------------------
# 547. 좋은 소재지만 연출이 ㅈ망이네 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 548. 망해도 싸지 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 549. 티비에서 방영해주길래 우연히 보게 됐습니다.평점이 왜 8점밖에 되지 않나 의문이네요 스토리가 진행되며 느껴지는 쾌락, 슬픔 그리고 사회 풍자적 요소 정말 재밌게 봤습니다.. : **긍정**
#
# - 영화는 평점
# --------------------
# 550. 이건 영화가 아니라 포르노 수준인데... : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 551. 감동..첸카이거감독작품은 역시 : 긍정
#
# 영화는 감동적인 장면
# --------------------
# 552. 진행자들이랑그방청객들 너무오버하는게 보기안좋더라. 그렇지만, 휘성편은 정말재미있게봤다. : **긍정**
#
# 이 문장은 영화
# --------------------
# 553. 이시대 아버지의모습.. 너무나 잘표현했던 영화. 아버지는 세월이가도 아버지입니다. : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 554. 너무 한 출연자에게만 어필하고...송은희씨는 너무 끼어들고 그치만 신동엽씨는 역시 프로네요~ : 부정.
#
# 이 문장은 끼
# --------------------
# 555. "아주 큰 교훈을 얻었다 ""야한장면을 보고 싶으면 야동을 보라""" : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 556. 어릴때봤지만 20년이지난 지금도 생각나는 인상깊은영화에요 오늘따라 다시보고싶어요 : 긍정적인 분류:
# - 영화의
# --------------------
# 557. 굳 : 본 문장은 긍정적인 평가
# --------------------
# 558. 초반에 엘베안에서 공효진이 이선균 기습볼뽀뽀할때 왜이리 좋지ㅋㅋㅋㅋ 이선균 공효진 둘다 표정이 재밌어서 그런가 되게달달했음ㅠ 새벽까지 몰아서 봤는데 꿀잼졸잼짱잼!!! : **긍정**
#
# 영화의 초반에
# --------------------
# 559. good : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 560. LOVELY!! 유머들이 기가 막혀요~^ : 부정.
#
# 이 문장은 영화 리
# --------------------
# 561. 재미있게 봤음요~ 추천!!! : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 562. 내가 알기로 이게 박찬욱감독의 본모습인데..... : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 563. 아무것도 모르는 대중을 선동하는 선동버스... : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 564. 한마디로 말해서 핵! 노~잼 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 565. 드라마가 좋은 것도 아니고 액션이 좋은 것도 아닌... : 부정.
#
# 드라마와 액션
# --------------------
# 566. 김청기감독이제일좋아요........................ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 567. 드니라방 소름돋는다...봉준호도 괜찮았다 미셸 공드리는 별로... : 긍정.
#
# 드니라방 소름
# --------------------
# 568. 간만에 괜찮은 스릴러물을 만났네요. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 569. 지루해 죽느줄 알았다... 유우때문에..끝까지 본 영화 -_- : 부정.
#
# 영화는 지루해가
# --------------------
# 570. 아이들이 좋아하고 어른이봐도 재미있어요 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 571. 한개도 아깝다쓰레기영화 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 572. 위로가 필요할때 위로가 되는 드라마!!! 너무죠으다 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 573. 재미있던데..내용이해도잘되고 : 긍정으로 분류합니다.
#
# 재미
# --------------------
# 574. 어릴적 우주비행사를 꿈꾸지 않은 사람은 없을것이다..ㅋ 이제라도 봤으니 다행..ㅋ : **긍정**
#
# 이 문장은 영화
# --------------------
# 575. 왜상받았지? 진짜지루하고 끝까지보면 욕나옴(보면 암) : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 576. 재미없다.. 옹박 오리지날 1편빼고 만들지 말았어야했다.. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 577. 오랜만에 영화다운영화를 봐서 좋아써요~~안보면 후회해요!! : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 578. 세익스피어가 이렇게 차별주의적인 사람이었다니.. : 긍정으로 분류합니다.
#
# 세익
# --------------------
# 579. 상당히 시답잖고 어설프네. : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 580. 평점이 왜이렇게 낮은걸까요?; 소재도 신선하고 중간중간 많이 웃었습니다 ㅋㅋ : **긍정**
#
# 평점이 낮
# --------------------
# 581. 로맨틱한 지구 종말. 잔잔한데 마지막 장면 여운이 너무크다.. 재난블록버스터보다 이런게 훨씬 와닿고 현실적으로 무섭고 슬픈것 같다. 보는내내 소소한 웃음도 있고 감동도 있고 배우들도 사랑스럽다. 나도 저렇게 종말을 맞이하고싶다 !!! : **긍정**
#
# 영화는 로맨틱
# --------------------
# 582. 바이오로보 표절... : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 583. 이 정도로 평점 끌어올린거 보면 배급사에서 알바 잘 뽑으신거 같아요. 아니면 4대보험 들어가는 정직원들인가 ㅋㅋ : **긍정**
#
# 이 정도로 평
# --------------------
# 584. 평점왜이렇게 높냐 이게 볼만하다고? 참나.... : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 585. 진짜 희대의 망작. 시간은 황금보다 귀하다는말이 절실하게 느껴졌다. : 부정.
#
# 이 문장은 영화의
# --------------------
# 586. 딸하고 너무 재미있게 봤어요 영화 본 뒤로 딸은 도라애몽과 같은 주머니가 있었으면 하네요 ㅎㅎ : 부정.
#
# 영화는 딸과 도
# --------------------
# 587. 이게 영화야?월요일 국군방송보다 졸려 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 588. 우연성이 너무심해 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 589. 모든 걸 다 떠나, 공포영화가 이토록 지루할 수도 있구나 하는 생각이 든다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 590. ㅋㅋㅋㅋ아놔 진짜 네이버영화 스포하지마라 : 부정.
#
# 영화 리뷰에서 영화의
# --------------------
# 591. 이것 다시 보고 싶은데 정말 재미 있었는데 : 긍정.
#
# 이 영화는 재미있
# --------------------
# 592. 포스터부터 90년대 영화다 진짜 할말을잃엇다 2010년영화라니 : 긍정적인 분류:
# 영화리뷰
# --------------------
# 593. 실화여서 더 재미있는듯ㅋ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 594. 이 영화때문에 영화보는 눈이 엄청 높아져서 몇몇만제외하고 거의 다 재미없는영화로 만든 걸작..영화관에서 나오면 꼭 허전한게 있었는데 이건 걍 꽉꽉 채워나온 느낌?영화관에서 본게 정말 신의한수이고 진짜 내생애 최고의 영화 : **긍정**
#
# 영화는 영화보는
# --------------------
# 595. 샘들러 영화는 별로인듯 잼있게본게..하나도 없음.. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 596. 샌프란시스코의 쟈니!! : 긍정
#
# 영화는 샌프란시
# --------------------
# 597. 그래도 액션은 볼만했음~ㅎㅎ : 부정.
#
# 영화는 액션에
# --------------------
# 598. 왜케 광고는 멋지게 해놨는지.. 정말실망 : 부정으로 분류합니다.
#
# 영화 리
# --------------------
# ...
# - 영화는
# --------------------
# 808. ㅅㅂ 내돈 : 긍정
#
# 영화는 시청자들에게 감
# --------------------
# 809. 투니버스에서 보는것만으로도 만족한다 ㅡㅡ : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 810. 액션 영화가 지루하다면 얘기는 끝난 것 아닌가. 도입부만 흥미로웠다. : 부정.
#
# 영화가 지루하다면
# --------------------
# 811. 제목때문에 삼류 에로 영화 타이틀 같지만 내용은 알찬 스릴러 물 그리고 요즘 덱스터에 나오는 데스몬드의 리즈시절 모습을 볼수 있기에 : 긍정.
#
# 이 영화는 알찬 스
# --------------------
# 812. 이건 아니잖아 그토록 딸을 찾기위해 모든것을 버린...미아찾기운동까지해가며 열성인 엄마는 딸도 못보고 죽게 만들고...엄마 죽고나서 급 몰입도떨어지고...범인은 여기저기 나 여기있소 단서남겨도 못잡고...현실성이 너무 떨어지고... : 부정적인 문장입니다.
#
# 이 문
# --------------------
# 813. 이런 애니는 처음..그리고 반가운 오인용 식구들 목소리~ : 긍정적인 문장입니다.
#
# 이런
# --------------------
# 814. 안보는게 약인 영화다 이런 영화 보면서 뭔가를 알고싶지도 느끼고 싶지도 않다 하지만 느꼈다 속이 울렁거리는 영화다 내가 본 느낌을 표현 한다면 길가다 많은양에 구토물을 본 느낌인데 구토한 사람이 뭘 먹었는지 궁금하지는 않다 : **부정**
#
# 영화의 내용과 관련
# --------------------
# 815. good~~ : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 816. 평점이 너무 낮아 놀랍네요; 개봉당시 영화관에서 2번 보고, DVD까지 소장한 작품인데.. 이 영화로 김지운 감독 주목받아 헐리우드 진출까지 한 대작입니다. 한국에서 이런 영화가 나왔다는게 감사한 작품! : **긍정**
#
# 영화는 평점이
# --------------------
# 817. 1잠도 아깝네요 제대로된게 하나도없었어요 기대도 안했는게 이정도면뭐... 대체피시 셍긱이잇는건지 한심.. 김대희 분량이없다며병풍이라 하시는분들 계신데 전 김대희 주먹쥐며 몇번째손가락올릴지모른다 욕할꺼다 막말한모습이 너무 싫엇어요.. : **부정**
#
# 영화 리뷰에서 의
# --------------------
# 818. 전작보고 기대했는데.....실망가득한영화다.. : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 819. 어린애들이 나오는 공포물은 거의다 재미가없다 ~~~~~~~ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 820. 명작입니다 꼭 보세요 공백10자 : 긍정
#
# 이 영화는 훌륭한
# --------------------
# 821. 정말 이것도영화라고 만든색히 지도 영화감독이라고 어디가서 떠들고 다니겠지..평점 최소가1이라서 1점은주는데 이건 정말쓰레기로도 못쓴다.에이 퉤퉤!! : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 822. 이딴게 영화 라니 ^ㅗ^ : 긍정
#
# 이딴게 영화는 영화 감
# --------------------
# 823. 이영화는 6점대가 적정하다고 생각합니다.연기도 좋고 스토리도 좋은데 몰입감이 떨어지네요.뭔가 억지스럽게 끌어가는 느낌입니다. : **부정**
#
# 이 영화는 긍
# --------------------
# 824. 평점보고봤다간정말큰코다침!!최고지루함!헉!! : 긍정적인 평가입니다.
#
# 이 문
# --------------------
# 825. 어쩌다 생각이 나서 처음으로 네이버 영화 평을 올리는데, 정말 어린 배우들 유명세에 기대어 흥행은 했는지 몰라도 나중에 이 친구들이 연기에 대해 눈을 조금이라도 뜨게 되었을 때 자신의 흑역사로 기억할 영화가 아닐까 싶다. : **부정**
#
# 이 문장은 영화
# --------------------
# 826. 잼있음 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 827. 이게 영화냐? 야동이지 : 긍정
#
# 이 영화는 야동의
# --------------------
# 828. 영화가 끝난후 텅비어버린 가슴..진실이 왜곡되는 정치적 이념의 송가.. : 부정으로 분류합니다.
#
# 영화의
# --------------------
# 829. 이런 영화는... 그냥 10점임... ㅜㅜ... 저 위 포스터는 도대체 누가 만든거냐??? 파스텔톤의 사랑 영화 아님... ㅜㅜ : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 830. 이런 영화를 만드는 이유를 모르겠다. : 부정.
#
# 이 영화를 만드는
# --------------------
# 831. 그래서 결론은 뭐지 ??? : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 832. 누구나겪을수있는삶에대한많은이슈들을일상적이면서유머러스하게전개하여편안한감동을만들어주는영화같아기분이좋아진다... : 긍정적으로 분류합니다.
#
# 이 영화
# --------------------
# 833. 행복을 아메바같이 단순화시킴. 또한 여행도 작위적~ : **긍정**
#
# 행복과 작위
# --------------------
# 834. 최고의 연기력과 기획 이영애 최고~! : 긍정
#
# 이 문장은 최고의
# --------------------
# 835. 내용이없어 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 836. 자토이치 짝퉁이군...어이가 없어 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 837. 쓰레ㅐ기영화 전작에 제대로먹칠 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 838. 호주에서 살고싶게끔만드는 영화 : 긍정
#
# 영화는 호주에서 살고
# --------------------
# 839. 다보고 느낀점수 : 긍정
#
# 영화는 영화 감독의
# --------------------
# 840. 비디오로 보지말고 그냥 오씨엔으로 보는게 나을듯 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 841. 지금 보니 웃음만... 격세지감... : 긍정적인 분류:
# - 지금
# --------------------
# 842. 심심할때 볼만.. : 긍정
#
# 이 문장은 영화를 감
# --------------------
# 843. 80년대 우리나라는 영화도 후진국이었군요 어떻게 저런 연기를... 동시대에 나온 영화가 ET 였던걸로. : 부정.
#
# 이 문장은 ET가
# --------------------
# 844. 평점조작단아 장난치지 말아라. : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 845. 첨 볼 땐 다슬이 참 사랑스럽다...두번째 볼땐 다슬이 가족들 참 좋은 분들이다...세번째 볼땐 내 가족들도 있는 그대로의 모습을 봐줘야겠다는 생각이 들었다. 다슬이가 계속 보고싶어.. : 긍정적인 분류:
# - 다슬
# --------------------
# 846. 시작은 좋으나 끝은 흐리멍텅.반전에만 집착하는 샤말란 : 부정으로 분류합니다.
#
# 시작
# --------------------
# 847. 숨막히는 사랑.. 정말 너무 슬퍼서 아름답다 : 긍정.
#
# 이 문장은 숨
# --------------------
# 848. 왜...박하선이 복수를 하는지 이해가 안되네요^^오히려 권상우가 더 피해자같은데~그만큼 남편한테 믿음이 없었나하는 생각도 드네요 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 849. 이러지도 저러지도 않는 오락가락 스릴러 : 긍정.
#
# 이러지도 저러
# --------------------
# 850. 후세에 걸작의 재조명을 시키다. : 긍정
#
# 후세에 걸작은 영화
# --------------------
# 851. 난 보는내내 그냥에로영화인줄알았는데 이게네이버에올라와있네. : 긍정적인 분류:
# 영화 리뷰
# --------------------
# 852. 감정의 골이 패여 생긴 마음속 주름이던, 세월의 흔적이 보여지는 얼굴위 주름이던 과하게 인위적으로 펴면 부자연스러움을 피할 수 없다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 853. 기대감이너무컸다.1탄의명성을먹칠한영화! : 긍정적으로 분류합니다.
#
# 이 영화
# --------------------
# 854. 최고 : 긍정
#
# 이 영화는 영화 감독의
# --------------------
# 855. 아....... : 아, 이 영화는 긍정적인 리
# --------------------
# 856. 내가 왜 이걸 10년도 더 지나서 보게 된 걸까...ㅋㅋㅋ 그 땐 초등학교 1학년었지 참 : 부정
#
# 이 문장은 긍정
# --------------------
# 857. 진짜 추억 돋는다 : 긍정으로 분류합니다.
#
# 진짜
# --------------------
# 858. bad : 부정.
#
# 이 문장은 영화 리
# --------------------
# 859. 영국영화도 상당히 독특하군요. 스토리야 있지만 영화로서의 재미는... 장편 독립영화도 아니고. : **긍정**
#
# 이 문장은 영화
# --------------------
# 860. 쓰레기네여 : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 861. 정의를 위해...일단 봐라 ........신선한 충격이다 ...이런 영화 평생 보기 힘들다 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 862. 정말 제인생최고의영화 : 긍정.
#
# 이 영화는 영화 감독
# --------------------
# 863. 나 저거 다운 잘못받은줄ㅋ20세기 전반대 영화인줄 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 864. 평 남긴 것들 본 영화가 하나같이 똑같냐 ㅋㅋㅋ 알바도 좀 티 안나게 하자... : 부정.
#
# 영화의 내용과 주제
# --------------------
# 865. 산뜻한 그들만의 반란....우리에게는 빵도 필요하지만 장미도 원한다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 866. 무슨말이 더 필요한가? 믿고보는 일본 애니아닌가!! : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 867. 이 OOO 영화를 내가 검색한 이유는 감독이 또 만든 '맨데이트' 때문 : 긍정
#
# 이 OOO 영화를 내가 검색
# --------------------
# 868. 야구란 이런거다 하는것... : 긍정
#
# 영화는 이런거다는
# --------------------
# 869. 무엇보다 쇼킹한건 이영화의 네이버평점... 아버지의 원수이지만 아버지와 같은 마음을 품게되는 영화 전반부의 암스테르담의 고뇌는 참으로 훌륭한 심리전개... 영화전체적으로도 지루하지 않은 영화전개와 스케일.. 고루 만족스러운 영화 : **긍정**
#
# 영화는 네이버 평
# --------------------
# 870. 홍번구에 비해 액션이 약했지만.. 성룡은 역시 우리를 즐겁게 해준다 : 부정.
#
# 영화는 액션 부
# --------------------
# 871. 정말재밌다 10자.. : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 872. 서정적인 세계에 빠져들고 싶다면 : 긍정.
#
# 이 문장은 서정
# --------------------
# 873. 고스터버스터즈 느낌의 수작이다. : 긍정.
#
# 고스터버스터즈 느
# --------------------
# 874. ㅇㅇ...좋음 : 긍정으로 분류합니다.
#
# 영화 리
# --------------------
# 875. 죽음을 통한 소녀의 성장을 다룬 블랙 코미디. : 긍정.
#
# 이 영화는 소녀가 죽
# --------------------
# 876. 진심개거지......울나라에서개봉왜한거임? : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 877. 영화 이보다 더 잘 만들 수 있지 않았을까? 유덜보다 캐롤 성격이 더 이상해보인다. 참신할 것도 없는 흔해빠진 로맨스물에 왠 평점을 이리 높이들 주는지... : **부정**
#
# 영화가 캐롤 성
# --------------------
# 878. 감독의 연출이 부재니 좋은 소재를 말아버린다 : 부정으로 분류합니다.
#
# 감독
# --------------------
# 879. I told you.. chickens are organized! : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 880. 상 받았다니까 왠지 좋았다고 해야할 것 같은 압박감에서 벗어나세요. 아무것도 없다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 881. 별로 안무서운데; : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 882. good! : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 883. '영구 vs 맹구'나 '람보 vs 코만도'를 만드는 게 더 낫겠다 : 긍정적인 분류:
# - 영구
# --------------------
# 884. 어설픈 스릴러, 어설픈 코메디, 어설픈 데미 무어 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 885. 어린이채널용 드라마 같은 것이 응응씬을 너무 남발한다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 886. I'll win cuz I have faith, courage, and enthsiasm! : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 887. 평이한 로맨틱 코메디. 행크스 많이 늙었네 : 긍정.
#
# 이 영화는 행크스
# --------------------
# 888. 꺼이 꺼이 울면서 봤던 영화. 정말 다시 한번 보고 싶다. 정말 진심으로 다시 한번... : **긍정**
#
# 이 문장은 영화
# --------------------
# 889. 닥터호의 아픔이 절실히 느껴지는 그런영화 입니다 : 부정.
#
# 영화는 닥터 호
# --------------------
# 890. """무법자의 천상천하유아독쫑"" 이란 제목이 더 잘어울리는 영화!" : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 891. 이 괴상한 심심한 영화는 갑자기 뭐지....기대이하자나?...뭐하나 제대로하는게 없는 영화....베네치아의 풍경만 볼만함.. : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 892. 지금까지 본 한국공포영화중에서 내용이 꽤 신선하고 재미있었던 영화입니다.참고로 내용 이해하기 싫어하고 무조건 피터지고 때려잡는 좀비영화같은거 좋아하는 사람들은 별로 안좋아할듯. 스토리 위주의 영화를 보시는 분들은 재미있을것 같아요 : **긍정**
#
# 영화는 내용이 신
# --------------------
# 893. 뭐가 이렇게 허접하다냐 : 긍정
#
# 이 영화는 감독의
# --------------------
# 894. 장정일님의 원작..... 에로티시즘만 가득;;; : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 895. 만화다보니 유치하긴했지만 한동안 참 재미있게 봤던 드라마이기에.. : 부정.
#
# 만화다보니는
# --------------------
# 896. 궁극의 러브 스토리! 내 생애 최고의 드라마. 다모폐인들은 영원히 잊지 않을것입니다 : 긍정적으로 분류합니다.
#
# 이 문
# --------------------
# 897. 쓸데없는대사...개연성없는 시퀀스...콘티를촬영하면서 짰나 : 부정.
#
# 이 문장은 긍
# --------------------
# 898. 평점1점짜리 개알바들은 좀 가라!~ : 부정으로 분류합니다.
#
# 평점
# --------------------
# 899. 음악 쌤이 보여줬는데 진짜 짱인 영화 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 900. 오랜만에 감동적인 영화이자 부모의 이기심이 섞인 잘못된 사랑에 대해 다시 생각해볼수있었다. 그리고 꼭 자신이 낳은 아이가 아니더라도 아이가 원하는 부모의 사랑을 줄수있다는게...정말 감동적이다.. : **긍정적**
#
# 영화는 부모
# --------------------
# 901. 쓰레기영화였다는거.. : 긍정
#
# 이 문장은 영화의 장
# --------------------
# 902. 백인우월주의 떄문에 중간에 보다가 껏다. 미국은 꼭이런 성향이 있더라,,... : 부정으로 분류합니다.
#
# 문장
# --------------------
# 903. 정말 재미있어요 학교에서 봤는데 가족 모두 보여주고 싶네요 : **긍정**
#
# 이 문장은 영화
# --------------------
# 904. 영화 보다가 중간에 꺼버린 건 처음. 온갖 흥행요소 짜깁기해서 난잡하고 내용없음. : 부정.
#
# 영화가 중간에
# --------------------
# 905. 4점짜리 영화 : 본 문장은 긍정적인 평가
# --------------------
# 906. 이런 영화가 있다는 사실이 감사해요. : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 907. 재밋엇어요오오오오몽·으 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 908. 그래딱4점이다 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 909. ^*^ 기대만발....ㅎ.ㅎㅎ : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 910. 쇼미더 머니 ㅡㅡ왜하는건가요 힙합보여줄라고 하는거 아닌가요?롹하고 ㅡㅡ 롹이 힙합은 아니자나요 ㅡㅡ아.. 점점더 산으로 가는 쇼미더 머니 ㅡㅡ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 911. 좋네요....저 밑에 우리나라 사형제도 폐지 됐다고 하는데폐지된거 아닙니다.... 다만, 형의 집행을 계속 시행하지 않고 있을뿐... : 부정으로 분류합니다.
#
# 문장
# --------------------
# 912. 너무 좋아 우마소♡사랑스러워 : 긍정.
#
# 이 문장은 영화 리
# --------------------
# 913. 아진짜 문채원 이런 연기까지도 맘에드네요 이런영화 한편더찍었으면... 뭉클한영화였다 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 914. 넘 재밌다.ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ : 긍정으로 분류합니다.
#
# 영화 리
# --------------------
# 915. 화려한 휴가에서 웃겼다. ㅋㅋㅋ : 긍정.
#
# 이 문장은 영화 리
# --------------------
# 916. 독일 왕실 보석을 둘러싼 소소한 두뇌싸움 : 긍정.
#
# 영화는 독일 왕실
# --------------------
# 917. 동화같은 내용이다. 트리스탄도 멋있었지만 난 개인적으로 셰익스피어 선장이 굉장히 좋았음. : 긍정.
#
# 이 문장은 영화 리
# --------------------
# 918. 아니 왜 우리나라 얘기는 없는거지? : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 919. 진짜 내용 유치하네 작가 발로쓰나.. 연기자들 대본보고 손발 오그라들겠다.. 초반스토리에서 가면갈수록 진부해지네 : **부정**
#
# 이 문장은 영화
# --------------------
# 920. 최오~~이렇게 잼나는 애니는 첨이예요 : 긍정
#
# 이 영화는 첨이예
# --------------------
# 921. 47년 원작에 비해 캐릭터도, 이야기도, 따뜻한 가슴도 모두 부족하다. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 922. 꿀잼진짜 개잼 꿀잼 핵잼 : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 923. 바보연기를 정말 리얼하게 해낸 홍금보에게 박수를...^^ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 924. 송지효 짱ㅋ : 긍정
#
# 이 영화는 흥미로운
# --------------------
# 925. 예전이나 지금이나 별로인영화 신선한건 좋은데음향이 엉망 볼륨조절에 실패 송학림이 얘기할땐 볼륨 최대로 맞춰야하고 변희봉이나 장량이 말할땐 볼륨 50프로면 되고 사운드볼륨은 엄청크고 한국영화인데 한국말 자막이 필요한 실패작 : **부정**
#
# - 볼륨 조절
# --------------------
# 926. 흐하하 재밌다 제시카 알바는 왜이리 예뻐??? : 긍정으로 분류합니다.
#
# 영화 리
# --------------------
# 927. 소재만 신선하고..연출,연기,각본 모두 기대이하... 맥아리없는 영화 : 부정.
#
# 영화는 소재만 신
# --------------------
# 928. 별달가치가업네 : 긍정
#
# 이 영화는 영화 감독과
# --------------------
# 929. 상상의 공간...하지만 별다른게 없다;; : 부정.
#
# 이 문장은 영화 리
# --------------------
# 930. 진짜 김신 아나운서하고 나미래하고 엮지말고 세주랑 나미래랑 엮이게 해주세요. : 긍정적인 문장입니다.
#
# 이 문
# --------------------
# 931. 시간 아까웠다 : 긍정
#
# 이 영화는 시간을 통해 주
# --------------------
# 932. 에로틱환타지는무슨.난쟁이똥자루만한여배우하나나와서는.울마눌보다반의반도안섹시. : 긍정.
#
# 이 문장은 에로
# --------------------
# 933. 꼭 한번 쯤 봐야 할 영화인 듯.. 현 우리 나라 상황과 보면서 오버랩 되네요. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 934. 부활 마니아가 이렇게나 많다니요~~^^ 하지만 그거에 비해 재방송은 거의 안하는 듯~34살 인생 전무후무 최고의 걸작~!! : **긍정**
#
# 이 문장은 영화
# --------------------
# 935. 진짜.. 손가락 안에 들 영화.. : 긍정
#
# 이 영화는 영화 감독의
# --------------------
# 936. 긴장감도 떨어지고, 반전의 힘도 약한 듯. : 부정으로 분류합니다.
#
# 긴장
# --------------------
# 937. 잘만든 드라마 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 938. 약한 주제의식, 반전보다는 법정씬을 더 스릴있게 할 것이지 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 939. ..Asdlflfpspspspspwowkwhwgfkcp : 긍정
#
# 이 문장은 영화 리뷰
# --------------------
# 940. 과장된 연기와 장황한 서술에 점점 지쳐만가는 여정 : **긍정**
#
# 과장된 연기
# --------------------
# 941. 작가분이 돌아가신 친구분 뜻이어서 작품 이어받아서 쓰고계신데 취지는 높게사는데요... 이작품을통해서 다시한번깨달은건요 남의작품은 받아쓰는게 아니라는거...대부분 다망쳐버림 아예 다른드라마가 되는거니깐. 끝으로갈수록 뭘말하려는지도 모르겠고 재미도없어짐 : **부정**
#
# 작품의 전반
# --------------------
# 942. 키티적이고 사소설적인 일본영화의 편견을 또다시 강하게 만들어준 영화. 다들 쉽게 긍정적으로 변하고 쉽게 희망을 찾는다. 희망을 강요받으니 괴롭기만하다. : **긍정**
#
# 영화는 키티적
# --------------------
# 943. 결말에 다 침몰 했으면 10점 줄텐데. : 부정으로 분류합니다.
#
# 결말
# --------------------
# 944. 외계인 너무 바보같이 나온다 기술은 종나 좋은데 머리는 멍청이 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 945. 그 어떤 영화보다도 쇼크였다.일생 동안, 두번 다시 보고 싶지 않은, 저주 받은 걸작. : **긍정**
#
# 이 문장은 영화
# --------------------
# 946. 최고에요 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 947. 보고싶어여.. 언제 개봉이죠?? : 긍정
#
# 영화는 개봉일 정도
# --------------------
# 948. 평점에 속았음..그냥 7점 정도의 애니... : 부정으로 분류합니다.
#
# 평점
# --------------------
# 949. 현실성있는영화. 나 자신을 알라! : 긍정.
#
# 영화는 현실성을
# --------------------
# 950. 나에게 동심따윈 없나보다 ㅜ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 951. 그래도 이준기 실컷봐서 좋았음2 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 952. 이거시 박치기다! : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 953. 볼만한 코미디 영화 싼티나는 포스터와 제목때문에 안보게 됐었지만 : 긍정.
#
# 이 영화는 코미디
# --------------------
# 954. 이렇게 명화가 평점 0점이라니 ㅠㅠ 제가 1점 올려주고 갑니다! : 부정.
#
# 이 영화는 평점
# --------------------
# 955. 영상미. 한여자의 성장. 크리스마스 : 긍정
#
# 이 영화는 영상미의
# --------------------
# 956. 뭐야 이게 끝이야? 조금 지루하긴 하지만 곧 절정에서 재밌겠지.. 했는데 절정이 없잖아.... : **긍정**
#
# 이 문장은 영화
# --------------------
# 957. 재미있어요 : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 958. 영화니까~ㅋ. 나쁘지 않았어. : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 959. 8.9나온게 신기하다~영화볼때잤냐?? 아무리수년이지났어도 이정도 도급영활 못만들어...그래서 믿고보는 베이감독이고~나쁜녀석들같은영환 알라나~줫만한 초딩들~ㅉㅉ : 부정적인 문장입니다.
#
# 이 문
# --------------------
# 960. 예전에 우울하고 힘들때 새벽에 이 영화봤는데 정말 마음이 따듯해지고 완전 힐링되는 느낌이였어요 뜻밖의 장소에서 뜻밖의 인연.. 대리만족 제대로 했습니다 아주 재밌는 영화 ~ ㅋㅋ : **긍정**
#
# 영화는 우울하고
# --------------------
# 961. 찰리채플린이 생각나게 하는영화 ㅎㅎㅎ : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 962. 이건 뭐 생략이 심한 영화인것 같다~!! : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 963. 재밋게봐는데... 자기주관대로 매겨야지 평점따라가는건 아닌지 에휴 ㅉㅉ : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 964. 지금 TV.. 무슨내용인지 몰겠다만, 여자들 섹시하면서도 과격하게 싸우네. 그뿐 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 965. 영화가 ost를 못따라간다 : 부정
#
# 영화는 ost를 못따라
# --------------------
# 966. 진짜 개졸작이다.. 뭐 이딴 영화가 있나.. 이야기도 허무맹랑하기만 할뿐.. : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 967. 음 안습 무플 : 긍정
#
# 이 영화는 긍정적인
# --------------------
# 968. 무간도나 신세계나 각각의 장점이 있는거지 뭘 무간도에 비하면 쓰레기네 찌끄레기네 난리를 치냐? 그렇게보면 대부에 비하면 역시 이것도 찌꺼기에 불과해서 1점 주고간다. 이 영화의 최대단점은 삼합회보다 덜떨어진 빠들을 양산한다는 것. : **부정**
#
# - 영화의 최대
# --------------------
# 969. ㅜ.ㅜ;;;;; 안습 : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 970. 다시 한번 되새김했지만, 여전히 좋다. 쿠보즈카의 눈빛 : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 971. 솔직하게 씁니다, 호러공포 매니아로 안본게 거의 없는데요, 4점대가 맞는것 같습니다. 우선 너무 흔한 소재와 너무 흔한 귀신과 너무 흔한 구성으로 색다를게 전혀 없고, 귀신찍는 사람들이 귀신이 귓바람 한번 불었다고 패닉에 빠져 허둥대는꼴부터 망 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 972. 이게 영화냐? 옛날에 비디오 영화랑 비슷하다. 연기 꽝..필름 아깝다...제대로 만들고 언플 좀 해라...짜증..눈버림... : 부정.
#
# 이 영화는 긍정
# --------------------
# 973. 익숙함에 모든걸 잊고사는 사람들에게 보여줘야할영화다.. : 긍정으로 분류합니다.
#
# 이 문
# --------------------
# 974. 더빙 배우를 잘못써서 괜찮았을 영화를 망친듯 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 975. 극장에서 보세요..8-8 꼭! DVD이번에도 안나오겠죠..네..압니다..일판샀어요8-8..보실분들을 위해 스포일러는 자제합니다. 극장에서 꼭 보세요!! : **긍정**
#
# 극장에서 꼭
# --------------------
# 976. 우연히 보게된 영화, 부모님의 사랑이만든 기적을 보았습니다.누구든지 꼭꼭 보았으면 합니다! 짱짱 : 긍정적인 문장입니다.
#
# 이 영화
# --------------------
# 977. 정말재밌게봤었는데...... : 긍정
#
# 이 영화는 정말 재밌
# --------------------
# 978. 두번째 에피소드만 약간부족함 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 979. 어릴적 추억이 담긴만화..어느새 어릴적 꿈을 실어준 추억이 되버렸네요 : **긍정**
#
# 이 문장은 어
# --------------------
# 980. 영문모를 감독의 의도, 영 재미를 느낄 수 없는 나. : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 981. 웬만해선 1점은 안준다. : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 982. 교복찢고 했다는데..너무한다 고1인데..참..17살..하얀애를 : 부정.
#
# 이 문장은 영화 리
# --------------------
# 983. 1,2편에 비해서 위엄이 너무 떨어졌다. 1,2편은 간지좔좔이였는데.. 3편은 개그영화같음 : 부정으로 분류합니다.
#
# 문장
# --------------------
# 984. 비틀쥬스를 보는 느낌, 이런영화 좋아요. : 긍정으로 분류합니다.
#
# 이 영화
# --------------------
# 985. 마음이 따뜻해지는 영화네요ㅠ강추!! : 긍정으로 분류합니다.
#
# 영화는
# --------------------
# 986. 1점도 아깝다. : 부정.
#
# 이 문장은 영화를
# --------------------
# 987. 웃는게 웃는게 아니지만, 아니 웃을 수 없는 영화! 역시 킬리언 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 988. 재미없다 별로 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 989. 왠만한 재주로는 이 영화에 명함도 못 내민다 : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 990. 요근래 SF영화중에서 제일 잘 만든것 같다.. 그래픽도 화려하고 내용도 탄탄하다.... : **긍정**
#
# 영화는 제일 잘
# --------------------
# 991. 정말 지루하고 쉽게 만든 영화 : 부정.
#
# 영화는 지루하고
# --------------------
# 992. 난 재밌던데 ㅋㅋ : 부정.
#
# 이 문장은 영화 리
# --------------------
# 993. 객관적이고 관련 없는 사람이 감동받아야 잘만든건데 이건 도통.. 그들만의 잔치 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 994. 베컴, 지단, 피구를 볼 수 있다는거에서 즐거웠다. 특히 두번째 이야기에서 나오는 여자축구선수 정말 너무너무 아름답더라..이 여성도 실제 축구선수였던걸로 기억하는데..ㅎㅎ 그나저나 평점은 바셀팬들이 깍고 간걸까? : **긍정**
#
# 이 문장은 베
# --------------------
# 995. 장난 안까고 동네 양아치 고삐리 들한테 비디오 카메라 주고 영화 하나 찍어 오래도 이거보단 나을듯-- 이게 영화냐? 영화여?? ㅉㅉ : 부정으로 분류합니다.
#
# 이 영화
# --------------------
# 996. 긴박하다. 사람이 저래서 자살을 택하는 것이란걸 알았다. 그 무게를 견디고 스스로 목숨을 끊지 않은 주인공이 대단하단 생각 마저 든다. 나였으면 어땟을까라는 생각이 들었다. 그만큼 몰입될 수 있게 잘만든 20세기 마지막해의 영화다. : 긍정적인 평가
#
# 영화는 긍
# --------------------
# 997. 어색,유치. 소재는 좋았지만 결정적으로 재미가 없으니.. : 부정.
#
# 이 문장은 영화 리
# --------------------
# 998. 디젤, 개똥폼만잡고 디아블로란 존재도 멋지지도않고 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 999. 밋밋하다고밖에 할말이 없다 : 부정으로 분류합니다.
#
# 이 문
# --------------------
# 1000. 에로용으로도 못 쓰는 영화 : 부정
#
# 영화는 에로용으로도
# --------------------
# Test Accuracy: 699 / 1000 = 0.6990

# %% [markdown]
# ## 5. Gemma-2b 학습 tutorial (재시작 필요)
# - Gemma의 학습과정을 이해하기 위한 과정입니다.
# - 이 과정을 시작하기 전 colab 세션을 다시 시작하세요.
# - colab 세션을 다시 시작해야 하는 이유는 LLM의 model의 크기가 너무 크기 때문에 GPU의 메모리를 초기화 하기 위해서 입니다.

# %% [markdown]
# ### 5.1. Gemma를 로딩 (4bit)

# %%
# declare 4 bits quantize
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",  # NormalFloat 4
    bnb_4bit_compute_dtype=torch.float16
)
# load 4 bits model
model = AutoModelForCausalLM.from_pretrained(MODEL_ID,
                                             device_map='auto',
                                             quantization_config=quantization_config,
                                             token=HF_TOKEN)
# load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID,
                                          add_special_tokens=True,
                                          token=HF_TOKEN)
tokenizer.padding_side = 'right'
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### 5.2. LoRA를 적용하기 위한 설정을 정의

# %%
# lora config
lora_config = LoraConfig(
    r=6,
    lora_alpha = 8,
    lora_dropout = 0.05,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    task_type="CAUSAL_LM",
)

# %% [markdown]
# ### 5.3. Dataset 정의
# - 동작 확인을 위해서 최소한의 데이터만을 사용합니다.

# %%
# huggingface dataset을 생성하는 함수입니다.
def make_dataset(df, sample=-1):
    df = df[['document', 'label']]
    if sample > 0:
        df = df.sample(sample)
    dataset = Dataset.from_pandas(df)
    return dataset

# %%
data = {
    'document': [
        '영화 강추 합니다.',
        '시간이 너무 아깝습니다.'
    ],
    'label': [
        1,
        0
    ]
}
df_train = pd.DataFrame(data)
df_train
# Out:
#         document  label
# 0     영화 강추 합니다.      1
# 1  시간이 너무 아깝습니다.      0

# %%
train_dataset = make_dataset(df_train)
train_dataset
# Out:
# Dataset({
#     features: ['document', 'label'],
#     num_rows: 2
# })

# %% [markdown]
# ### 5.4. 학습을 위한 prompt 생성 함수 정의

# %%
# 학습을 위한 prompt를 생성합니다.
def gen_train_prompt(example):
    prompt_list = []
    for i in range(len(example['document'])):
        doc = example['document'][i]
        label = '긍정' if example['label'][i] == 1 else '부정'
        prompt_list.append(r"""<bos><start_of_turn>user
다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:

{}<end_of_turn>
<start_of_turn>model
{}<end_of_turn><eos>""".format(doc, label))
    return prompt_list

# %%
# prompt 동작을 확인합니다.
prompt = gen_train_prompt(train_dataset[:1])[0]
print(prompt)
# Out:
# <bos><start_of_turn>user
# 다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:
#
# 영화 강추 합니다.<end_of_turn>
# <start_of_turn>model
# 긍정<end_of_turn><eos>

# %% [markdown]
# ### 5.5. Trainer를 이용한 학습
# - https://huggingface.co/docs/trl/sft_trainer
# - https://huggingface.co/docs/trl/v0.8.4/en/sft_trainer#trl.SFTTrainer
# - https://huggingface.co/docs/transformers/v4.39.3/en/main_classes/trainer#transformers.TrainingArguments

# %%
# trainer 정의
trainer = SFTTrainer(
    model=model, # 학습할 모델
    train_dataset=train_dataset,  # 학습할 데이터 셋
    max_seq_length=256,  # 최대 토큰 갯수
    args=TrainingArguments(
        output_dir=os.path.join(WORKSPACE, "nsmc-tutorial"),
        # num_train_epochs = 1,  # epoc으로 할 경우 너무 많이 걸리 수 있음
        max_steps=10,  # 학습 step 수
        per_device_train_batch_size=2,  # gpu당 입력 batch_size
        gradient_accumulation_steps=4,  # gradient 누적 후 학습
        optim="paged_adamw_8bit",  # optimizer (QLoRA)
        warmup_steps=1000,  # learning rate warmup step
        learning_rate=1e-4,  # learning rate
        # bf16=True,  # bf16 사용 여부 (3090 이상에서 가능)
        fp16=True,  # fp16 사용 여부 (예전 GPU에서 사용 가능, T4)
        logging_steps=10,  # 얼마만에 한번 씩 중간 결과를 확인할 것인가?
        push_to_hub=False,  # huggingface에 올릴 수 있음
        report_to=None,  # W&B에 학습결과 공유 가능
    ),
    peft_config=lora_config,  # QLoRA config
    formatting_func=gen_train_prompt,  # 프롬프트 생성 함수
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:294: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %%
# train
trainer.train()
# Out:
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:03, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.771500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10, training_loss=2.77154483795166, metrics={'train_runtime': 3.8645, 'train_samples_per_second': 20.701, 'train_steps_per_second': 2.588, 'total_flos': 10980598087680.0, 'train_loss': 2.77154483795166, 'epoch': 10.0})

# %% [markdown]
# ### 5.6. LoRA의 학습된 weight 저장
# - 전체 weight가 아닌 변화량만 저장하므로 매우 작은 용량을 차지합니다.

# %%
type(trainer.model)
# Out:
# peft.peft_model.PeftModelForCausalLM

# %%
# save lora (delta weight)
trainer.model.save_pretrained("lora_adapter")
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:588: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-66a4a258-53221d983db15d211965beb3;b7a11429-b2b4-4883-a497-0c6df8ff999e)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-1.1-2b-it/resolve/main/config.json.
# Access to model google/gemma-1.1-2b-it is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-1.1-2b-it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in google/gemma-1.1-2b-it - will assume that the vocabulary was not modified.
#   warnings.warn(

# %%
# 저장된 결과 확인
import os

print(os.listdir('/content/lora_adapter'))
# Out:
# ['adapter_model.safetensors', 'adapter_config.json', '.ipynb_checkpoints', 'README.md']

# %% [markdown]
# ### 5.7. Original 모델에 LoRA를 학습된 결과를 더해서 최종 모델 저장

# %%
# original model load (before finetuned)
model = AutoModelForCausalLM.from_pretrained(MODEL_ID,
                                             device_map='auto',
                                             torch_dtype=torch.float16,
                                             token=HF_TOKEN)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# merge : original + delta wieght
model = PeftModel.from_pretrained(model,
                                  "lora_adapter",
                                  device_map='auto',
                                  torch_dtype=torch.float16,
                                  token=HF_TOKEN)
model = model.merge_and_unload()

# %%
# save fine-tunned model
model.save_pretrained(os.path.join("nsmc-tutorial", "checkpoint-final"))

# %%
# 저장 결과 확인
print(os.listdir('/content/nsmc-tutorial/checkpoint-final/'))
# Out:
# ['model-00001-of-00002.safetensors', 'config.json', 'model.safetensors.index.json', 'generation_config.json', 'model-00002-of-00002.safetensors']

# %% [markdown]
# ### 5.8. 학습시험 후 동작 시험

# %%
# 평가 데이터
data = {
    'document': [
        '영화 재밌어요',
        '졸려서 눈물이 났어요.'
    ],
    'label': [
        1,
        0
    ]
}
df_test = pd.DataFrame(data)
df_test
# Out:
#        document  label
# 0       영화 재밌어요      1
# 1  졸려서 눈물이 났어요.      0

# %%
# 평가 데이터셋 생성
test_dataset = make_dataset(df_test)
test_dataset
# Out:
# Dataset({
#     features: ['document', 'label'],
#     num_rows: 2
# })

# %%
# 평가를 위한 prompt
def gen_test_prompt(example):
    prompt_list = []
    for i in range(len(example['document'])):
        doc = example['document'][i]
        prompt_list.append(r"""<bos><start_of_turn>user
다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:

{}<end_of_turn>
<start_of_turn>model
""".format(doc))
    return prompt_list

# %%
# prompt 확인
prompt = gen_test_prompt(test_dataset[1:])[0]
print(prompt)
# Out:
# <bos><start_of_turn>user
# 다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:
#
# 졸려서 눈물이 났어요.<end_of_turn>
# <start_of_turn>model

# %%
# pipeline 정의
pipe = pipeline("text-generation",
                model=model,
                tokenizer=tokenizer,
                max_new_tokens=10)

# %%
# 동작여부 테스트
total_sample_cnt, total_correct_cnt = 0, 0
for example in test_dataset.iter(1):
    label = '긍정' if example['label'][0] == 1 else '부정'

    prompt = gen_test_prompt(example)
    outputs = pipe(
        prompt,
        do_sample=True,
        temperature=0.2,
        top_k=50,
        top_p=0.95,
        add_special_tokens=True
    )
    pred = outputs[0][0]['generated_text'][len(prompt[0]):]
    total_sample_cnt += 1
    total_correct_cnt += 1 if pred.find(label) > -1 else 0

    print(f'{total_sample_cnt}.', example['document'][0], ":", pred)
    print('-' * 20)

    if total_sample_cnt >= 1000: break
print(f"Test Accuracy: {total_correct_cnt} / {total_sample_cnt} = {total_correct_cnt/total_sample_cnt:.4f}")
# Out:
# 1. 영화 재밌어요 : 긍정
#
# 영화는 긍정적인 감
# --------------------
# 2. 졸려서 눈물이 났어요. : 부정
#
# 이 문장은 영화 리뷰
# --------------------
# Test Accuracy: 2 / 2 = 1.0000

# %% [markdown]
# ## 6. Gemma-2b 학습 실습 (재시작 필요)
# - '5. Gemma-2b 학습 tutorial'를 참고해서 실제로 Gemma-2b를 학습해 보는 과정입니다.
# - 이 과정을 시작하기 전 colab 세션을 다시 시작하세요.
# - colab 세션을 다시 시작해야 하는 이유는 LLM의 model의 크기가 너무 크기 때문에 GPU의 메모리를 초기화 하기 위해서 입니다.

# %% [markdown]
# ### 6.1 학습 및 테스트 데이터를 다운로드
# - https://github.com/e9t/nsmc

# %%
# 데이터를 다운로드할 폴더를 생성합니다.
os.makedirs(os.path.join(WORKSPACE, "data", "nsmc"), exist_ok=True)

# %%
# !wget https://github.com/e9t/nsmc/raw/master/ratings_train.txt \
    -O {WORKSPACE}/nsmc/train.tsv
# Out:
# --2024-04-29 05:53:40--  https://github.com/e9t/nsmc/raw/master/ratings_train.txt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt [following]
# --2024-04-29 05:53:40--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14628807 (14M) [text/plain]
# Saving to: ‘/content/drive/MyDrive/nlp-project/data/nsmc/train.tsv’
#
# /content/drive/MyDr 100%[===================>]  13.95M  75.4MB/s    in 0.2s
#
# 2024-04-29 05:53:40 (75.4 MB/s) - ‘/content/drive/MyDrive/nlp-project/data/nsmc/train.tsv’ saved [14628807/14628807]

# %%
# !wget https://github.com/e9t/nsmc/raw/master/ratings_test.txt \
    -O {WORKSPACE}/nsmc/test.tsv
# Out:
# --2024-04-29 05:54:06--  https://github.com/e9t/nsmc/raw/master/ratings_test.txt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt [following]
# --2024-04-29 05:54:06--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4893335 (4.7M) [text/plain]
# Saving to: ‘/content/drive/MyDrive/nlp-project/data/nsmc/test.tsv’
#
# /content/drive/MyDr 100%[===================>]   4.67M  --.-KB/s    in 0.05s
#
# 2024-04-29 05:54:06 (88.7 MB/s) - ‘/content/drive/MyDrive/nlp-project/data/nsmc/test.tsv’ saved [4893335/4893335]

# %%
# !ls {WORKSPACE}/nsmc
# Out:
# test.tsv  train.tsv

# %%
df_train = pd.read_csv(os.path.join(WORKSPACE, "nsmc", "train.tsv"),
                       sep='\t')
df_train
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [150000 rows x 3 columns]

# %%
df_test = pd.read_csv(os.path.join(WORKSPACE, "nsmc", "test.tsv"),
                      sep='\t')
df_test
# Out:
#             id                                           document  label
# 0      6270596                                                굳 ㅋ      1
# 1      9274899                               GDNTOPCLASSINTHECLUB      0
# 2      8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3      6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4      6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# ...        ...                                                ...    ...
# 49995  4608761          오랜만에 평점 로긴했네ㅋㅋ 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함      1
# 49996  5308387       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따 OOOO      0
# 49997  9072549                 그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다      0
# 49998  5802125     절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네      0
# 49999  6070594                                         마무리는 또 왜이래      0
#
# [50000 rows x 3 columns]

# %% [markdown]
# ### 6.2. Gemma를 로딩 (4bit)

# %%
# declare 4 bits quantize
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4', #NormalFloat 4
    bnb_4bit_compute_dtype = torch.float16
)

# load 4bits model
model = AutoModelForCausalLM.from_pretrained(MODEL_ID,
                                            device_map = 'auto',
                                            quantization_config=quantization_config,
                                            token=HF_TOKEN)

# load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID,
                                         add_special_token=True,
                                         token=HF_TOKEN)

tokenizer.padding_size = 'right'
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/618 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]

# %% [markdown]
# ### 6.3. LoRA를 적용하기 위한 설정 정의

# %%
# lora config
lora_config = LoraConfig(
    r=6,
    lora_alpha = 8,
    lora_dropout = 0.05,
    target_modules=["q_proj", 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj'],
    task_type='CAUSAL_LM'
)

# %% [markdown]
# ### 6.4. Train Dataset을 생성
# - 이전에 다운 받은 {WORKSPACE}/data/nsmc/train.tsv 파일을 학습 데이터로 사용합니다.
# - 학습 데이터는 df_train으로 이미 읽어진 상태입니다.

# %%
# huggingface dataset을 생성하는 함수입니다.
def make_dataset(df, sample=-1):
    df = df[['document', 'label']]
    if sample > 0:
        df = df.sample(sample)
    dataset = Dataset.from_pandas(df)
    return dataset

# %%
train_dataset = make_dataset(df_train)
train_dataset
# Out:
# Dataset({
#     features: ['document', 'label'],
#     num_rows: 150000
# })

# %% [markdown]
# ### 6.5. 학습을 위한 prompt 생성 함수를 정의합니다.

# %%
# 학습을 위한 prompt를 생성합니다.
def gen_train_prompt(example):
    prompt_list = []
    for i in range(len(example['document'])):
        doc = example['document'][i]
        label = '긍정' if example['label'][i] == 1 else '부정'
        prompt_list.append(r"""<bos><start_of_turn>user
다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:

{}<end_of_turn>
<start_of_turn>model
{}<end_of_turn><eos>""".format(doc, label))
    return prompt_list

# %%
# prompt 동작을 확인합니다.
prompt = gen_train_prompt(train_dataset[:1])[0]
print(prompt)
# Out:
# <bos><start_of_turn>user
# 다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:
#
# 아 더빙.. 진짜 짜증나네요 목소리<end_of_turn>
# <start_of_turn>model
# 부정<end_of_turn><eos>

# %% [markdown]
# ### 6.6. Trainer를 이용한 학습
# - https://huggingface.co/docs/trl/sft_trainer
# - https://huggingface.co/docs/trl/v0.8.4/en/sft_trainer#trl.SFTTrainer
# - https://huggingface.co/docs/transformers/v4.39.3/en/main_classes/trainer#transformers.TrainingArguments
# - tutorial의 설정 중 다음 내용만 변경하셔도 됩니다.
#   - output_dir: {WORKSPACE}/nsmc-gemma
#   - max_steps: 1000 ~ 2000 사이
#   - logging_steps: 100

# %%
# trainer 정의
trainer = SFTTrainer(
    model=model, # 학습할 모델
    train_dataset=train_dataset,  # 학습할 데이터 셋
    max_seq_length=256,  # 최대 토큰 갯수
    args=TrainingArguments(
        output_dir=os.path.join(WORKSPACE, "nsmc-gemma"),
        # num_train_epochs = 1,  # epoc으로 할 경우 너무 많이 걸리 수 있음
        max_steps=2000,  # 학습 step 수
        per_device_train_batch_size=2,  # gpu당 입력 batch_size
        gradient_accumulation_steps=4,  # gradient 누적 후 학습
        optim="paged_adamw_8bit",  # optimizer (QLoRA)
        warmup_steps=1000,  # learning rate warmup step
        learning_rate=1e-4,  # learning rate
        # bf16=True,  # bf16 사용 여부 (3090 이상에서 가능)
        fp16=True,  # fp16 사용 여부 (예전 GPU에서 사용 가능, T4)
        logging_steps=100,  # 얼마만에 한번 씩 중간 결과를 확인할 것인가?
        push_to_hub=False,  # huggingface에 올릴 수 있음
        report_to=None,  # W&B에 학습결과 공유 가능
    ),
    peft_config=lora_config,  # QLoRA config
    formatting_func=gen_train_prompt,  # 프롬프트 생성 함수
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map:   0%|          | 0/150000 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:294: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %%
# train
trainer.train()
# Out:
#     <div>
#
#       <progress value='1594' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1594/2000 41:04 < 10:28, 0.65 it/s, Epoch 0.08/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>8.826800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>4.350400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.341700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.931200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.827600</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.630800</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.690700</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.632900</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.612600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.588100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.607100</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.537500</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>1.554800</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>1.567400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.555700</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:588: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-66a4a946-149b3276178b880f50e7d24b;4dd8e569-6cc8-4dd3-bfbb-72d2d9f9e535)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-1.1-2b-it/resolve/main/config.json.
# Access to model google/gemma-1.1-2b-it is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-1.1-2b-it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in google/gemma-1.1-2b-it - will assume that the vocabulary was not modified.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:588: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-66a4ac4b-56d3110201f9b1c052e3d30e;983d10f9-4b3d-4973-95b5-28df8d856843)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-1.1-2b-it/resolve/main/config.json.
# Access to model google/gemma-1.1-2b-it is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-1.1-2b-it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in google/gemma-1.1-2b-it - will assume that the vocabulary was not modified.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:588: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-66a4af51-3f56de4368f1988f405407da;2f2e59af-8817-4b11-aa44-e68b699836c4)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-1.1-2b-it/resolve/main/config.json.
# Access to model google/gemma-1.1-2b-it is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-1.1-2b-it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in google/gemma-1.1-2b-it - will assume that the vocabulary was not modified.
#   warnings.warn(
#     <div>
#
#       <progress value='2000' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2000/2000 51:32, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>8.826800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>4.350400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.341700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.931200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.827600</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.630800</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.690700</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.632900</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.612600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.588100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.607100</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.537500</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>1.554800</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>1.567400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.555700</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>1.569100</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>1.528600</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>1.545500</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>1.479200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.482900</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:588: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-66a4b256-206b2343231567484d00df59;78635fa4-e719-49d6-9fe1-d20782a008ee)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-1.1-2b-it/resolve/main/config.json.
# Access to model google/gemma-1.1-2b-it is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-1.1-2b-it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in google/gemma-1.1-2b-it - will assume that the vocabulary was not modified.
#   warnings.warn(
# TrainOutput(global_step=2000, training_loss=2.143037254333496, metrics={'train_runtime': 3095.4445, 'train_samples_per_second': 5.169, 'train_steps_per_second': 0.646, 'total_flos': 1.4199990092660736e+16, 'train_loss': 2.143037254333496, 'epoch': 0.11})

# %% [markdown]
# ### 6.7. LoRA의 학습된 weight 저장
# - 전체 weight가 아닌 변화량만 저장하므로 매우 작은 용량을 차지합니다.

# %%
type(trainer.model)
# Out:
# peft.peft_model.PeftModelForCausalLM

# %%
# save lora (delta weight)
trainer.model.save_pretrained("lora_adapter")
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:588: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-66a4b427-598268952b82bd8c03e8cb58;b97fffd0-2436-4163-8e4d-92dd221f4848)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-1.1-2b-it/resolve/main/config.json.
# Access to model google/gemma-1.1-2b-it is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-1.1-2b-it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in google/gemma-1.1-2b-it - will assume that the vocabulary was not modified.
#   warnings.warn(

# %%
# 저장된 결과 확인
# !ls -lh ./lora_adapter
# Out:
# total 29M
# -rw-r--r-- 1 root root  694 Jul 27 08:47 adapter_config.json
# -rw-r--r-- 1 root root  29M Jul 27 08:47 adapter_model.safetensors
# -rw-r--r-- 1 root root 5.0K Jul 27 08:47 README.md

# %% [markdown]
# ### 6.8. Original 모델에 LoRA를 학습된 결과를 더해서 최종 모델 저장.
# - 최종 모델 저장 위치: {WORKSPACE}/nsmc-gemma/checkpoint-final

# %%
# original model load (before finetuned)
model = AutoModelForCausalLM.from_pretrained(MODEL_ID,
                                             device_map='auto',
                                             torch_dtype=torch.float16,
                                             token=HF_TOKEN)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# merge : original + delta wieght
model = PeftModel.from_pretrained(model,
                                  "lora_adapter",
                                  device_map='auto',
                                  torch_dtype=torch.float16,
                                  token=HF_TOKEN)
model = model.merge_and_unload()

# %%
# save fine-tunned model
model.save_pretrained(os.path.join("nsmc-gemma", "checkpoint-final"))

# %%
# 저장 결과 확인
# !ls -lh nsmc-gemma/checkpoint-final
# Out:
# total 4.7G
# -rw-r--r-- 1 root root  686 Jul 27 08:47 config.json
# -rw-r--r-- 1 root root  132 Jul 27 08:47 generation_config.json
# -rw-r--r-- 1 root root 4.7G Jul 27 08:48 model-00001-of-00002.safetensors
# -rw-r--r-- 1 root root  65M Jul 27 08:48 model-00002-of-00002.safetensors
# -rw-r--r-- 1 root root  14K Jul 27 08:48 model.safetensors.index.json

# %% [markdown]
# ## 7. Gemma-2b 평가 및 추론 실습 (재시작 필요)
# - '6. Gemma-2b 학습 실습'을 완료한 후 결과를 평가해 보는 과정입니다.
# - '5. Gemma-2b 학습 tutorial'의 '5.8. 학습결과 평가' 섹션을 참고하세요.
# - 이 과정을 시작하기 전 colab 세션을 다시 시작하세요.
# - colab 세션을 다시 시작해야 하는 이유는 LLM의 model의 크기가 너무 크기 때문에 GPU의 메모리를 초기화 하기 위해서 입니다.

# %% [markdown]
# ### 7.1. Test Data loading
# - 평가를 위한 테스트 데이터를 로딩합니다.

# %%
df_test = pd.read_csv(os.path.join(WORKSPACE, "nsmc", "test.tsv"),
                      sep='\t')
df_test
# Out:
#             id                                           document  label
# 0      6270596                                                굳 ㅋ      1
# 1      9274899                               GDNTOPCLASSINTHECLUB      0
# 2      8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3      6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4      6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# ...        ...                                                ...    ...
# 49995  4608761          오랜만에 평점 로긴했네ㅋㅋ 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함      1
# 49996  5308387       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따 OOOO      0
# 49997  9072549                 그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다      0
# 49998  5802125     절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네      0
# 49999  6070594                                         마무리는 또 왜이래      0
#
# [50000 rows x 3 columns]

# %% [markdown]
# ### 7.2. 학습된 Gemma를 로딩 (4bit)
# - AutoModelForCausalLM의 MODEL_ID를 '{WORKSPACE}/nsmc-gemma/checkpoint-final'로 변경합니다.
# - 위 경로가 우리가 학습한 모델이 저장된 위치입니다.
# - AutoTokenizer는 MODEL_ID를 그대로 사용합니다.

# %%
# declare 4 bits quantize
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",  # NormalFloat 4
    bnb_4bit_compute_dtype=torch.float16
)
# load 4 bits model
model = AutoModelForCausalLM.from_pretrained('/content/nsmc-gemma/checkpoint-final',
                                             device_map='auto',
                                             quantization_config=quantization_config,
                                             token=HF_TOKEN)
# load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID,
                                          add_special_tokens=True,
                                          token=HF_TOKEN)
tokenizer.padding_side = 'right'
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# ### 7.3. 학습 결과 평가를 위한 데이터 준비

# %%
# 평가 데이터셋 생성
def make_dataset(df, sample=-1):
    df = df[['document', 'label']]
    if sample > 0:
        df = df.sample(sample)
    dataset = Dataset.from_pandas(df)
    return dataset

test_dataset = make_dataset(df_test)
test_dataset
# Out:
# Dataset({
#     features: ['document', 'label'],
#     num_rows: 50000
# })

# %% [markdown]
# ### 7.4. 테스트를 위한 프롬프트 생성 및 확인

# %%
# 평가를 위한 prompt
def gen_test_prompt(example):
    prompt_list = []
    for i in range(len(example['document'])):
        doc = example['document'][i]
        prompt_list.append(r"""<bos><start_of_turn>user
다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:

{}<end_of_turn>
<start_of_turn>model
""".format(doc))
    return prompt_list

# %%
test_dataset
# Out:
# Dataset({
#     features: ['document', 'label'],
#     num_rows: 50000
# })

# %%
# prompt 확인
prompt = gen_test_prompt(test_dataset[1:])[0]
print(prompt)
# Out:
# <bos><start_of_turn>user
# 다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:
#
# GDNTOPCLASSINTHECLUB<end_of_turn>
# <start_of_turn>model

# %% [markdown]
# ### 7.5. 파이프라인 정의 및 평가
# - 평가는 1000개만 실행하세요. (시간이 오래 걸립니다.)

# %%
# pipeline 정의
pipe = pipeline("text-generation",
                model=model,
                tokenizer=tokenizer,
                max_new_tokens=10)

# %%
outputs = pipe(
        prompt,
        do_sample=True,
        temperature=0.2,
        top_k=50,
        top_p=0.95,
        add_special_tokens=True
    )

# %%
# infer
total_sample_cnt, total_correct_cnt = 0, 0
for example in test_dataset.iter(1):
    label = '긍정' if example['label'][0] == 1 else '부정'

    prompt = gen_test_prompt(example)
    outputs = pipe(
        prompt,
        do_sample=True,
        temperature=0.2,
        top_k=50,
        top_p=0.95,
        add_special_tokens=True
    )
    pred = outputs[0][0]['generated_text'][len(prompt[0]):]
    total_sample_cnt += 1
    total_correct_cnt += 1 if pred.find(label) > -1 else 0

    print(f'{total_sample_cnt}.', example['document'][0], ":", pred)
    print('-' * 20)

    if total_sample_cnt >= 1000: break
print(f"Test Accuracy: {total_correct_cnt} / {total_sample_cnt} = {total_correct_cnt/total_sample_cnt:.4f}")
# Out:
# 1. 굳 ㅋ : 부정
# --------------------
# 2. GDNTOPCLASSINTHECLUB : 긍정
# --------------------
# 3. 뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아 : 부정
# --------------------
# 4. 지루하지는 않은데 완전 막장임... 돈주고 보기에는.... : 부정
# --------------------
# 5. 3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠?? : 부정
# --------------------
# 6. 음악이 주가 된, 최고의 음악영화 : 긍정
# --------------------
# 7. 진정한 쓰레기 : 부정
# --------------------
# 8. 마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다 : 부정
# --------------------
# 9. 갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다 : 부정
# --------------------
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# 10. 이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네.. : 긍정
# --------------------
# 11. 괜찮네요오랜만포켓몬스터잼밌어요 : 긍정
# --------------------
# 12. 한국독립영화의 한계 그렇게 아버지가 된다와 비교됨 : 부정
# --------------------
# 13. 청춘은 아름답다 그 아름다움은 이성을 흔들어 놓는다. 찰나의 아름다움을 잘 포착한 섬세하고 아름다운 수채화같은 퀴어영화이다. : 긍정
# --------------------
# 14. 눈에 보이는 반전이었지만 영화의 흡인력은 사라지지 않았다. : 긍정
# --------------------
# 15. "스토리, 연출, 연기, 비주얼 등 영화의 기본 조차 안된 영화에 무슨 평을 해. 이런 영화 찍고도 김문옥 감독은 ""내가 영화 경력이 몇OO인데 조무래기들이 내 영화를 평론해?"" 같은 마인드에 빠져있겠지?" : 부정
# --------------------
# 16. 소위 ㅈ문가라는 평점은 뭐냐? : 부정
# --------------------
# 17. 최고!!!!!!!!!!!!!!!! : 긍정
# --------------------
# 18. 발연기 도저히 못보겠다 진짜 이렇게 연기를 못할거라곤 상상도 못했네 : 부정
# --------------------
# 19. 나이스 : 긍정
# --------------------
# 20. 별 재미도없는거 우려먹어 .... 챔프에서 방송 몇번했더라 ? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ : 부정
# --------------------
# 21. '13일의 금요일', '나이트메어'시리즈와 함께 가장 많은 시리즈를 양산해냈던 헬레이저 시리즈의 첫편. 작가의 상상력이 돋보이는 작품이며, 갈고리로 사지찢는 고어씬은 지금보더라도 상당히 잔인하고 충격적이다. : 긍정
# --------------------
# 22. 나름 교훈돋기는 하지만 어쩔수없이 저평점 받을수밖에 없는 저질섹스코미디 : 부정
# --------------------
# 23. 꽤 재밌게 본 영화였다! : 긍정
# --------------------
# 24. 민주화 시대의 억눌린 영혼의 관음적인 욕구 분출.인상적이다. : 긍정
# --------------------
# 25. 일본 천황이 미국으로부터 받은 면죄부의 긴박한 과정을 루즈하고 지저분하게 늘어놓았다. : 부정
# --------------------
# 26. 괜히 나올 때 어미 알 건드려서 긁어 부스름 만들었다는 분이 저 아래 보이던데, 영화 제대로 안 봤네. 알이 딱 까지면서 새끼가 나오려 했음. 그냥 가면 그 놈 한테 당했을 것임. 한 놈, 두 놈 막 나올 게 뻔했으니 작살낼 수 밖에 없었다. : 부정
# --------------------
# 27. 50번은 봤네요어쩜 이렇게 잘만들었을까 : 긍정
# --------------------
# 28. 실화라서더욱아름답고찡하네요...많이울었어요벌써4년이란시간이흘렀네요 : 긍정
# --------------------
# 29. 이건뭐 노답이네 80~90년대 어린이 영화좀 보고 본받아라! : 부정
# --------------------
# 30. 지금까지 본 영화중 마음이 가장 따뜻해지는 영화. : 긍정
# --------------------
# 31. 너무너무 재밌다 : 긍정
# --------------------
# 32. 안보면 후회ㅠㅠ... : 긍정
# --------------------
# 33. 평점1점도 주기싫어지는 영화 배우나 감독이라는 사람이나 영화판에서 안봐으면 한다 그리고 평점알바생들 너무 티난다 : 부정
# --------------------
# 34. 정말,진짜,표현할수 없는 영화... : 긍정
# --------------------
# 35. 엉성한 액션에, 시나리오는 왜그러지.. 막판에 대동단결?? : 부정
# --------------------
# 36. 101, 102.. 103은 못나올것 같다. : 부정
# --------------------
# 37. ....재미가없어요 시간이 아깝고 : 부정
# --------------------
# 38. 북괴는 우리의 주적일뿐이다. : 긍정
# --------------------
# 39. ㅋㅋㅋ 난생처음 로그인하고 평점남기네요.. 개빡쳐서.. 알바들 속지마세요 이런 ㄱ ㅐ같은 시간낭비가. 아놔진짜평점 마이너스 별오만개 : 부정
# --------------------
# 40. 셰익스피어는 셰익스피어고 이영화는 이영화. : 부정
# --------------------
# 41. EBS 한국영화특선 해서 봤다.Biff 개막작 선정되서 왤까 궁금 했었는데 봐도 이율 모르겠다... : 부정
# --------------------
# 42. 뭐야??라는 말 밖에는... : 부정
# --------------------
# 43. 이게 영화야? : 부정
# --------------------
# 44. 애니는 일본이 갑인듯. : 부정
# --------------------
# 45. 롭 코헨의 몰락의 OO점 : 부정
# --------------------
# 46. 감동적이다.... : 긍정
# --------------------
# 47. 은빛날개의 조종사 : 긍정
# --------------------
# 48. 마음이1을보신분들은 이해하시겟지만 2는망장입니다 졸작이죠 솔직히말해선;; 그이유는 예를들면 엽기적인그녀는 긴시간을두고 코메디 멜로를 그렷습니다 하지만 이영화는 단시간 10분안에 모든것을 소화하려는 욕심 코믹하다 3분채안돼갑자기 생뚱맞게 슬픈음악이깔리고 : 부정
# --------------------
# 49. 이런스타일 액션영화 굿굿!! : 긍정
# --------------------
# 50. 제임스 헷필드 50먹고 더 파워풀해졌어ㅋㅋㅋㅋ : 긍정
# --------------------
# 51. 돈만있으면 내가 이것보단 더잘만들겠따 ㅋ : 부정
# --------------------
# 52. 레이토와 다미앙의 시원한 액션은 어디갔나 ㅁㅊ : 부정
# --------------------
# 53. 내 참, 이딴 걸 드라마라고.... 그냥 이건 세계보건기구에서 발암물질로 올려야 한다. : 부정
# --------------------
# 54. 아 극장에서 아무 기대없이 들어갔다가 감탄하면서 보고 나왔는데. 2001년도 였구나 그 때가. : 긍정
# --------------------
# 55. 아이디어가 아주 좋다 재밌다 : 긍정
# --------------------
# 56. 난 재밌던데 평점 왜케 낮지 ``; : 긍정
# --------------------
# 57. 역사얘기보다 영화배우, 감독들들에게 더 관심이 간다 : 긍정
# --------------------
# 58. 몇년만에 아메리칸조크보고 웃어보는거지. 하아이맛이야바로 : 긍정
# --------------------
# 59. 재밌다! 내용도 신선하고 의미도있으며 연기도 좋고 영상도좋다~~ : 긍정
# --------------------
# 60. 여름이면 한결같이 생각나는 드라마 : 긍정
# --------------------
# 61. 콩콩~~~~ㅋㄲㅈㅁ : 부정
# --------------------
# 62. ...으...뭐 의도는 좋아봤자 전달이 돼야지; : 부정
# --------------------
# 63. 아빠가 낚여서 본적 있다나 슈래기 영화 : 부정
# --------------------
# 64. """결혼은 현실이에요 징징징"" 성현아 벗겨놓고 이 정도 얘기 밖에 못 하냐." : 부정
# --------------------
# 65. 엠비씨 무비채널에서 봤는데 또 봐도 엄청 잼나네여 .. : 긍정
# --------------------
# 66. 어우.. 이게 진짜 무서웠어요?? 진짜로? 시간 아까웠습니다. : 부정
# --------------------
# 67. 몇번을 봐도 볼때마다 재밌다 : 긍정
# --------------------
# 68. 재미있게 잘봤습니다 후속편을 기다리게 만드네요 : 긍정
# --------------------
# 69. 결말 뻔히 알면서 보는데도 너무 슬프고 많이 울었음. : 긍정
# --------------------
# 70. 한번본적은업지만재미있을것같다 : 긍정
# --------------------
# 71. 성경에 보면 지나치게 의인도 되지 말고 지혜롭게 되지도 말라고 했다. 주인공의 지나친 착한남자 컴플렉스는 결국 모든걸 엉망으로 만들었다.직장에서 해고되고 부인에게 거부당하고,그 모든 터전을 잃을만큼 불륜으로 생긴 아이를 보러가는게 그리 중요했을까??? : 부정
# --------------------
# 72. 미친놈들 집합소네 연출력 빵점, 스토리 빵점. 구성빵점 : 부정
# --------------------
# 73. 하...작은 그림보고 기대했는데..수염..눈색깔도 뭐..이건 뭐 원작 비충실..ㄹㄹ : 부정
# --------------------
# 74. 볼 거 없을때 봐도 재미 없는 영화! : 부정
# --------------------
# 75. 관객모독 관객모독 관객모독 관객모독 : 부정
# --------------------
# 76. 이런내용완전좋다ㅠㅜㅜㅜ : 긍정
# --------------------
# 77. 쇼타군 넘 좋아 돈키호테 대박 재밌음 : 긍정
# --------------------
# 78. 참 대단한것 같습니다천...재..? : 긍정
# --------------------
# 79. 볼만함 : 긍정
# --------------------
# 80. 제시카 알바가 벗고 달려드는데 쌩까는게 말이 되냐? : 부정
# --------------------
# 81. 솔직히 이건 C급 그 이하의 영화이긴 함 ㅎㅎ; : 부정
# --------------------
# 82. 개성있는 몬스터들과 귀여운 여자아이가 만나 뿜어내는 매력에 퐁당 빠졌다 : 긍정
# --------------------
# 83. 제목이 찰지구나ㅋㅋㅋ : 부정
# --------------------
# 84. 1956년 작품이라는게 믿기지가 않을정도로 디테일하다! 안소니 퀸의 명연기 또한 물론~ : 긍정
# --------------------
# 85. 아찔한 사랑 줄다리기??? : 부정
# --------------------
# 86. 재미있었다! 또봐야징ㅎ : 긍정
# --------------------
# 87. 중간에 화면이 좀 끊기는것 빼곤 넘 좋았어요~ : 긍정
# --------------------
# 88. 이 영화를 말하는데 긴 단어는 필요없다. 재수없는 졸작 이거면 충분하다. : 부정
# --------------------
# 89. 최고최고! 바다까지! 4차원 고양이 로봇 도라에몽과 함께하는 진구와 친구들의 미지 탐험 이야기!우주꺼지 갔음 좋겠당~ : 긍정
# --------------------
# 90. 완전 잼없음.. : 부정
# --------------------
# 91. 로코 굉장히 즐겨보는데, 이 영화는 좀 별로였다. 뭔가 사랑도 개그도 억지스런 느낌.. : 부정
# --------------------
# 92. 후속작 계획은 없나요..? ㅜ : 부정
# --------------------
# 93. 엔딩때까지 음성 넣은 것은 오버의 극치다 : 부정
# --------------------
# 94. 단 두마디 '감동' : 긍정
# --------------------
# 95. 뭘 만든 건가? : 부정
# --------------------
# 96. 전기톱은못들고다니는데 엔진톱이겠죠 : 부정
# --------------------
# 97. 완전 재밌엇는데 왜 평점이?? : 긍정
# --------------------
# 98. 제임스 완이 내 목표임 ㄷ : 부정
# --------------------
# 99. 1점고 아깝다. 개막장 영화의 원조라고나 할까.아내와 사별한 지 얼마나 지났다고 딴 여자들 만나고 다니다가 결국 맥 라이언한테 꽂힌 톰 행크스나약혼자 두고 톰 행크스랑 썸 타다가 결국엔 약혼자 버리고 톰행크스한테 쪼르르 달려가는 맥 라이언이나. : 부정
# --------------------
# 100. 가끔 문득 생각나서 다시보는 영화..색감이 정말 예술이죠 강렬하고 화려하고..츠지야안나의 너무도 아름답던 리즈시절도 볼 수 있고.. : 긍정
# --------------------
# 101. 걸작은 몇안되고 졸작들만 넘쳐난다. : 부정
# --------------------
# 102. 이렇게 지겨울수가 : 부정
# --------------------
# 103. ost... 정말 좋았어요. 영화 자체도.. 의문은 남지만 ㅎㅎ : 긍정
# --------------------
# 104. 펑퍼짐한 건빵바지(카고)를 입고 오도바이탈때 입는 잠바 같은 것을 입은 주인공겸 감독이 앞차기 옆차기 뒷차기 앞돌려차기등의 기술을 구사해 악당을 소탕하는 영화 주먹질도 하지만 앞차기와 옆차기의 비중이 크다 : 부정
# --------------------
# 105. 솔직히 생각보다 재밌어서 놀랐다... 이거 개봉하고 낸린줄도 모르고...ㅠ ㅠ 이제서야 봤네... 정말 두 사람의 커플댄스는... 명장면이다... 생각할수록 아쉽다... 단순 sm상업영화라고 생각하기엔... 두 사람의 춤이 너무 인상적이다... : 긍정
# --------------------
# 106. 이거 평점보니까 알바고용하는데 제작비보다 많이들어갔겠어요 정말 재미라고는 찾아볼 수 없고 특히 마지막에 여자애가 경상도사람이 들으면 코웃음 칠만큼 어색한 사투리로 엄마한테 말할때는 그나마 잡히던 감정도 깨져버렸습니다 : 부정
# --------------------
# 107. TV시리즈중에는 단연 최고乃 : 긍정
# --------------------
# 108. 글쌔....슬프지만 너무 짜여진듯한 : 부정
# --------------------
# 109. 여기서 땡칠이 얘낳지 안나? : 부정
# --------------------
# 110. 너무재밌음ㅠㅠ뭐랄까 굉장히 따뜻한 느낌? : 긍정
# --------------------
# 111. 견자단나오는 영화중에 제일 노잼 : 부정
# --------------------
# 112. 재밌기만한데;;왜이렇게욕을하셍휴ㅠㅠ : 긍정
# --------------------
# 113. 실제 사실은 어땠는지 모르겠으나 의로운 협객으로서 김두한이 거지패에서 종로 최고의 주먹으로 평정하는 초기 모습을 잘 보여 줌. 배경음악이 영상과 잘 어울린다는 느낌. 참고로 황정민이 우미관 지배인으로 나와서 유명하기도 한 영화. : 긍정
# --------------------
# 114. 재밌는데? 자막읽기 힘들었지만 영어권사람들이 보면 더 몰입될듯 공간이 한정되있지만 상상만으로도 충분히재미나고 생각할게 많은영화 바이러스가 언어라는게 참신한듯 바이러수를 소문 괴담 선동 찌라시 언론플레이 등과 대입해서 생각해보면 재밌을듯 : 긍정
# --------------------
# 115. 괜찮아요~ : 긍정
# --------------------
# 116. 내가 극장가서 본 영화중 제일 쓰레기 같았다 : 부정
# --------------------
# 117. . : 부정
# --------------------
# 118. 피는 물보다 진하다. 이 한마디로 모든게 표현되는 영화. : 긍정
# --------------------
# 119. 이뿌고 따뜻한 애니였어요 : 긍정
# --------------------
# 120. 너무 좋았음 : 긍정
# --------------------
# 121. 어렷을때 보고 박준형에 배신감을ㅋㅋㅋㅋ : 긍정
# --------------------
# 122. 차인표 말투 적응안돼, 송선미 이쁘다 : 긍정
# --------------------
# 123. 과소평가! 확실히 재밌고 유쾌함 : 긍정
# --------------------
# 124. 훌륭한 작가와 뛰어난 연출진이 만나, 훌륭하고 뛰어난 한 편의 드라마가 만들어졌다. : 긍정
# --------------------
# 125. 신선한 소재로 식상한 영화를 만들었어..유치한건 둘째치고 재밋게라도 만들던가.. : 긍정
# --------------------
# 126. 다시봐도 정말 최고군요 잭 바우어 형님이 여기 나왔었다니 처음 볼땐 못 느꼈던 또하나의 재미 : 긍정
# --------------------
# 127. 이런 쓰레기영화좀 만들지마라 진짜 재미없다ㅡㅡ : 부정
# --------------------
# 128. 정말 가슴아픈영화....질리지도 않는영화....몇번을봐도...음악도 너무 좋아요...OST도 구해 들었다는... : 긍정
# --------------------
# 129. 영화도 못만들었지만 이건 탄생하지 말았어야할 그자체로 쓰레기임.. : 부정
# --------------------
# 130. 정말 재밋어요...다들 연기도 잘하고 볼만해요...~~~ : 긍정
# --------------------
# 131. 신기록 갱신인가..간닷 : 부정
# --------------------
# 132. 오시이 마모루는 영화를 통해 책을 넘어서려 한다. : 긍정
# --------------------
# 133. 데어데블보다 못한 졸작. CG는 훌륭하지만 악마 인형탈쓰고 나오는게 웃기고 인물 관계나 스토리가 너무 뻔함. 시간이 아까움. 짧은 러닝타임이 고마울 정도. : 부정
# --------------------
# 134. 마트라는 폐쇄된 공간속에서 그안에 갇힌 사람들의 심리변화가 인상적이네요. 결말이 인상적입니다. : 긍정
# --------------------
# 135. 차인표 연기는 너무 현실적이여서 마음에 와닿는다 왕초드라마를볼때도 난 연기를하는건지 진짜 실제로 그러는건지 몰랐다 이영화 내용이 쥐어짜는스토리지만 차인표라는 배우때문에 영화가살았다 너무 현실적인 연기력이다 대단하다 눈물한방울 흘리지않았지만 마음이아팠다 : 긍정
# --------------------
# 136. 이게뭐야엉엉 본시리즈말고 그냥나왔다면 이정도는안줬겠지만 본이라는 이름을 달고왔으니 엉엉 : 부정
# --------------------
# 137. 스토리가 신선하다. 재미있다. 좋다. : 긍정
# --------------------
# 138. 재밌었다.진저 너무 무서버~ㅠ : 긍정
# --------------------
# 139. 아직까지 잊지 못하는 영화. 제목부터 마음에 잔잔하게 와 닿는다. 영화 장면중에 소낙비를 피해놀라 달려 가는 부분은 정말 ☆어느 멋진날~☆ 햇살 비춰진 행복한 빗속을 달리듯 느껴졌었다 : 긍정
# --------------------
# 140. 지루하지않고 가볍게 볼수있는 코믹 스릴러 영화네요저는 잔인하고 무거운 스릴러 영화보다 오히려 좋았습니다 : 긍정
# --------------------
# 141. 김민이 너무 어설픔 졸작 : 부정
# --------------------
# 142. 화면 어지럽고 엉성함과 지루함의 연속임. : 부정
# --------------------
# 143. 영화 다보고 평점 읽는것이 이영화 최고의 재미 ㅋ : 긍정
# --------------------
# 144. 정말 재밌게 잘봤습니다! : 긍정
# --------------------
# 145. 예수쟁이들 좀 제발 인터넷에서 안 봤으면... : 부정
# --------------------
# 146. 작가의 예리함과 필력에 박수를 보냅니다. 진보한 드라마란 바로 이런 것 시청률 의식하지마시고 앞으로도 좋은내용 부탁드립니다 : 긍정
# --------------------
# 147. 작품성을 떠나서 보고 나면 너무너무 찝찝해 지는 영화.. : 부정
# --------------------
# 148. 초중학생 수준의 단조로운 대사와 지루하고 재미 없는 영화. : 부정
# --------------------
# 149. 2012년도에 참으로 억지스럽네 미국을 욕해라 뭐 이런건가? ㅋㅋ : 부정
# --------------------
# 150. 1편이 오억만배 재밌는 영화 2편도 나름대로는 재밌지만... : 긍정
# --------------------
# 151. 다시 봐도 수작이다. 미국 국수주의라 뭐라는 시점도 있겠으나 전쟁물 중에 손가락안에 꼽을정도로 잘만들어 졌다. 스토리 라인은 뻔하나 그 뻔한걸 너무 잘 살렸다. 언제 봐도 다시봐도 재미 있다. 10년이 지난 영화가.. : 긍정
# --------------------
# 152. 클럽과 사건의 연결이 전혀안된다. 섹스클럽얘기는 흥미거리일뿐 스토리연관이 없다. : 부정
# --------------------
# 153. 다니엘,,미쉘페이퍼,,마틴스콜세지~~ 쵝오 : 긍정
# --------------------
# 154. 탕웨이..이제껏 관심없었는데 이번 영화를 계기로 너무좋다..ㅠㅠ : 긍정
# --------------------
# 155. 간만에 참 유쾌하게 웃은듯... : 긍정
# --------------------
# 156. 액션이 진짜 꽤 괜찮았다. ㅎ : 긍정
# --------------------
# 157. 무슨 말이 더 필요한가 .. 아마 이 영화보고 법무관 또는 법조인이 되고싶다 라고 생각을 품엇던 사람이 있을듯 : 긍정
# --------------------
# 158. 개노답이다진짜 돈아까움 : 부정
# --------------------
# 159. 죠스보다더재밌음bb : 긍정
# --------------------
# 160. 두말할필요없다 이건 보지마 시간이 남으면 집에서 발닦고 잠이나 자라 : 긍정
# --------------------
# 161. 굿 : 긍정
# --------------------
# 162. 마지막 도서카드에 그려진 모습을 보고 우는 이츠키의 모습을 보고 저도 울었습니다... 지금 본지 3달은 지난거 같은데 아직도 그 모습을 떠올리면 먹먹해지네요 : 긍정
# --------------------
# 163. 완전한 삶은 없다 그저 하나씩 배워나갈뿐. : 긍정
# --------------------
# 164. 어라이즈 시리즈 중에 그나마 나은 2편. 4편보면 진짜 노잼이라 욕밖에 안나오는데 그래도 이건 조금이나마 볼만한편. 극장판 주제에 오프닝은 1부터 4까지 애프터이펙트만 처바르고 바뀌질 않는데 예산이 모자란건지 감독이 미친건지 모르겠다 : 긍정
# --------------------
# 165. 이야~ 미키루크 나오는 홈보이 영화를 다 아는 분들이 계시네~ 이야 놀라울뿐..... : 긍정
# --------------------
# 166. 팬이긴한데 이건 안봤네요ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ몰라 나도 : 부정
# --------------------
# 167. 케이블에서 우연히 보게 된 월광보합 때문에 깔깔 거리고 웃다가 선리기연 마지막 장면에서 일생소애가 흘러나오는데 눈물이...되돌릴 수 없는 시간이 가장 아프게 와닿았다. : 긍정
# --------------------
# 168. 보고싶다 기대 만발 싸랑해 키르아 ♥ : 긍정
# --------------------
# 169. 심심할때 보면 딱 좋은 영화 : 긍정
# --------------------
# 170. 별로 재미 없는데.....왜 7점이지? : 부정
# --------------------
# 171. 노인들의 섹스 외엔 보여줄 게 없는 영화. 영활까? : 부정
# --------------------
# 172. 멀 말하고자하는지 아직도 이해가....공포도 아니여서 실망;ㅁ; : 부정
# --------------------
# 173. 역시 영화를 볼 때도 도덕성을 버려 둘 수는 없네요 : 긍정
# --------------------
# 174. 그리스의 아름다운 풍경을 감상하면서 달달한 로맨스를 즐길 수 있는 영화! 보는내내 흐뭇한 미소를 지으며 봤다ㅎㅎㅎ : 긍정
# --------------------
# 175. OO어썸!! : 긍정
# --------------------
# 176. 조쉬나와서 바꾸먼.. 이건 뭐병- _-정신줄을 놓은건가 드팔마 : 부정
# --------------------
# 177. 종교인이 아님에도 그 인간적인 고뇌가 느껴진다. 숭고한 감동!! : 긍정
# --------------------
# 178. 수고요! 수고 수고 ㅅㄱ : 긍정
# --------------------
# 179. 한회 한회 보면서 총체적으로 발연기다. 중량급 연기자들도 모두 하향 평준화되는듯. 작가의 생각도 너무 어이업슴. 일일극 치고는 최악으로 평점 1점도 아깝다. : 부정
# --------------------
# 180. 전작에 비해 훨씬 스토리도 고급스러웠고, 무엇보다 이번편에서도 역시 간지나는 액션신은 스타뎀 성님이 도맡아 하시는거보고 더욱 좋았다. : 긍정
# --------------------
# 181. 아! 희망이란,,, 미래란,,, : 긍정
# --------------------
# 182. 먼지낀 회색초콜릿같은 맛의 영화랄까요 : 부정
# --------------------
# 183. 아주 진짜 영화를 찍어라, 영화를 찍어...ㅉㅉ : 부정
# --------------------
# 184. 이게 뭐가 다들 재밌다는거지 ㅋㅋㅋ 마지막 반전이 가장 최악이었는데... : 부정
# --------------------
# 185. b급 액션의 진수.. 깨알같은 까메오들과.. 잔웃음.. 거기다가 엠버 허드의 ㅎㄷㄷ한 몸매 어느영화에서나 빛을 발한다. : 긍정
# --------------------
# 186. 어릴때 감동적으로 본 영화라 잊지 못합니다. 라스트장면에서 이불 뒤집어쓰고 울었던 기억이...꼭 다시 보고 싶습니다. 파일 좀 보내주세요. dodadan@naver.com : 긍정
# --------------------
# 187. 두 주인공의 관계와 로맨스는 어색하고, 요술인지 마법인지.. 뭘하는건지 : 부정
# --------------------
# 188. 왜 헤라클레스의 인물묘사를 저따위로 했을까? : 부정
# --------------------
# 189. 뭐야이거 무서워 : 부정
# --------------------
# 190. 오다기리 죠의 배바지가 기억에 남네요 : 긍정
# --------------------
# 191. 카메라로 이렇게까지..아름답다 : 긍정
# --------------------
# 192. 이게영화냐?첫장면부터 역겨웠다 분위기있는척앵글잡으면 괜찮은영화인거같지?허세덩어리 : 부정
# --------------------
# 193. 지상최고의 드라마? 이정도면 될까 ? : 부정
# --------------------
# 194. 사랑이 무엇인지 알려주는 영화 : 긍정
# --------------------
# 195. 미국 당시의 시대흐름과 개개인들의 인간승리응 보여준 영화.. 좌절하고 힘들때보면.. 용기를 주는 영화 : 긍정
# --------------------
# 196. 3점이 제일 적어서 3점 준다 : 부정
# --------------------
# 197. 재미따!시간가는지 몰랐어 ㅋㅋ : 긍정
# --------------------
# 198. 기대안해서 그런가.. 조카랑 너무 재밌게 봤다.나니아,샤크보다 : 긍정
# --------------------
# 199. 소품은 잘 만들었는데 연기를 너무 못하네요... 몰입이 안됨-_-; 엑기스만 보고 끝냄.... 내가 본 영화중에 최악이다... : 부정
# --------------------
# 200. 신날 것 없는 애니. : 부정
# --------------------
# 201. 여성성의 한계에 갖힌 탈출의 덫 : 부정
# --------------------
# 202. 정말 이건 대박임 걍 잼슴 : 긍정
# --------------------
# 203. 도가 지나친 신앙심의 말로. 종교인에게도 비종교인에게도 전하는 메세지가 뚜렷해서 좋음. 강추~!! : 긍정
# --------------------
# 204. ㅋㅋ 귀여워 : 긍정
# --------------------
# 205. 내 기억에 너무 잼있었떤듯 : 긍정
# --------------------
# 206. 우와 신기하다!! 나 진심 시사회보고 평점쓴거삭제당함!!! : 긍정
# --------------------
# 207. 순수함을 말하고있다. 자연스럽게 대화만으로 서로가 끌리는 사이.... 자연스러운 만남, 영적 소통, 하루뿐인 아쉬움을 공감하며. 이들의 반년 후의 모습이 설레이며 궁금해졌다. : 긍정
# --------------------
# 208. 무섭지라도 않으면 끔찍하기라도 하던가 : 부정
# --------------------
# 209. 요요비치 나옴...발코니에서 아래를 내려다 보는 일행중 한명으로 등장함 상영 1시간 10분쯤 10초 즈음해서..영화는 형편없음. 야하지도 않고,. : 부정
# --------------------
# 210. 20년이 지나도 여전하구나~~ : 긍정
# --------------------
# 211. 남자 조낸 찌질한 연기 잘함...보는 내가 답답해요..그동안 봐온 독립영화중 좀글네요 : 긍정
# --------------------
# 212. 젊음과 열정 격정과 두려움..그 모든 것이 묻어나는 영화.. : 긍정
# --------------------
# 213. 어라~게임 영화가 아니네~ : 부정
# --------------------
# 214. 엄정화 다시보기 연기굿 : 긍정
# --------------------
# 215. 이렇게 불쾌한 내용을 왜 보게한거냐 : 부정
# --------------------
# 216. 이거 다운하려는데 청소년 관람 불가라고 뜸 : 부정
# --------------------
# 217. 공산사회주의의 잔인함을 느끼게 해주는 영화 북한에 비하면 암것도 아니지만 : 긍정
# --------------------
# 218. 다시보고싶다 : 긍정
# --------------------
# 219. 왜 이렇게 다들 스토리에 불만이지....... 이야기에는 다 원형이 있다. 이 영화는 그 원형이 되는 스토리 안에서 예술을 한거고... 그걸 가지고 진부하다고 하면 대체 뭘 본건지.. : 부정
# --------------------
# 220. 글쎄 : 긍정
# --------------------
# 221. 역시 팀 버튼. : 긍정
# --------------------
# 222. 노다메는 유치한게매력인데 욕하는새뀌들 드라마부터 보고와 : 부정
# --------------------
# 223. 애매하네... : 부정
# --------------------
# 224. 저만 별로였던가요 ㅠㅠ 그냥 그랬어요 : 부정
# --------------------
# 225. -,.ㅡ 허접스런 영화,스토리도 시대착오적인..3류 코미디 : 부정
# --------------------
# 226. 이 영화를 보고난후 극장 영사실을 유심히 보게 되었다. ^^ : 긍정
# --------------------
# 227. 많이무겁지도, 그렇다고 가볍지도않아요. 진짜 보기좋은 성장영화 : 긍정
# --------------------
# 228. 터지고 깨뜨리고 박어 : 부정
# --------------------
# 229. 매주 이것만 기다리로있어요ㅠ너무 재밌어요♥소변 사랑합니당 : 긍정
# --------------------
# 230. 맥가이버 머리 유행했을때 인기폭발 -_-; : 긍정
# --------------------
# 231. 완전쓰레기군 . 하고 보는데 생각보다 생각없이 잘 봣다. 그래서 2점준다. : 부정
# --------------------
# 232. 이건뭐 차라리 19세면노출을더하던가 이건뭐 망 : 부정
# --------------------
# 233. 보면 볼수록 나도 저 회사에서 일하면서 잘하고 싶단 생각이 만들게 하는 드라마. 캐스팅도 아주 완벽한 듯 합니다. : 긍정
# --------------------
# 234. 개잼남..포르x는 중요부분만 챙겨보지만 이건 오직 정주행함..ㅋ : 부정
# --------------------
# 235. 전 재미나게 봤는데..달튼의 능글한 매력과 젊은 시절 페넬로페를 본 것으로도 10점 : 긍정
# --------------------
# 236. 공포영화야 이게?ㄷㄷ : 부정
# --------------------
# 237. 농담과 장난끼만으로 영화를 만들기엔 무리가 있어 보인다. : 부정
# --------------------
# 238. 외계인이 징그럽지만 SF는 재밌다!ㅋㅋ : 긍정
# --------------------
# 239. 세븐을 생각하면서 봤다가 큰코다친 영화, 모건프리먼의 연기는 좋았으나.. : 긍정
# --------------------
# 240. 이토준지 원작의 영화화는 대체.. : 부정
# --------------------
# 241. 척보기에도 흥행에 실패하겠고만.. : 부정
# --------------------
# 242. 나름 대중성 있는 만화작품을 이렇게 이런 태도로 취급하다. : 부정
# --------------------
# 243. 중년의 나이라면 한 번쯤은 봐야 할 영화 : 긍정
# --------------------
# 244. 감동... : 긍정
# --------------------
# 245. 일본스타일 공포영화를 시도한듯한느낌. 깜짝깜짝놀래키는것밖에없는 일회용 공포영화 : 부정
# --------------------
# 246. 아, 이거! 어릴 때 봐서 잘 기억은 안 나짖만 재밌었던 것 같음. : 긍정
# --------------------
# 247. 영화 바람을 재밌게 본사람이라면 추천합니다. 가벼운마음으로 보기 좋은영화에요 : 긍정
# --------------------
# 248. 훌륭하다. 초한지 얼른 읽어보고 다시 봐야겠다. 연출 훌륭하다 껄껄 한신의 토사구팽은 슬펐다 : 긍정
# --------------------
# 249. 적은돈으로 나름 최선을 다해 만든 듯, 한하유가 마음에 들어서 10점 : 긍정
# --------------------
# 250. 연애인더빙도 참고 다참았지만 이건진짜 못참겠다 : 부정
# --------------------
# 251. 정신없는 여자주인공보느라고 어지럽다. 스토리도 완전 어거지;; : 부정
# --------------------
# 252. 뭔가 스토리가 이상함 : 부정
# --------------------
# 253. 이 영화에 별점 하나 주는 사람들과 같이 살고있다는게 끔찍하다 : 부정
# --------------------
# 254. 돈걱정 제로인 비현실적인 사람들, 비현실적 세상 설정 : 부정
# --------------------
# 255. -- : 긍정
# --------------------
# 256. 책으로 먼저 접한, 폭풍의 언덕.21살 이었던, 내게 사랑의 그 진한밀도를 알게 해준. : 긍정
# --------------------
# 257. 서브남주들이 더 빛나 보이고 주인공 같았던 영화. 벤자민과 지지가 나올 때가 더 즐거웠다. 특히 지지. 여주보다 더 예쁨! : 긍정
# --------------------
# 258. 1편보다는 더짜임새가있네요..그렇지만 개인적으로 로버트쇼에 더눈독이가네요..... : 부정
# --------------------
# 259. 평점9점 이상은 뭐냐 애니보고 그런말이 나오나 보자 : 긍정
# --------------------
# 260. 현실은 이러하다 : 긍정
# --------------------
# 261. 첫장면보고 영화 재미있겠구나 했는데...너무 지루하네요 지난과거를 회상하는건데 너무 지루하고 재미없습니다..감동도 없고 시간남아돌아도 다른영화 보시는게 좋을것 같아요.. : 부정
# --------------------
# 262. 조금만 집중해서 보면 엄청 심오한 영화다..! : 긍정
# --------------------
# 263. 탕웨이... 정말 매력적인 여자... : 긍정
# --------------------
# 264. 세분 비구니들이 꼭 자기자신을 찾기를 간절히 바랍니다.약간의 눈물은 흘렸지만 잔잔한 그들의 모습에서 나의 삶을 뒤돌아본 너무나좋은 느낌의 다큐였습니다. 진심으로 이런 분들의 삶을 으원하며 감독님의 열정에 감사 드립니다. : 긍정
# --------------------
# 265. 부산엔 언제 개봉해요? : 부정
# --------------------
# 266. 어떻게든 감싸줄려고 노력을 하는구나 : 긍정
# --------------------
# 267. 완전 잼다ㅋㅋㅋㅋ : 긍정
# --------------------
# 268. 이거 끝날때까지 먼가 기대했는데 아무것도 없었네요 : 부정
# --------------------
# 269. 완전 대박 ㅠㅠ 후회없는 영화에요♡꺅꺅꺅 : 긍정
# --------------------
# 270. 디박!! 대박!!잼씀 : 긍정
# --------------------
# 271. 제가 본 애니메이션 영화중에 명작입니다 : 긍정
# --------------------
# 272. 마수리와 비교하면 한 없이 작아지는 컴미 : 부정
# --------------------
# 273. 이젠 양동근은 믿고보는 배우가 아니게 되어버렸다. : 부정
# --------------------
# 274. 진짜 졸잼.. 와 마지막 결말 너무맘에들음 ㅠㅠ 진짜 재밌었음!! : 긍정
# --------------------
# 275. 감명깊고 재밌다.굿!!!!!!!!!!!!! : 긍정
# --------------------
# 276. 나는 다르게 생각하는데... 여기서 너구리에서 인간으로 변신해서 살아가는 사람들은 우리 사회의 소수자들을 상징하는 것 같다. : 긍정
# --------------------
# 277. 2시간이 아깝다. 내용도 단순 재미도 감동도 볼거리도 없다. : 부정
# --------------------
# 278. 지금까지 나온 드라마 중 최고였습니다. 100점 만점! : 긍정
# --------------------
# 279. 정말 초딩을 위해서 만든거 스토리 쓰레기 벨런스쓰레기 액션쓰레기 : 부정
# --------------------
# 280. 굿~~재밋다~~봐도봐도 잼따 : 긍정
# --------------------
# 281. 연기자들 지혼자 날라가는 연기 압권 : 긍정
# --------------------
# 282. 보고울음 : 긍정
# --------------------
# 283. 배우 이민호와 김희선의 어울리지 않을것 같은 어울림이 묘한 매력으로 다가오는 신의 ^^ 타임스립드라마의 최고봉이라 할 수 있답니다. 잔잔하게 애잔한 신의의 매력으로 풍덩 빠져보심이 어떨런지 ^^ 내인생 최고의 드라마였습니다. 적극 추천합니다. : 긍정
# --------------------
# 284. 이딴 영화가 평점이 왜이리 높은거지..; 케이블에서도 볼가치가 없는 영화.. : 부정
# --------------------
# 285. 평점 높아서 1 준다ㅋㅋㅋ 정말 재미가 없다.. 지루하고 너무 뻔하고.. : 부정
# --------------------
# 286. 그냥 강지환 아깝다.... : 부정
# --------------------
# 287. 군인이 가져아할 것 , 그것을 모두 담아서 표현한 영화이다.이 나라를 위해 죽어서 기쁘다. : 긍정
# --------------------
# 288. 영국에도 팍팍한 탄광노동자의 삶이 있구나. 자신의 재능을 발휘할 수 있는 삶을 찾아가는 소년은 행복하다. : 긍정
# --------------------
# 289. 재미가 없다. : 부정
# --------------------
# 290. 기타케이스에서 총 나오는 씬만 해도 이미 8점은 된다 : 긍정
# --------------------
# 291. 더지니어스2 보다 훨났다 : 긍정
# --------------------
# 292. """이정진,님 정말 비운의 배우라는 생각이!.." : 긍정
# --------------------
# 293. 살아가는데 한번쯤은 봐주는게 인생에 대한 의리인 영화 : 긍정
# --------------------
# 294. 3d를 그냥 보니까 좀... : 부정
# --------------------
# 295. 진짜 재밌게 봤다 : 긍정
# --------------------
# 296. 글쎄 돈 주고는 다신 안 보겠어 : 부정
# --------------------
# 297. 삼순이보다가 궁금해서 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ : 긍정
# --------------------
# 298. 판타스틱 4 vs 협녀 둘중 하나만 본다고하면 고문이 따로없다. : 부정
# --------------------
# 299. 재미있습니다...ㅋ 좀 황당하고 유머러스하고 엉뚱하지만 유쾌하게 보았네요~ 더불어 음악도 좋았습니다~^^ : 긍정
# --------------------
# 300. 볼만하다... : 긍정
# --------------------
# 301. 재미있는데여 : 긍정
# --------------------
# 302. 이거 완전 재밌게봤는데..평점 왜이리 낮음??ㅠ : 긍정
# --------------------
# 303. 당신은 지금 행복합니까 : 긍정
# --------------------
# 304. 빌어먹을 내가 이제껏 본영화중에 가장 루즈한 영화다. 말도 안돼고, 웃기지도 않고, 빌어먹을 내시간 다잡아 쳐먹고, : 부정
# --------------------
# 305. 졸다니...ㅠ그냥생물들소개..스토리無 3d어지럽고 나레이션오글오글..ㅋㅋㅋ애기영화 : 부정
# --------------------
# 306. 시즌 4.5.6강추.. 사만다 완젼 웃겨.ㅋㅋㅋ : 긍정
# --------------------
# 307. 이야기가 전개되는 과정에서 흥미를 유발하지 못한채 시간만 흘러가는군 : 부정
# --------------------
# 308. 가슴 깊이 울림을 주는 감동적인 영화다.마지막 자막이 올라 갈때까지 흐르는 눈물...이런 아름다운 영화를 이제야 감상하다니...케빈 코스트너,클린트 이스트우드 감독님...존경합니다~~^^ : 긍정
# --------------------
# 309. 지나고 보면 다 아무것도 아닐일인데..시간이 준 지혜를 전달해준 영화 : 긍정
# --------------------
# 310. 여주인공이..꽤 괜찮은얼굴^-^ : 긍정
# --------------------
# 311. 진짜 포스터만 멋짐,. 보다가끔. 주연들은 넘 좋지만,ㅠ : 긍정
# --------------------
# 312. 히 액스멘의 부활이 완벽하다 : 긍정
# --------------------
# 313. 재미있어요 : 긍정
# --------------------
# 314. 대한민국 해군으로써 dj를 혐오하는건 최대다수의 행복을 죽은 젊은이들의 목숨과 그들 가족의 슬픔보다 중하게여겼기때문이다. 손바닥으로 하늘을 가린다고 하늘이 가려지는게 아니다. : 긍정
# --------------------
# 315. 좀 주인공이 짜증났음 마지막도 그렇고 : 부정
# --------------------
# 316. 거인만 불쌍해...보는내내 속이 불편함. 아 짜증나 : 부정
# --------------------
# 317. 아오이 유우 맨앞에 한 5분 나오나? 아~~ 이 속았다는 느낌. : 부정
# --------------------
# 318. 이영화를보고 느낀건.. 개나소나 누구나 영화감독이 될수있다는것이다... 원작을 이렇게 망쳐놓다니.... : 부정
# --------------------
# 319. 몰입도 제로 뱀파이어가 피 조금 흘려서 자살하는 꼴에 늑대인간과 뱀파이어라는 초자연적인 존재의 총격전은 왜 하필 소재가 늑대인간대 뱀파이어인지도 모르겠는 작품 : 부정
# --------------------
# 320. 논스톱,뉴논스톱,논스톱3,논스톱,4,논스톱5,레인보우로망스 : 긍정
# --------------------
# 321. 댓글들 덕분에 영화 보다가 빠르게 포기함 댓글에 참으로 감사함 내 아까운 시간 아껴서....오광록씨 연기연습좀 더하셔야할듯.... : 긍정
# --------------------
# 322. 하감독님 21세기는 순정영화도 시가 아니라 긴장감과 메시지가 있어야 먹힌 답니다. : 긍정
# --------------------
# 323. 잔잔하게... 오래 기억남네요... 우리시대 보통의 가족의 모습이 솔직하게 담겨있네요. 한소녀의 성장기도요 : 긍정
# --------------------
# 324. 재밌습니다. 이만하면 최근 본 상업영화중 순위권에 랭크될만 하네요. : 긍정
# --------------------
# 325. 홍콩영화를 어줍잖게 흉내내고 있는 기절초풍하게 하는 싸구려 무비 : 부정
# --------------------
# 326. 나탈리아 와아.... 바람핀거였어..... 확실한 영상이 나왓음 했는데.... : 긍정
# --------------------
# 327. 이상은땜에 극장에서 봤었지만 최악의 영화였던걸로 기억함.. : 부정
# --------------------
# 328. '반딧불의 무덤'처럼 불편하게 만드는 진정한 이국적감성 : 긍정
# --------------------
# 329. 존재조차 몰랐던 영화!! noraism 한테 맞구 나한테 와라.. : 부정
# --------------------
# 330. 후.. : 부정
# --------------------
# 331. 사람의 인생을 한 그림에서 알 수없다는 것. 겉 으로만 알고 있는 것과 진정으로 느끼고 알고 있는 것은 분명히 느낌이 다르니까. 밴 애플렉과 션. 윌은 복 받은 사람 : 긍정
# --------------------
# 332. 스토리. 캐릭터. 표현력. 영상미. : 긍정
# --------------------
# 333. 티비드라마보다 못한영화.그 시대엔 티비드라마가 한국영화보다 더 재미있었다. : 부정
# --------------------
# 334. 힐러리를 사랑하는 남자아이밖에 생각이 안나요..ㅋ : 긍정
# --------------------
# 335. 스토리도 정말 별거없구 엄청 지루함. : 부정
# --------------------
# 336. 쓰레기 드라마. 오정.세만 빛났다. : 부정
# --------------------
# 337. 와 포스터도 같넼ㅋㅋㅋ : 부정
# --------------------
# 338. 이건 클래식을 위한 드라마도, 청춘들의 성장 드라마도 아닌 주제를 알 수 없는 드라마가 되어 버렸다. 클래식계의 현실을 고발하기 위한 드라마인가? 심각한 드라마다. 부채도사는 어디로..ㅠㅠ : 부정
# --------------------
# 339. 좋아요..^.^ : 긍정
# --------------------
# 340. 쾌락의 정점을 찍은 그들의 삶을 보고 우리는 또 다른 쾌락을 느낀다. 그들이 추하다 생각하지만 결국 우리도 돈을 추구하고 누구나 부유한 삶은 한번쯤 상상 해본다는거..감독한테 엿먹은거 같다. : 긍정
# --------------------
# 341. 개인적으로 미식축구를 다시 생각하게 만든 감동적인 영화군요-_-;; : 긍정
# --------------------
# 342. 의외로 재밌던 영화 지루하지 않은 사극 멜로였다 : 긍정
# --------------------
# 343. 캐릭터들이 하나같이 짜증유발 매력적인 캐릭터가 없다 할아버지 빼고~ : 부정
# --------------------
# 344. 엔딩 임팩트가 약하다..통쾌했으면 좋았을 걸.. : 긍정
# --------------------
# 345. 역시 박신양..마지막이 쫌...; : 긍정
# --------------------
# 346. 주연배우 너무 지겹고,,, 너무 무리한 압축... 으으으윽 : 부정
# --------------------
# 347. 같은 상처를 공유하기에 부담스럽고 피하고만 싶은 어머니, 가족이란,,, : 긍정
# --------------------
# 348. 문제아라고 쏘아부쳤던 아이들의 속내. 재빠르고 영리하고 의리있는 시릴 / 다르덴은 이렇게 엉망인 가운데에도 진심의 작은 마음이 지켜갈 수 있는 것에 대해 꾸준히 이야기해주네. 극적이지 않게 직조하는 능력에 감탄 ?@non : 긍정
# --------------------
# 349. 유치해....더 사실적으로 만들지.. : 부정
# --------------------
# 350. 흑역사네 ㅋㅋㅋㅋㅋ : 긍정
# --------------------
# 351. 꽃 빨아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 진짜 짱이었어요 : 긍정
# --------------------
# 352. 별로다. : 부정
# --------------------
# 353. 전라도의 모든것을 보여주는 영화!! : 긍정
# --------------------
# 354. 뻔한 스토리, 조잡한 효과... : 부정
# --------------------
# 355. 1억2천만불에 제작했지만 수익은 4백만불만 먹고 망한 전세계 2위로 망한 영화 : 부정
# --------------------
# 356. 기분 나빠서 못보겠다. 두치 때문에 저게 두치냐 ,ㅡㅡ : 부정
# --------------------
# 357. 수채화같은 영상과 가슴을 울리는 음악이 조화된 잊지못할 명작 : 긍정
# --------------------
# 358. 가장 싫어하는 신파 스릴러 ㅠㅠㅠ : 부정
# --------------------
# 359. 뭐지..? 이영화는? : 부정
# --------------------
# 360. 재밌었음 : 긍정
# --------------------
# 361. 아버지와 소원해졌다면 이런 영화 한편쯤 보는것도 괜찮을듯 싶다. : 긍정
# --------------------
# 362. 감독이 살아서 요즘 개독들 보면 아마 기가 막힐 듯. : 부정
# --------------------
# 363. 말로는 설명할 수 없는 놀랍고 감동적인 영화 : 긍정
# --------------------
# 364. 나가사와 마사미도 그렇고 이 시리즈 너무 좋다 그냥~ : 긍정
# --------------------
# 365. 기대안했는데 너무 잼나다 연기짱~ 내용두 탄탄하고 강추~ : 긍정
# --------------------
# 366. 현실적이고 재밌게 꾸며주세요너무 막장은 싫고요인물들의 성격,행동이 일관됬으면 좋겠네요무조건 재미만 추구안했음 좋겠습니다 : 긍정
# --------------------
# 367. 조로아크가 조로아를 간절히 바라는것이 느껴지네요.. : 긍정
# --------------------
# 368. 정종철,박준형등 이무리의 사람들이 나오는 영화는 크게 성공 안한듯?... : 부정
# --------------------
# 369. 아진짜...바보요괴들 귀요미잼잼잼ㅋㅋ이 바보요괴들 그립다 ....또보고싶다♡감동도잇구! : 긍정
# --------------------
# 370. 나름 머리좋고 학식이 높다는 경제학자들이 어떻게 서민들의 생활을 파괴하면서까지 돈을 벌어가는지에 대해 적나라에게 설명해주는 뜻깊은 영화. : 긍정
# --------------------
# 371. 간만에 원하는 영화가 나왔네요 : 긍정
# --------------------
# 372. 진짜 말이 필요없는 드라마네요 난 왜 작년에 이걸몰랐지..?? 진짜 영화같은 색감과 명품연기자들..인생 드라마가 될거같아요 : 긍정
# --------------------
# 373. 괜찮은데 좋아요..우리나라 만화영화발전을 위해서.. 내용재밌는데요 순수만화 : 긍정
# --------------------
# 374. 참신한 소재지만 어슬픈 마무리때문에 실화인줄 알았네 : 긍정
# --------------------
# 375. 재미있어요 너무나도재밌어요 : 긍정
# --------------------
# 376. 반전에 반전, 감독도 지켰는지 대충 얼머무리면서 마무리, 쫑났다. : 부정
# --------------------
# 377. 인생을 다시한번 생각하게 하는 영화...여운이 남는 영화 : 긍정
# --------------------
# 378. (밑에 분) 그래 난 사람 아니다. ㅎㅎ : 부정
# --------------------
# 379. 한채영 스탈좋은 거 인정 그러나 언제나 느끼지만 얼굴은.그닥...모두들 책을 읽어대시는구만 ㅋㅋㅋㅋ 내가 본 한국영화중 최악의 연기조합. 연출수준은 학생영화. 이걸 개봉했다는게 놀랍다.이보다 같은해에 나온 해변으로 가다가 훨 나음. : 부정
# --------------------
# 380. 이거 왜 재방안해주나요...!!! : 긍정
# --------------------
# 381. 와 아저씨 조인성도보고 능력있으신분이셨네.. 아무튼 전 서울고 : 긍정
# --------------------
# 382. 툭툭끊기는재미와,어울리지않는대사로멋있게보일라는오도방정. : 긍정
# --------------------
# 383. 진-하게 여운이 남는영화 : 긍정
# --------------------
# 384. 쉬리에서 한 10년은 퇴보한 방화 수준의 망작 : 부정
# --------------------
# 385. 소간지 짱!! : 긍정
# --------------------
# 386. 5점정도가 적당한 영화...역시 안졸리나는 액숑이다 : 긍정
# --------------------
# 387. 완전 짱임. 한번 보면 폐인됨,.ㅋㅋㅋ : 긍정
# --------------------
# 388. 줄거리만 읽어도 대충 감이오는 스토리와 결말이라 기대안하고 봤는데 역시 예상대로였지만 재밌게봤다훈훈해서 좋달까~~ : 긍정
# --------------------
# 389. 대박 : 긍정
# --------------------
# 390. 조음 : 부정
# --------------------
# 391. 제발 이런 쓰레기영화 만들지말자 국가적낭비다... : 부정
# --------------------
# 392. 어줍잖게 예술가의 고뇌 인양 포장해서 입생로랑에 대해 사기치지마라 지루한 영화는 참을수 있지만 겉멋만 잔득 들어가고 내실은 텅비었으면서 예술인척 하는게 더 봐주기 짜증난다. 올드함과 진부함 그리고 건질것 하나도 없는 대사들의 향연 : 부정
# --------------------
# 393. 오타루에 와서 다시보는 러브레터. 학교다닐때는 큰 감흥없이 봤는데, 지금 다시 보니 너무 좋다.지금 내리는 큰눈이 그치면 밖으로 나가 다시 느껴봐야지~ㅎ : 긍정
# --------------------
# 394. 공포영화인지, 웃길려고하는건지 알수없다 : 부정
# --------------------
# 395. 공허하게 담배피기 - 빌리 밥 숀튼. : 부정
# --------------------
# 396. 30대 여자의 노처녀 히스테리에 열등감이 더해지면 어떻게 되는지를 보여주는 영화. 골때리고 끝내주게 웃겨준다 : 긍정
# --------------------
# 397. 재밌어요. : 긍정
# --------------------
# 398. ..대체 내용이 왜 이렇게 이어지는건가 싶었다 ㅡㅡ; : 부정
# --------------------
# 399. 브로큰 : 부정
# --------------------
# 400. 포스터가 약간 거북하다... : 부정
# --------------------
# 401. 유다인이란 배우를 알게 해준 영화 : 긍정
# --------------------
# 402. 소설 원작 잘 재현해낸거 같아요 : 긍정
# --------------------
# 403. 보다나옴...대사가 온통 노래 : 긍정
# --------------------
# 404. 은행털이 들이 보여주는 몸개그 열전. : 부정
# --------------------
# 405. 정말 오랜만이다...이런 감정...ㅠ : 긍정
# --------------------
# 406. 손현주 짱 : 긍정
# --------------------
# 407. 훈훈한 내용이지만 스토리가 다소 억지스럽고 부족하다. : 부정
# --------------------
# 408. 무언가 잊고 살았다는 느낌을 준 영화 이제 생각을 좀 바꿔야 할거 같음 : 긍정
# --------------------
# 409. 또 뻔한결말 또 뻔한 시걸의 영화 : 부정
# --------------------
# 410. 혼자 북치고 장구치다가 관객 우롱하면서 끝난다. : 부정
# --------------------
# 411. 천하의 슈렉도 속편이 거듭되다보니 힘이 떨어지는군 : 부정
# --------------------
# 412. 주군의태양+파스타 내용은 뻔하지만 재미있다 : 긍정
# --------------------
# 413. 여자주인공이이해가안됐다남자여자순수한사람여자는양심때문에죽음을평점높다 : 부정
# --------------------
# 414. 시대를 너무 앞서간 영화 ! : 긍정
# --------------------
# 415. 박중훈은 괜찮았다 근데 아직 넘 어색하고 꽝이었다 : 부정
# --------------------
# 416. 반담 영화 중에 꼽는 작품/ 네이버 평점의 신뢰도는 땅에 떨어졌다 : 부정
# --------------------
# 417. 이건 당연히 9점줘야함 ㅇㅇ : 긍정
# --------------------
# 418. 본지 오래되어서 기억이 잘 안나지만, 야한장면이 부족했던 걸로 기억.. : 긍정
# --------------------
# 419. 주저리주저리 떠들다 결국 산으로 가는 이야기 : 부정
# --------------------
# 420. 매력적인 구석이 있으나 엄청난 자의식 과잉에 질식할 것 같다. : 부정
# --------------------
# 421. 할말을 잃고 봣다...내시간이 아까웠.... : 부정
# --------------------
# 422. 헐 : 부정
# --------------------
# 423. tv 전기세가 아깝다!!! : 부정
# --------------------
# 424. 너무 지루하다. 잠 와 죽는 줄 알았다. 아흠. : 부정
# --------------------
# 425. 우리에게 행복을 가져다 주는 이들보다 끔찍한 이들이 더 많은 게 현실이다. 우리를 행복하게 해주는 사람들과 함께 하는 것도 중요하지만 그보다 더 중요한 것은 나 스스로 행복해져야 한다는 것이다. 스스로 행복한 사람이 타인도 행복하게 만들 수 있다. : 긍정
# --------------------
# 426. 간결하고 지적이며 몰입도가 대단한영화 : 긍정
# --------------------
# 427. 진짜 이병훈 사극중에서 제일 재미없었던 드라마이었던듯 : 부정
# --------------------
# 428. 블랙코미디의 진수! 그러나 찌질이들의 위악이 역겨워 별 한점만 주련다. : 부정
# --------------------
# 429. 가슴찡한 웃음뒤에 숨겨진 찡함... 독특한 재미가 있네요 : 긍정
# --------------------
# 430. 평점이 왜케 낮아. 이거 짱인데 : 긍정
# --------------------
# 431. 스팟 출연진이 화려하지만 멍청하고 허영심만 가득찬 아마추어의 무개념 자기 배설用 : 부정
# --------------------
# 432. 입양을 바라보는 냉정하고도 따뜻한 시선에 감탄했다. : 긍정
# --------------------
# 433. 알바들아 흥해라ㅡㅡ : 부정
# --------------------
# 434. CG나 연기가 현시대에 많이 뒤떨어지는게 흠이지만 SF의 시초로서 슈퍼맨의 위상을 고려하면 9점.. : 긍정
# --------------------
# 435. 전 너무재미있었음 성유리의 어색한 연기?/ ㅋ : 긍정
# --------------------
# 436. 지금보면 삼류영화에요~지루함 : 부정
# --------------------
# 437. 일본영화를좋아하는이유 : 긍정
# --------------------
# 438. ㅋ 연기, 시나리오, 연출 제대로 된게 하나도 음슴 ㅋㅋ 보는 내내 비웃음 나온다 진짜 ㅋㅋㅋㅋ난 로멘틱코메딘줄 알았네 ㅋㅋ : 긍정
# --------------------
# 439. 하얀노파 그냥 웃지요 ㅋㅋㅋㅋㅋㅋㅋ : 부정
# --------------------
# 440. 자극적이기 위해 끼운 억지스런 장면들. 속보이는 뻔한 계산.연출성은 그렇다치고 감독의 인격수준이 바닥. : 부정
# --------------------
# 441. 갠적으로 1편보다 더 재밌었쏘 : 긍정
# --------------------
# 442. 이스트우드 뿐 아니라 애드 해리스의 연기도 잊혀지지 않는다. : 긍정
# --------------------
# 443. 고은정혼자자나체한은정 혼자 잘 난체 언제쯤 크다재미없는 이야기 : 부정
# --------------------
# 444. 이것도 알바있나 개봉전이 8.5야.. 와 0점 못줘서 1점준다 : 부정
# --------------------
# 445. 사람들이 일상을 대할땐 언제나 신경적이고 지루하하는 경향이 심하다. 삶이란 생각보다 길고 어려운 난간에 봉착하기 마련이기때문인것같다그렇게일상에지내다보면소중한감성을잊고살아오는것같다 이영화를 보고도쿄가가진메트로폴리탄이가진 뒷편 잊고지내던감성이 살아난듯하다 : 긍정
# --------------------
# 446. 엑소시스트의 먹칠해준 영화 : 부정
# --------------------
# 447. 별 반갑지 않은 감독의 시끌벌쩍 : 부정
# --------------------
# 448. 완전 .잼잇엇어요!!! 정말.현재의 나를 보는 듯한느낌 : 긍정
# --------------------
# 449. 이런 쓰레기 한쿡영화는 돈주고 봐주면 절댜 안된다! : 부정
# --------------------
# 450. 이게 뭐? 재밌어?! 마지막이라면 그렇다 쳐도 이건 첨부터 여자를 지키는 영화라고 하는데 그런건 나오지도 않고 반전주의 의식을 볼수도 없음 결론적으로 애로영화 노잼 : 부정
# --------------------
# 451. 상어매니아 기대를 가장 충족시키는 영화라고 생각한다 : 긍정
# --------------------
# 452. 이걸 반전이라고? 미치겠구만..내시간 돌려줘!! : 부정
# --------------------
# 453. 6년연애..여자가 다른 남자에게 흔들린것만 빼면 정말 100%공감하는 제얘기..해피엔딩은 될수 없다는.. : 긍정
# --------------------
# 454. 공감불가 저런 OOO기들은 다죽여야 하는데 : 부정
# --------------------
# 455. 눈물로 마무리 짓게 되는 영화 : 긍정
# --------------------
# 456. 10점으로 이 영화를 표현하기엔 턱없이 부족하다 : 부정
# --------------------
# 457. 사이코패스 ....- : 부정
# --------------------
# 458. 불쌍한 펭귄맨 맥스의 무표정이 제일무섭다 : 긍정
# --------------------
# 459. 1점주는 OOO들은 흰둥이똥구멍이나 핧으라지. 쓰레기들.. : 부정
# --------------------
# 460. 베트남전의 폐해에 대해 보여주는 점보다 미국식 패권주의가 느껴짐. 무조건 미국이 전쟁에 참여해 정의의 편이라는 점을 부각시키는 것은 옳지 않다고 봄. 전쟁영화치고 짜릿한 스릴이나 감동 또는 재미도 별로. : 부정
# --------------------
# 461. 포스터에 있네요. 보지 않고 판단하지 마라. : 부정
# --------------------
# 462. 평보고 만원결제하고봤는데.. ㅡㅡ; 신랑 보다잠들고 돈아까워서 끝까지보긴했는데.. 평점주는것도 알바있단거 첨알았네요.. 걍 개인기 맘비우고보려고해도 유부녀랑 아무렇지않게 사랑에빠지고.. 그걸 미화시키고.. ㅡㅡ;; 어의없음! : 부정
# --------------------
# 463. tv 전기세가 아깝다 캬악 퉷!!! : 부정
# --------------------
# 464. 후반부에 펑펑 울었다ㅠㅠ : 긍정
# --------------------
# 465. 있을수 없는 이야기... 인정할수 없는 결론... : 부정
# --------------------
# 466. 해리포터 전 시리즈중에 제일 인물 심리묘사나 구체적인 이야기, 그리고 어린애들 영화같지 않은 진지함과 진중함도 느꼈던 편. 갠적으론 파트2의 화려함보다는 파트1의 느낌이 더 좋은것 같다 : 긍정
# --------------------
# 467. 정말 이런 영화가 개봉되다니 믿어지지 않음.처음으로 영화평점을 매기게 한 영화. 무슨 생각으로 수입했는지???? : 부정
# --------------------
# 468. 재미없다 진심으로 솔직히 재미없다 : 부정
# --------------------
# 469. d : 부정
# --------------------
# 470. 내생애 최악의 공포영화 공포영화가 무서워야되는데 웃김.. : 부정
# --------------------
# 471. 참 좋은 영화....! : 긍정
# --------------------
# 472. 오리지날이다.. : 부정
# --------------------
# 473. 최고의 드라마 김태희랑 OST가 너무좋다 : 긍정
# --------------------
# 474. 너무 재미 있네요 ^0^ : 긍정
# --------------------
# 475. 이건 뭐 그냥... : 부정
# --------------------
# 476. 최고의 영화다.이 영화를 본 후 앞으로 영화를 잘 선택해야 한다는 충고를 얻었다 : 긍정
# --------------------
# 477. 법은강한자에게만 평등하고정의는 없다 : 긍정
# --------------------
# 478. 작품성이고 뭐고 도무지 : 부정
# --------------------
# 479. 진짜 만나기 힘든 명품 드라마! 배우며 작가, 모두 최고! : 긍정
# --------------------
# 480. 별로 : 부정
# --------------------
# 481. 이 영화를 이제서야 보게 되다니..명작으로 불러질만 한데 제목이 아쉽다 : 긍정
# --------------------
# 482. 이렇게 못 만들기가 더 어렵겠다. 초딩 학예회급 연기력을 선보인 이요원은 모구 게다가 황정민 딸로 나온 아주머니는 모냐? 감독이나 제작진은 몰보구 캐스팅들을한 거냐? 한심한 영화네... 네이버두 별점 0개 할 수 있게 해주세요 : 부정
# --------------------
# 483. 글쎄 좀 쌩뚱맞다고 해야하나.... 이입도 안되고.. 인내심을 요한다.. : 부정
# --------------------
# 484. 발전하게 없네여~ : 부정
# --------------------
# 485. 난꽤 재밌었음 배우연기가 오지니까 : 긍정
# --------------------
# 486. 시나리오작가 상 줘라 두번줘라 : 부정
# --------------------
# 487. 감독이 무슨 이야기를 하고싶은지 모르겠다 복선이 너무 많다 장치가 너무 많다 목잡하고 답답하다 여주인공의 감정과잉이 보는이로 하여금 실소를 머금게한다 : 부정
# --------------------
# 488. 죄송하지만 빨리 끝나고 다른 드라마 좀 했음 좋겠네요 왜케 길어요 넘 재미없어요. : 부정
# --------------------
# 489. 이건 100퍼 킬링 타임용 ㅋㅋ : 긍정
# --------------------
# 490. 오빠들더멋잇어졋어요ㅎㅎ : 긍정
# --------------------
# 491. 영화 보다 잔건 처음... : 부정
# --------------------
# 492. 어디하나 흠잡을 곳 없는 최고의 영화 : 긍정
# --------------------
# 493. 별점이 굉장히 높네요. 그럴만한 가치가 있는영화.. : 긍정
# --------------------
# 494. 여기 티모시 스펄이라는 배우나오지 않나요? 배우 목록에 없어서 영화에서 밥으로 나온 그사람 없음 배우목록에 첨부점요 영화는 좋아요 : 긍정
# --------------------
# 495. 평점 처음달아보게만드는데 내인생에서 베스트b급아류작인듯 : 긍정
# --------------------
# 496. 킬링타임용 그 이상 그 이하도 아님 : 부정
# --------------------
# 497. 감정이입 되더라구요.. 이렇게 심하게 영화가 제가 된 적은 없었는데.. 저에게 해당되는 이야기는 아닐지라도, 가슴 찡했습니다.. : 긍정
# --------------------
# 498. 군인들도 자더라ㅎㅎㅎㅎ : 긍정
# --------------------
# 499. 캡틴 듀브아 나올 때마다 너무 웃겼다. 줄리안이랑 곰의 러브스토리도 재밌었고 무엇보다 서커스씬은 노래 firework와 어울려 환상적이었다. : 긍정
# --------------------
# 500. 아오 초등학교 2학년떄 존 나게 무섭게 봤다 ㄷㄷ : 긍정
# --------------------
# 501. 아재미때까리진짜없네 : 부정
# --------------------
# 502. 좋은 스릴러 소재로 왜 엉성한 멜로를 만들었을까? : 부정
# --------------------
# 503. 권선징악이라는 진부한 스토리..하지만 드라마 중반부까진 10점 주어도 괜찮을듯한 연출 스토리 연기력. 후반부 갈수록 누구나 예상가능한 권선징악결론이겠지만 왜인지..예상못할 훌륭한 반전 하나정도 나오지 않을까하는 개인적인생각입니다. 암튼 난 꿀잼ㅋㅋ : 긍정
# --------------------
# 504. 김승우는 연기를 몇년했는데도 연기가 늘지를 않는구나.황정민이나 송강호한테 가서 좀 배우고와라.발연기 대단하다. : 긍정
# --------------------
# 505. bad : 부정
# --------------------
# 506. 애기때 극장에서 엉엉 울었던기억 : 부정
# --------------------
# 507. 처음에 이 아이가 크리스천베일임을 알아보고 매우 깜짝놀랐다. 역시 명배우의 이름답게 어릴 때부터 재능을 가지고 계셨구나... 어린아이가 본 시선으로 전쟁이 아닌, 때 묻지 않은 순수함과 호기심을 풀어낸게 멋지다. : 긍정
# --------------------
# 508. 요즘 비디오가계가 없어서 힘들죠?ㅠ : 긍정
# --------------------
# 509. 캐릭터의 개인기는 좋지만 시나리오를 하루만에 썼네. : 부정
# --------------------
# 510. 별한개도 아깝다 이런영화에 돈을쓰다니 돈이남아도냐? : 부정
# --------------------
# 511. 어설픈 연출과 빗나간 주제의식이 적절하게 섞여있다 : 부정
# --------------------
# 512. 빨갱이는 빨갱이일뿐.. : 부정
# --------------------
# 513. 공유 짱짱맨 ♥＼(^0^*)/ : 긍정
# --------------------
# 514. 환희님비롯,신인배우들 연기 기대이상이구요, 아름다운 영상에 콘서트 보는 것 같아요. OST곡들 모두 좋아요. : 긍정
# --------------------
# 515. 두뇌와 가슴이 없이 눈으로만 보는 무지한 사람들에게는 지루하고 돈만 날릴영화겠지. 그런부류는 그냥 치고받고하는 헐리욷 쓰레기 영화나 보길. 왜 이런영화를 돈들이고 시간 낭비하며 보러갔는지 이해가 안감. 명화를 보며 만화만도 남도 못한 쓰레기라 할게지 : 부정
# --------------------
# 516. 낚았다 히데오의 조금? 그런 영화 : 부정
# --------------------
# 517. 다시는 보고싶지 않은 영화 : 긍정
# --------------------
# 518. 평점에 낚인 영화 .... : 부정
# --------------------
# 519. 개봉 하고 .. 순식간에 내려가서 망한 영화라고만 알고 있다가 한번 본 후로는 괜찮은 영화라고 생각이 들더군요 ~ 어떤분은 허구라고 하는대... 실제로 있던일인대 무슨 허구입니까... : 긍정
# --------------------
# 520. 흥미롭고 가슴 뭉클해요. : 긍정
# --------------------
# 521. 평점보고 봤다가 내용도 노잼이고 웃긴것도 아닌 유치한 개그나 치고있고 액션이 쩌는것도 아닌 80년대 액션을 보여주고 20분 보다가 짜증나서 넘겨가면서 보다가 꺼버렸음. 지금 궁금한건 저기 나온 딸래미 여자애 분명히 AV에서 본거같은데 누군지 기억이안나 : 부정
# --------------------
# 522. 제목도 그렇고 정말로 짜증이 나는 영화였다 : 부정
# --------------------
# 523. 이런 찝찝함이라니.... : 부정
# --------------------
# 524. 솔직히 재미는 있자나... : 부정
# --------------------
# 525. 잘만들었다고 보기에는 그다지..특이한 취향을가진 사람들의 행복찾기..? : 긍정
# --------------------
# 526. 드라마 왜 이리 재미없는 이야기 : 부정
# --------------------
# 527. 1점보다 더 이하주고싶다 : 부정
# --------------------
# 528. 라이언 필립이 왜 못 뜨는지 확실히 알려준 영화. : 부정
# --------------------
# 529. 잘보고있어여진자,,, ㅠㅠㅠ부럽다 : 긍정
# --------------------
# 530. 와 여러번봐도 재밌다. : 긍정
# --------------------
# 531. 솔직히 아닌것은 아니다 : 부정
# --------------------
# 532. 스페인 영화기도 하고 맨 마지막 씬은 결코 잊을 수 없다 : 긍정
# --------------------
# 533. 감독의 상상력과 작품성이 우수했던 작품이라 생각됩니다. 현실과 환상의 세계를 헤엄치는 미스터리 다시 한번 재감상을 통해 미스터리 작품의 세계로 빠져들고 싶습니다. : 긍정
# --------------------
# 534. 이거 감독하고 출연배우빼곤 아무도 끝까지 못본다던 그 유명한영화? : 부정
# --------------------
# 535. 이거 KBS2 TV에서 한거쟎아요.. : 부정
# --------------------
# 536. 감동이 살아있어!^ : 긍정
# --------------------
# 537. 케이블에서 할때마다봄.조쉬하트넷 멋있음 : 긍정
# --------------------
# 538. 좋아요 다시 보고 싶은 영화 : 긍정
# --------------------
# 539. 정말 정말 할일없을때 시간때우기도 재미없었네 : 부정
# --------------------
# 540. 재미없다..보지마라.. : 부정
# --------------------
# 541. 스토리가 스릴있고 훈훈하다 : 긍정
# --------------------
# 542. 지루하다. 2차 대전의 화려한 전투씬을 기대했는데동네 아줌마들의 친목 도모라니...임팩트와 감동이 없다.물론 이런 내용을 좋아하는 사람도 있겠지만 나는 땡. 2점 : 부정
# --------------------
# 543. 오늘 엘지유플러스로 장화,홍련이란 영화를 보았을떄무섭고 감동 적이었어요 : 긍정
# --------------------
# 544. 색다른 코난 시리즈 인 듯 ~~~♥ : 긍정
# --------------------
# 545. 1회부터 지금까지쭈욱~~넘잼있어요~오늘강우창이 넘나빠ㅠㅠ순금이는우짜라꼬ㅠㅠ : 긍정
# --------------------
# 546. 정화누나!!!!전생에 나라를 구하셨습니다!!!정화누나 너무 좋아하는데~~~요즘은 너무 부러워요~~~크크크~~~ : 긍정
# --------------------
# 547. 좋은 소재지만 연출이 ㅈ망이네 : 부정
# --------------------
# 548. 망해도 싸지 : 부정
# --------------------
# 549. 티비에서 방영해주길래 우연히 보게 됐습니다.평점이 왜 8점밖에 되지 않나 의문이네요 스토리가 진행되며 느껴지는 쾌락, 슬픔 그리고 사회 풍자적 요소 정말 재밌게 봤습니다.. : 긍정
# --------------------
# 550. 이건 영화가 아니라 포르노 수준인데... : 부정
# --------------------
# 551. 감동..첸카이거감독작품은 역시 : 긍정
# --------------------
# 552. 진행자들이랑그방청객들 너무오버하는게 보기안좋더라. 그렇지만, 휘성편은 정말재미있게봤다. : 긍정
# --------------------
# 553. 이시대 아버지의모습.. 너무나 잘표현했던 영화. 아버지는 세월이가도 아버지입니다. : 긍정
# --------------------
# 554. 너무 한 출연자에게만 어필하고...송은희씨는 너무 끼어들고 그치만 신동엽씨는 역시 프로네요~ : 긍정
# --------------------
# 555. "아주 큰 교훈을 얻었다 ""야한장면을 보고 싶으면 야동을 보라""" : 긍정
# --------------------
# 556. 어릴때봤지만 20년이지난 지금도 생각나는 인상깊은영화에요 오늘따라 다시보고싶어요 : 긍정
# --------------------
# 557. 굳 : 부정
# --------------------
# 558. 초반에 엘베안에서 공효진이 이선균 기습볼뽀뽀할때 왜이리 좋지ㅋㅋㅋㅋ 이선균 공효진 둘다 표정이 재밌어서 그런가 되게달달했음ㅠ 새벽까지 몰아서 봤는데 꿀잼졸잼짱잼!!! : 긍정
# --------------------
# 559. good : 긍정
# --------------------
# 560. LOVELY!! 유머들이 기가 막혀요~^ : 긍정
# --------------------
# 561. 재미있게 봤음요~ 추천!!! : 긍정
# --------------------
# 562. 내가 알기로 이게 박찬욱감독의 본모습인데..... : 부정
# --------------------
# 563. 아무것도 모르는 대중을 선동하는 선동버스... : 부정
# --------------------
# 564. 한마디로 말해서 핵! 노~잼 : 긍정
# --------------------
# 565. 드라마가 좋은 것도 아니고 액션이 좋은 것도 아닌... : 부정
# --------------------
# 566. 김청기감독이제일좋아요........................ : 긍정
# --------------------
# 567. 드니라방 소름돋는다...봉준호도 괜찮았다 미셸 공드리는 별로... : 부정
# --------------------
# 568. 간만에 괜찮은 스릴러물을 만났네요. : 긍정
# --------------------
# 569. 지루해 죽느줄 알았다... 유우때문에..끝까지 본 영화 -_- : 부정
# --------------------
# 570. 아이들이 좋아하고 어른이봐도 재미있어요 : 긍정
# --------------------
# 571. 한개도 아깝다쓰레기영화 : 부정
# --------------------
# 572. 위로가 필요할때 위로가 되는 드라마!!! 너무죠으다 : 긍정
# --------------------
# 573. 재미있던데..내용이해도잘되고 : 긍정
# --------------------
# 574. 어릴적 우주비행사를 꿈꾸지 않은 사람은 없을것이다..ㅋ 이제라도 봤으니 다행..ㅋ : 긍정
# --------------------
# 575. 왜상받았지? 진짜지루하고 끝까지보면 욕나옴(보면 암) : 부정
# --------------------
# 576. 재미없다.. 옹박 오리지날 1편빼고 만들지 말았어야했다.. : 부정
# --------------------
# 577. 오랜만에 영화다운영화를 봐서 좋아써요~~안보면 후회해요!! : 긍정
# --------------------
# 578. 세익스피어가 이렇게 차별주의적인 사람이었다니.. : 부정
# --------------------
# 579. 상당히 시답잖고 어설프네. : 부정
# --------------------
# 580. 평점이 왜이렇게 낮은걸까요?; 소재도 신선하고 중간중간 많이 웃었습니다 ㅋㅋ : 긍정
# --------------------
# 581. 로맨틱한 지구 종말. 잔잔한데 마지막 장면 여운이 너무크다.. 재난블록버스터보다 이런게 훨씬 와닿고 현실적으로 무섭고 슬픈것 같다. 보는내내 소소한 웃음도 있고 감동도 있고 배우들도 사랑스럽다. 나도 저렇게 종말을 맞이하고싶다 !!! : 긍정
# --------------------
# 582. 바이오로보 표절... : 부정
# --------------------
# 583. 이 정도로 평점 끌어올린거 보면 배급사에서 알바 잘 뽑으신거 같아요. 아니면 4대보험 들어가는 정직원들인가 ㅋㅋ : 부정
# --------------------
# 584. 평점왜이렇게 높냐 이게 볼만하다고? 참나.... : 부정
# --------------------
# 585. 진짜 희대의 망작. 시간은 황금보다 귀하다는말이 절실하게 느껴졌다. : 부정
# --------------------
# 586. 딸하고 너무 재미있게 봤어요 영화 본 뒤로 딸은 도라애몽과 같은 주머니가 있었으면 하네요 ㅎㅎ : 긍정
# --------------------
# 587. 이게 영화야?월요일 국군방송보다 졸려 : 부정
# --------------------
# 588. 우연성이 너무심해 : 부정
# --------------------
# 589. 모든 걸 다 떠나, 공포영화가 이토록 지루할 수도 있구나 하는 생각이 든다. : 부정
# --------------------
# 590. ㅋㅋㅋㅋ아놔 진짜 네이버영화 스포하지마라 : 부정
# --------------------
# 591. 이것 다시 보고 싶은데 정말 재미 있었는데 : 긍정
# --------------------
# 592. 포스터부터 90년대 영화다 진짜 할말을잃엇다 2010년영화라니 : 부정
# --------------------
# 593. 실화여서 더 재미있는듯ㅋ : 긍정
# --------------------
# 594. 이 영화때문에 영화보는 눈이 엄청 높아져서 몇몇만제외하고 거의 다 재미없는영화로 만든 걸작..영화관에서 나오면 꼭 허전한게 있었는데 이건 걍 꽉꽉 채워나온 느낌?영화관에서 본게 정말 신의한수이고 진짜 내생애 최고의 영화 : 긍정
# --------------------
# 595. 샘들러 영화는 별로인듯 잼있게본게..하나도 없음.. : 부정
# --------------------
# 596. 샌프란시스코의 쟈니!! : 긍정
# --------------------
# 597. 그래도 액션은 볼만했음~ㅎㅎ : 긍정
# --------------------
# 598. 왜케 광고는 멋지게 해놨는지.. 정말실망 : 부정
# --------------------
# 599. 이게뭐냐 빨갱이 영화냐 ㄷㄷ : 부정
# --------------------
# 600. 재미있어요~~ : 긍정
# --------------------
# 601. ㅇ이승환님편 진짜 울면서 듣고보고... 최고얍! ^^ : 긍정
# --------------------
# 602. 간만에 재밌는 영화봔네...찰스 그로딘때문에 배꼽이... : 긍정
# --------------------
# 603. 지브리스튜디오와 비교해도 손색없는 명작애니의 탄생! : 긍정
# --------------------
# 604. 정말 좋은 영화 또 보고싶다~ : 긍정
# --------------------
# 605. 주말 예능치고 너무 재미없어요.... : 부정
# --------------------
# 606. 수 많은 무비꼴라쥬중 유일하게 좌석이 꽉찬 영화. 어르신분들이 정말 많던 영화. 수 많은 장면중... 저는 포스터와 같이. 배위에서 선우스님을 진심어리게 위로 해주던 장면이 너무 좋았습니다. 스님들의 또 다른 모습을 보았습니다. : 긍정
# --------------------
# 607. 왜 마지막 장면에 눈물이 나지.. : 긍정
# --------------------
# 608. 시원 통쾌한 복수극. . . : 긍정
# --------------------
# 609. ㅈㄴ 재미없어요. 감독 때려쳐라 : 부정
# --------------------
# 610. 진부?? 하지만 마음속에는 사랑과 유쾌함이 남았어요.. 강추 입니다. : 긍정
# --------------------
# 611. 다시보고싶은 그리운영화 : 긍정
# --------------------
# 612. 감동적이고 재미있었음^^ㅋ : 긍정
# --------------------
# 613. 생각보다 너무 실망했던 영화..언터쳐블의 감동만 생각했던듯 : 부정
# --------------------
# 614. 연기가 완전 어색해 재미없어 베컴나와서 1점주는거야 고맙게여겨 : 부정
# --------------------
# 615. 슈퍼스타허각! 보면서 유일하게 온몸에 소름이 돋고 닭살 돋았던건 허각씨뿐이었어요 : 긍정
# --------------------
# 616. 답이 없는 문제를 내놓고는 관객들 헛고생시키는 영화. 염정아 연기가 그나마 살렸다. : 부정
# --------------------
# 617. 최고의 바이올린 영화죠. 소장하고 싶어서 찾았었는데... 다시 보고 싶네요. : 긍정
# --------------------
# 618. 반전스릴러영화의 교과서라 보면됨. 하지만 그 이상, 그 이하도 없었음 걍 요즘사람이 보기엔 지루한 고전영화. 공포영화의 역사가 궁금하다해서 궂이 본다면 예상했던 그대로를 보게될거임 : 부정
# --------------------
# 619. 1점은 스파키의 귀여움에 ㅋ 오랜만에 짜증나는 영화 : 부정
# --------------------
# 620. 같은 값이면 머리들도 좀 써라. 예산 타령만 하지 말고. : 부정
# --------------------
# 621. "신의 존재와 필연적인 죽음에 관한 질문, 종교의 구원과 사후세계에 대해 진지하게 묻고 있는 영화다. 영화도 충분히 철학적인 도구가 될 수 있음을 증명하는 불후의 ""걸작""" : 긍정
# --------------------
# 622. 아 ㅠㅠ 시간 아까워 뭐 이런 거지같은영화가 다있는지. 뭘 전하고 싶은 건지.... : 부정
# --------------------
# 623. 이런 드라마 또 없나요.. 정말 사람사는 얘기에요. : 긍정
# --------------------
# 624. 마지막 장면이 평생 잊혀지지 않을 것 같아...눈물이... : 긍정
# --------------------
# 625. 내가 본 최고의 만화! : 긍정
# --------------------
# 626. 예전엔 재밌게 봤는데;;내용을 다 알고있어서..좀; : 부정
# --------------------
# 627. 동방불패2와 같은 졸작. 수박 겉 핥기식 trash 영화. : 부정
# --------------------
# 628. 누구나 한 번쯤 들어봤을 ‘그레이스 켈리’에 대한 이 영화는 왕비/여배우로서 주인공이 느끼는 갈등과 모나코와 프랑스 간의 문제 사이에서 중심을 잡지 못 한 채 난잡하게 진행된다. : 부정
# --------------------
# 629. 개쩐다는 말밖에 나오지 않는다. : 부정
# --------------------
# 630. 감동깊게 본영화... : 긍정
# --------------------
# 631. 간만에 영화보면서 원없이 졸았다. 스릴러 좋아하네.. : 긍정
# --------------------
# 632. 감동이 있는 영화....굿 : 긍정
# --------------------
# 633. 주인공이 하나하나 알아 가는 장면들.... 주인공의 시점,관점 이며 하나씩 달라질때 마다, 왠지 대단한 장면들이 아닌데도.. 나는 정말 기분좋은 소름을 느낄 수 있었다. 소설은...이렇게 써야하는거구나...ㅎㅎ 정말 명작이다... : 긍정
# --------------------
# 634. 이거.. 후속작도 나오나요 ? 왠지 또 나올꺼 같은 느낌이 : 긍정
# --------------------
# 635. 토해 : 긍정
# --------------------
# 636. 진짜 명품드라마다.... : 긍정
# --------------------
# 637. 마지막 어째서 소지섭이 그렇게 갔을까... 하는 생각에 계속 생각해봤는데, 결국은 배우로써 재미는 다봤고, 이제 조폭으로서의 인생을 마감하고픈 생각에 그랬을거라 생각된다. 자기 자신의 끝은 그런 모습으로 가는게 나을것 같다는 생각에서...? : 긍정
# --------------------
# 638. 오래전 영화지만 참으로 매력있는 컨셉의 영화~~ : 긍정
# --------------------
# 639. 7년전 주말의영화에서 본영화. 최고였는데.. 이젠 어디서보지 ㅜㅜ : 긍정
# --------------------
# 640. 평점이 8점대라니. : 긍정
# --------------------
# 641. 왠지 수상한... : 긍정
# --------------------
# 642. 2편을봐봐라 1편에 10점만점을 줘도모자라다 : 긍정
# --------------------
# 643. 힘도 없으면서 편이나 가르는 못난짓은 21세기도 별 다름이 없는듯 : 부정
# --------------------
# 644. 너무 도식적이었던 한계는 어쩔 수 없을 뿐더러 이현우... 영화에 몰입할 수 없었음. : 부정
# --------------------
# 645. 간만에 본 한국영화 중 수작중의 수작 : 긍정
# --------------------
# 646. 견자단을 데리고 이것밖에 못만드냐 진짜..게다가 머리스타일 어쩔껴 정말 : 부정
# --------------------
# 647. '열왕기하2 20~' 읽어보시오 : 부정
# --------------------
# 648. 감동~~~ㅠ : 긍정
# --------------------
# 649. 막줄래들은 군바리들을 어떻게 괴롭히는가 : 부정
# --------------------
# 650. 니들이 이제는 아주 막가는구나 : 부정
# --------------------
# 651. """내 인생의 영화 ""라고까지 해줄수 있다.무인도에 가져갈 단 한편의 영화" : 긍정
# --------------------
# 652. 지나치게 비현실적이라 괴리감 큼... 결정적 한방은 대체 언제???? 하다 끝남 : 부정
# --------------------
# 653. 선정적이거나 자극적인 내용이 아닌 가슴 따뜻하고 정감가는 드라마여서 좋았어요~ : 긍정
# --------------------
# 654. 1편 수준을 기대하고 봤는데, 스토리도 난잡하고 재미가 없는게 결정적.. 다음편은 안볼듯 : 부정
# --------------------
# 655. 빨리 돌려서 액션만 보면 됨... 스케일만 크고 아무것도 없음... : 부정
# --------------------
# 656. 숨겨진 명화!! : 긍정
# --------------------
# 657. 7~8점인데 10점 줌 재밌게봄 : 긍정
# --------------------
# 658. 이거 어렸을때 보고 오늘 사서 엄마하고 봤습니다.역시 명화더군요 : 긍정
# --------------------
# 659. 외쳐! 갓 토르! 그냥 노잼이어도 10점준다 : 부정
# --------------------
# 660. 어거지로 빠뜨려서 마무리 짓는 한심한 역량의 작품 : 부정
# --------------------
# 661. 보는내내 뭐지 했다.... : 부정
# --------------------
# 662. tv다큐멘터리인줄알았더니영화네요 정말잘봤습니다눈물이 멈추지않았음 ㅠㅠ : 긍정
# --------------------
# 663. 어른이 보기에는 좀 잔잔한...그런데 우리 아들은 재미있었다며 집에 돌아와서 양인형 까맣게 칠해서 블랭키 만들자고하네요.ㅎㅎ 역시 아이들의 상상력은 어른과는 차이가 있구나하고 느낌니다. : 긍정
# --------------------
# 664. 어떤 오락영화던 그 이상의 것을 보여줬다. 그것도 85년도에 : 긍정
# --------------------
# 665. 소장했었는데 비디오테잎 누가빌려갔는데 행불. 보고싶다 ㅡㅡ : 부정
# --------------------
# 666. 감동 ㅠㅠ.... : 긍정
# --------------------
# 667. 그저 그래 : 부정
# --------------------
# 668. 재밌었어요~ 마음이 훈훈해지는 영화~ㅎ : 긍정
# --------------------
# 669. 뭐랄까, 결국은 가족이랄까?감동적이다,안타깝기도하고 아릿한 느낌이다. : 긍정
# --------------------
# 670. 이 정도로,물고 빨아주니까,교만하고,나태해져서,런던 올림픽에서,죽쒀버린 대한민국대표팀.미달이처럼 팬들의,관심과사랑이 부담스러워졌나?그렇다면,김연아는,어째서 팬들의관심과사랑을 즐길줄 아느냐는 거지.뭐가 그렇게 부담스러우셨는지요?누님들?결국 정신력의 문제 : 부정
# --------------------
# 671. 평점이 낮아서 왠만하면 올려줄려고 했지만 이건 아니다. ㅡ,.ㅡ;; : 부정
# --------------------
# 672. 보는내내 어떻게 찍었을까? 이 생각만.. ㅋ : 긍정
# --------------------
# 673. 제가 본 최고의 액션영화 다섯손가락에 들어가요~ 액션영화하면 이 영화가 제일먼저 생각나는듯최고의영화!! : 긍정
# --------------------
# 674. 획기적인 영화. : 긍정
# --------------------
# 675. 호화캐스팅.지루한전개 한마디루 별루였음 : 부정
# --------------------
# 676. 홍보만 잘됬어도 1997인기는 능가했을껀데... : 부정
# --------------------
# 677. 너무 감동있게 잘 봣습니다 : 긍정
# --------------------
# 678. 모가 재밌다는건지 ;;걍 그럭저럭; : 부정
# --------------------
# 679. 점수가 너무 높다.. ,, : 부정
# --------------------
# 680. 최악 : 부정
# --------------------
# 681. 아 정말 소름끼치는데??? : 긍정
# --------------------
# 682. 청춘 시트콤의 표본이자 스타 등용문의 서막 : 긍정
# --------------------
# 683. ㅠㅠ 로빈 윌리엄스.. 역시 명품배우네요 : 긍정
# --------------------
# 684. 조질나게 재미없고 유치 찬란하네 뭔지 모르고 보다가 짜증나서 채널 돌렸네 : 부정
# --------------------
# 685. 한숨만....으휴... : 부정
# --------------------
# 686. 누군가에게는 잔인한느낌으로 다가올만큼 좋았다 오늘방송 : 긍정
# --------------------
# 687. 소피마르소가 아니었다면 평점 2점짜리 영화 : 부정
# --------------------
# 688. 빈약한 스토리 빈약한 각본 빈약한 연출 빈약한 그래픽 보고나면 정신도 빈약... : 부정
# --------------------
# 689. 징편인데 단편스럽다. 생명 가지고 장난. : 부정
# --------------------
# 690. 최고다배트맨 비긴즈랑 바교는 아니지배트맨에는 내가알기론 그렇게 큰 cg는 없는걸로 알고있는데이거는 케릭터 하나하나 다cg쨋든 베트맨도 잼슴 : 긍정
# --------------------
# 691. 성우가어린이라는게아쉼다리얼리티를살리기위해서라도이건아님 : 부정
# --------------------
# 692. 시간만 아깝고, 지루함의 극치 절대보지마세요 일점도 아깝다. : 부정
# --------------------
# 693. 정말 소름끼치는 영화다 강추! : 긍정
# --------------------
# 694. 제이크 질렌할에 몰입되서 봄 : 긍정
# --------------------
# 695. 아이엠도 그랬듯이 내가좋아하는 가수보러가는것.하지만 케이팝의 대단함덕에 소름이 정말 쫙쫙 돋는다. 감동적이면서도 다큐멘터리 식이고 상영관에 사람도 별로없어서 보기좋다. SM이 이런걸로도 돈버는건 이젠 뭐라할기운도 없다.그저 난 좋으니까 에셈한테봉사 : 긍정
# --------------------
# 696. 1점으헤헤시내ㅓ헤세헤 : 부정
# --------------------
# 697. 산티아고~♥♥오랜만에다시봤지만 짜릿한영화 : 긍정
# --------------------
# 698. 가슴 따뜻해지는 영화. : 긍정
# --------------------
# 699. 주인공도 매력적이지 않고, 스토리도 어디서 많이 본듯하다 : 부정
# --------------------
# 700. 약간의 비약이 있지만 정말 좋은 영화입니다. -_-b : 긍정
# --------------------
# 701. 잊혀질만 하면 떠오르는 영화. 분명 이 영화가 날 홀린 게 분명하다. 볼 때마다 한동안은 그 여운이 가시질 않는다... : 긍정
# --------------------
# 702. 이거 정글의 법칙처럼 탐험 다니던 거라 내가 보고 있었는데 이제 무슨 먹방을 찍냐?? 집밥 먹으러 돌아다니네;재미없다 : 부정
# --------------------
# 703. 오래되어 낡은 공포 기법에 조악한 새 룰을 적용해봤자. : 부정
# --------------------
# 704. 짐캐리만의 영화 : 부정
# --------------------
# 705. 이게 아바타보다 아래라니 말도안된다. 나도 당시 광고봤을땐 아류작인줄 알았더니만 지금와서보니 마케팅업체가 엉망인 듯 싶다. 비슷한영화 아바타는 전개가 억지스러운면이 있으나 이 영화는 짜임새까지도 치밀하다. 적극추천 : 긍정
# --------------------
# 706. 뻔한 악당에 뻔한 결과. 대체 왜 아버지 친구들은 항상 배신자인거지???슈레더는 그냥 인간인데 이상하게 쎌뿐이고. : 부정
# --------------------
# 707. 당시 세대의 좋은 향수를 일으킬수 있는 추억으로만 남기세요 기념이라니.. : 긍정
# --------------------
# 708. 내용이 너무진부해서 참고보기힘들었다.. 그냥 CF감독이 만든영화같다. 한마디로 아무내용이 없다는뜻.. : 부정
# --------------------
# 709. 1점도아깝다. 네이버 평점사기 1위로 꼽고싶은영화. 3류순정만화보다 더허접한 영화 : 부정
# --------------------
# 710. 재미있는영화 소소한감동 있는영화 : 긍정
# --------------------
# 711. 김정훈 연기 진짜하 새기..ㅋ : 긍정
# --------------------
# 712. 완전 쓰레기 영화입니다. ^^ 스릴러는 말뿐. 초절정 저예산 허접시나리오 영화. 정말 시간아깝네.. : 부정
# --------------------
# 713. how boring! : 부정
# --------------------
# 714. 한정된 공간때문에 비행기를 선택했는데 1시간동안 뭘한건지.위급함.긴장감은 개뿔,신사다운 머피..후반은 나홀로집에를 연상시키는 결투씬.머저리같이 약한 머피.제이슨 본같은 레이첼 ㅋㅋ정말 후반부 개웃김 : 부정
# --------------------
# 715. 진짜 영화별로안좋아하는데 티비볼꺼없어서 채널돌리다가 우연히보게댐 근데 진짜 재밌게봤다 개쩌는영화 : 긍정
# --------------------
# ...
# 771. 너무 좋았습니다! 코믹한것도있었고 생각해보게되는것도 있었고.. 편위점 알바를해본적이있어서 공감가는것도 있었습니다 : 긍정
# --------------------
# 772. ㅡㅡ 나 이영화 1보고나서 2봣는데 쓰례기네.. 먼갑자기예언이쳐나옴? 먼 재난영화냐ㅡㅡ? 아욕나와진짜 리뷰처음써본다 : 부정
# --------------------
# 773. 웃기고 재밌고 감동 ㅜㅜ 그와중에 송승헌 너무 잘생기고 엄정화 너무 예쁨...☆ : 긍정
# --------------------
# 774. ㅋㅋ 머이러냐 우주선안에서중력이해제된상태에서 빨간불이 난다는것은 큰실수다 : 부정
# --------------------
# 775. 감독의 진지한 연출력이 배우들의 열연으로 플러스되나싶더니 결말에서 자폭...김민준의 카리스마는멋있지만 허세의 기운도ㅋ 조연들연기가 깨알같아서별점상승요ㅎㅎ 아, 물론 영화는 안봤어요^^ : 부정
# --------------------
# 776. OO 이런것도 영화라고.. : 부정
# --------------------
# 777. 블랙코미디 존나 꿀잼ㅋㅋㅋ배우들 완전 초호화 캐스팅임ㅋㅋㅋ : 긍정
# --------------------
# 778. 정말 어지간히 좀 하기를 ... 자중나서 점점 보기 시러진다 .. 다른 방송사 드라마보다 정말 스토리 전개가 뻔하다 .... 무슨 미리예상한데로 보는 드라마인지 ... : 부정
# --------------------
# 779. 딸연기가 오버연기니 어쩌니 하시는분들은 뭐지? 난 진짜 현실감있게 정말 리얼하게 연기 잘했다고 생각하는데? 당신들은 저상황에 놓이면 저러지 않을꺼라 생각하나? 더했으면 더했지 덜하진 않을듯 : 긍정
# --------------------
# 780. 별점 반개도 아깝네요. 내용도 없고 약간 중간에서 갈팡질팡해야하는 그런 스릴이 있어야하는데 저스틴 연기가 아직 부족한듯. 각본, 연기, 연출력 다 망한 영화. : 부정
# --------------------
# 781. 톰크루즈와 잭 니콜슨의 명연기.. 잭니콜슨의 말 '내가 범죄자라는거야 ? 나와 내 부하들이 지켜주는 덕분에 너희들이 편한거야.' : 긍정
# --------------------
# 782. 정말 의미있는 영화. 좋은 주제를 잘 찍었다. : 긍정
# --------------------
# 783. 대단하다 이런 영화가 10점이라니... : 긍정
# --------------------
# 784. 이런게 영화죠.. 최고의 영화입니다 : 긍정
# --------------------
# 785. 총알탄사나이의 재미를 느끼긴 힘들다. : 부정
# --------------------
# 786. 완전 내 스타일... 아 샤를리즈 테론 아직도 여신급으로 아름답고 스토리도 아주 꿀잼입니다. 왜이리 평가가 낮죠 ㅎㅎㅎㅎ : 긍정
# --------------------
# 787. 난 재미없었음 걍 여주가 이뻐서.. : 부정
# --------------------
# 788. 다 걍 넘어가주는데... 남자주인공... 그 어리버리.. 미그적거리는거... 왜 화나지.. : 부정
# --------------------
# 789. 하나도 아까운데 홍진호때문에 준다 : 부정
# --------------------
# 790. 영화가 왜이렇게 잡음이 심한건지... 내용에 비해 너무 부실한듯합니다. : 부정
# --------------------
# 791. 불륜은 싫지만 이 영화는 도대체 싫어할수가 없다. : 긍정
# --------------------
# 792. 좋았다.(열자..) : 긍정
# --------------------
# 793. 지나간 여자랑 버스는 잡는게 아니란다 : 부정
# --------------------
# 794. 반전을 만들어 관객을 놀래키려고 많이 노력했다. 하지만 다 리얼리티가 떨어진다 : 부정
# --------------------
# 795. 우리나라 적국의 이야기가 아니라 전쟁의 고통을.알려준 영화라고 생각된다. 중국군 이야기가 아니라 그냥 군인의 이야기라고 생각된다. : 긍정
# --------------------
# 796. 이것이 사과여 사과자나ㅋㅋㅋ : 부정
# --------------------
# 797. 개연성 없는 결말이다 . : 부정
# --------------------
# 798. 역시 아따마마가 진ㄹ;ㅣㅎㅎ : 긍정
# --------------------
# 799. 스토리는 평이하지만 세자동차 이동씬은 화려했다 : 긍정
# --------------------
# 800. 마이너스 별점은 왜 없나요? : 긍정
# --------------------
# 801. 너무 슬퍼서 쌀밥을 찾았습니다. : 긍정
# --------------------
# 802. 짱임 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ웃기면서도 감동적인^^ : 긍정
# --------------------
# 803. 감독이 말하고자 하는 것이 무엇인지 알 수 없는영화. 귀신이 등장하는 설정이 산만함. : 부정
# --------------------
# 804. 별점을 줘야하는 내가 창피해 : 부정
# --------------------
# 805. 캐릭터를 처음부터 잘못잡았다.. 원작만 따라갔어도 이지경은 아닐것을 : 부정
# --------------------
# 806. 정말 불편하고 안좋은면을 다룬다. 그래서 불편하다 : 부정
# --------------------
# 807. 좋아요.. 마무리가 조금 아쉬워요. 기분이 좋아지는 영화.. : 긍정
# --------------------
# 808. ㅅㅂ 내돈 : 부정
# --------------------
# 809. 투니버스에서 보는것만으로도 만족한다 ㅡㅡ : 긍정
# --------------------
# 810. 액션 영화가 지루하다면 얘기는 끝난 것 아닌가. 도입부만 흥미로웠다. : 부정
# --------------------
# 811. 제목때문에 삼류 에로 영화 타이틀 같지만 내용은 알찬 스릴러 물 그리고 요즘 덱스터에 나오는 데스몬드의 리즈시절 모습을 볼수 있기에 : 긍정
# --------------------
# 812. 이건 아니잖아 그토록 딸을 찾기위해 모든것을 버린...미아찾기운동까지해가며 열성인 엄마는 딸도 못보고 죽게 만들고...엄마 죽고나서 급 몰입도떨어지고...범인은 여기저기 나 여기있소 단서남겨도 못잡고...현실성이 너무 떨어지고... : 부정
# --------------------
# 813. 이런 애니는 처음..그리고 반가운 오인용 식구들 목소리~ : 부정
# --------------------
# 814. 안보는게 약인 영화다 이런 영화 보면서 뭔가를 알고싶지도 느끼고 싶지도 않다 하지만 느꼈다 속이 울렁거리는 영화다 내가 본 느낌을 표현 한다면 길가다 많은양에 구토물을 본 느낌인데 구토한 사람이 뭘 먹었는지 궁금하지는 않다 : 긍정
# --------------------
# 815. good~~ : 긍정
# --------------------
# 816. 평점이 너무 낮아 놀랍네요; 개봉당시 영화관에서 2번 보고, DVD까지 소장한 작품인데.. 이 영화로 김지운 감독 주목받아 헐리우드 진출까지 한 대작입니다. 한국에서 이런 영화가 나왔다는게 감사한 작품! : 긍정
# --------------------
# 817. 1잠도 아깝네요 제대로된게 하나도없었어요 기대도 안했는게 이정도면뭐... 대체피시 셍긱이잇는건지 한심.. 김대희 분량이없다며병풍이라 하시는분들 계신데 전 김대희 주먹쥐며 몇번째손가락올릴지모른다 욕할꺼다 막말한모습이 너무 싫엇어요.. : 부정
# --------------------
# 818. 전작보고 기대했는데.....실망가득한영화다.. : 부정
# --------------------
# 819. 어린애들이 나오는 공포물은 거의다 재미가없다 ~~~~~~~ : 부정
# --------------------
# 820. 명작입니다 꼭 보세요 공백10자 : 긍정
# --------------------
# 821. 정말 이것도영화라고 만든색히 지도 영화감독이라고 어디가서 떠들고 다니겠지..평점 최소가1이라서 1점은주는데 이건 정말쓰레기로도 못쓴다.에이 퉤퉤!! : 부정
# --------------------
# 822. 이딴게 영화 라니 ^ㅗ^ : 부정
# --------------------
# 823. 이영화는 6점대가 적정하다고 생각합니다.연기도 좋고 스토리도 좋은데 몰입감이 떨어지네요.뭔가 억지스럽게 끌어가는 느낌입니다. : 부정
# --------------------
# 824. 평점보고봤다간정말큰코다침!!최고지루함!헉!! : 부정
# --------------------
# 825. 어쩌다 생각이 나서 처음으로 네이버 영화 평을 올리는데, 정말 어린 배우들 유명세에 기대어 흥행은 했는지 몰라도 나중에 이 친구들이 연기에 대해 눈을 조금이라도 뜨게 되었을 때 자신의 흑역사로 기억할 영화가 아닐까 싶다. : 긍정
# --------------------
# 826. 잼있음 : 긍정
# --------------------
# 827. 이게 영화냐? 야동이지 : 부정
# --------------------
# 828. 영화가 끝난후 텅비어버린 가슴..진실이 왜곡되는 정치적 이념의 송가.. : 부정
# --------------------
# 829. 이런 영화는... 그냥 10점임... ㅜㅜ... 저 위 포스터는 도대체 누가 만든거냐??? 파스텔톤의 사랑 영화 아님... ㅜㅜ : 부정
# --------------------
# 830. 이런 영화를 만드는 이유를 모르겠다. : 부정
# --------------------
# 831. 그래서 결론은 뭐지 ??? : 부정
# --------------------
# 832. 누구나겪을수있는삶에대한많은이슈들을일상적이면서유머러스하게전개하여편안한감동을만들어주는영화같아기분이좋아진다... : 긍정
# --------------------
# 833. 행복을 아메바같이 단순화시킴. 또한 여행도 작위적~ : 부정
# --------------------
# 834. 최고의 연기력과 기획 이영애 최고~! : 긍정
# --------------------
# 835. 내용이없어 : 부정
# --------------------
# 836. 자토이치 짝퉁이군...어이가 없어 : 부정
# --------------------
# 837. 쓰레ㅐ기영화 전작에 제대로먹칠 : 부정
# --------------------
# 838. 호주에서 살고싶게끔만드는 영화 : 긍정
# --------------------
# 839. 다보고 느낀점수 : 긍정
# --------------------
# 840. 비디오로 보지말고 그냥 오씨엔으로 보는게 나을듯 : 부정
# --------------------
# 841. 지금 보니 웃음만... 격세지감... : 부정
# --------------------
# 842. 심심할때 볼만.. : 긍정
# --------------------
# 843. 80년대 우리나라는 영화도 후진국이었군요 어떻게 저런 연기를... 동시대에 나온 영화가 ET 였던걸로. : 부정
# --------------------
# 844. 평점조작단아 장난치지 말아라. : 부정
# --------------------
# 845. 첨 볼 땐 다슬이 참 사랑스럽다...두번째 볼땐 다슬이 가족들 참 좋은 분들이다...세번째 볼땐 내 가족들도 있는 그대로의 모습을 봐줘야겠다는 생각이 들었다. 다슬이가 계속 보고싶어.. : 긍정
# --------------------
# 846. 시작은 좋으나 끝은 흐리멍텅.반전에만 집착하는 샤말란 : 부정
# --------------------
# 847. 숨막히는 사랑.. 정말 너무 슬퍼서 아름답다 : 긍정
# --------------------
# 848. 왜...박하선이 복수를 하는지 이해가 안되네요^^오히려 권상우가 더 피해자같은데~그만큼 남편한테 믿음이 없었나하는 생각도 드네요 : 부정
# --------------------
# 849. 이러지도 저러지도 않는 오락가락 스릴러 : 긍정
# --------------------
# 850. 후세에 걸작의 재조명을 시키다. : 긍정
# --------------------
# 851. 난 보는내내 그냥에로영화인줄알았는데 이게네이버에올라와있네. : 긍정
# --------------------
# 852. 감정의 골이 패여 생긴 마음속 주름이던, 세월의 흔적이 보여지는 얼굴위 주름이던 과하게 인위적으로 펴면 부자연스러움을 피할 수 없다. : 부정
# --------------------
# 853. 기대감이너무컸다.1탄의명성을먹칠한영화! : 긍정
# --------------------
# 854. 최고 : 긍정
# --------------------
# 855. 아....... : 긍정
# --------------------
# 856. 내가 왜 이걸 10년도 더 지나서 보게 된 걸까...ㅋㅋㅋ 그 땐 초등학교 1학년었지 참 : 긍정
# --------------------
# 857. 진짜 추억 돋는다 : 긍정
# --------------------
# 858. bad : 부정
# --------------------
# 859. 영국영화도 상당히 독특하군요. 스토리야 있지만 영화로서의 재미는... 장편 독립영화도 아니고. : 긍정
# --------------------
# 860. 쓰레기네여 : 부정
# --------------------
# 861. 정의를 위해...일단 봐라 ........신선한 충격이다 ...이런 영화 평생 보기 힘들다 : 긍정
# --------------------
# 862. 정말 제인생최고의영화 : 긍정
# --------------------
# 863. 나 저거 다운 잘못받은줄ㅋ20세기 전반대 영화인줄 : 부정
# --------------------
# 864. 평 남긴 것들 본 영화가 하나같이 똑같냐 ㅋㅋㅋ 알바도 좀 티 안나게 하자... : 부정
# --------------------
# 865. 산뜻한 그들만의 반란....우리에게는 빵도 필요하지만 장미도 원한다 : 긍정
# --------------------
# 866. 무슨말이 더 필요한가? 믿고보는 일본 애니아닌가!! : 긍정
# --------------------
# 867. 이 OOO 영화를 내가 검색한 이유는 감독이 또 만든 '맨데이트' 때문 : 부정
# --------------------
# 868. 야구란 이런거다 하는것... : 부정
# --------------------
# 869. 무엇보다 쇼킹한건 이영화의 네이버평점... 아버지의 원수이지만 아버지와 같은 마음을 품게되는 영화 전반부의 암스테르담의 고뇌는 참으로 훌륭한 심리전개... 영화전체적으로도 지루하지 않은 영화전개와 스케일.. 고루 만족스러운 영화 : 긍정
# --------------------
# 870. 홍번구에 비해 액션이 약했지만.. 성룡은 역시 우리를 즐겁게 해준다 : 긍정
# --------------------
# 871. 정말재밌다 10자.. : 긍정
# --------------------
# 872. 서정적인 세계에 빠져들고 싶다면 : 긍정
# --------------------
# 873. 고스터버스터즈 느낌의 수작이다. : 긍정
# --------------------
# 874. ㅇㅇ...좋음 : 긍정
# --------------------
# 875. 죽음을 통한 소녀의 성장을 다룬 블랙 코미디. : 긍정
# --------------------
# 876. 진심개거지......울나라에서개봉왜한거임? : 부정
# --------------------
# 877. 영화 이보다 더 잘 만들 수 있지 않았을까? 유덜보다 캐롤 성격이 더 이상해보인다. 참신할 것도 없는 흔해빠진 로맨스물에 왠 평점을 이리 높이들 주는지... : 부정
# --------------------
# 878. 감독의 연출이 부재니 좋은 소재를 말아버린다 : 부정
# --------------------
# 879. I told you.. chickens are organized! : 긍정
# --------------------
# 880. 상 받았다니까 왠지 좋았다고 해야할 것 같은 압박감에서 벗어나세요. 아무것도 없다 : 부정
# --------------------
# 881. 별로 안무서운데; : 부정
# --------------------
# 882. good! : 긍정
# --------------------
# 883. '영구 vs 맹구'나 '람보 vs 코만도'를 만드는 게 더 낫겠다 : 부정
# --------------------
# 884. 어설픈 스릴러, 어설픈 코메디, 어설픈 데미 무어 : 부정
# --------------------
# 885. 어린이채널용 드라마 같은 것이 응응씬을 너무 남발한다. : 부정
# --------------------
# 886. I'll win cuz I have faith, courage, and enthsiasm! : 긍정
# --------------------
# 887. 평이한 로맨틱 코메디. 행크스 많이 늙었네 : 긍정
# --------------------
# 888. 꺼이 꺼이 울면서 봤던 영화. 정말 다시 한번 보고 싶다. 정말 진심으로 다시 한번... : 긍정
# --------------------
# 889. 닥터호의 아픔이 절실히 느껴지는 그런영화 입니다 : 긍정
# --------------------
# 890. """무법자의 천상천하유아독쫑"" 이란 제목이 더 잘어울리는 영화!" : 긍정
# --------------------
# 891. 이 괴상한 심심한 영화는 갑자기 뭐지....기대이하자나?...뭐하나 제대로하는게 없는 영화....베네치아의 풍경만 볼만함.. : 부정
# --------------------
# 892. 지금까지 본 한국공포영화중에서 내용이 꽤 신선하고 재미있었던 영화입니다.참고로 내용 이해하기 싫어하고 무조건 피터지고 때려잡는 좀비영화같은거 좋아하는 사람들은 별로 안좋아할듯. 스토리 위주의 영화를 보시는 분들은 재미있을것 같아요 : 긍정
# --------------------
# 893. 뭐가 이렇게 허접하다냐 : 부정
# --------------------
# 894. 장정일님의 원작..... 에로티시즘만 가득;;; : 부정
# --------------------
# 895. 만화다보니 유치하긴했지만 한동안 참 재미있게 봤던 드라마이기에.. : 긍정
# --------------------
# 896. 궁극의 러브 스토리! 내 생애 최고의 드라마. 다모폐인들은 영원히 잊지 않을것입니다 : 긍정
# --------------------
# 897. 쓸데없는대사...개연성없는 시퀀스...콘티를촬영하면서 짰나 : 부정
# --------------------
# 898. 평점1점짜리 개알바들은 좀 가라!~ : 부정
# --------------------
# 899. 음악 쌤이 보여줬는데 진짜 짱인 영화 : 긍정
# --------------------
# 900. 오랜만에 감동적인 영화이자 부모의 이기심이 섞인 잘못된 사랑에 대해 다시 생각해볼수있었다. 그리고 꼭 자신이 낳은 아이가 아니더라도 아이가 원하는 부모의 사랑을 줄수있다는게...정말 감동적이다.. : 긍정
# --------------------
# 901. 쓰레기영화였다는거.. : 부정
# --------------------
# 902. 백인우월주의 떄문에 중간에 보다가 껏다. 미국은 꼭이런 성향이 있더라,,... : 부정
# --------------------
# 903. 정말 재미있어요 학교에서 봤는데 가족 모두 보여주고 싶네요 : 긍정
# --------------------
# 904. 영화 보다가 중간에 꺼버린 건 처음. 온갖 흥행요소 짜깁기해서 난잡하고 내용없음. : 부정
# --------------------
# 905. 4점짜리 영화 : 부정
# --------------------
# 906. 이런 영화가 있다는 사실이 감사해요. : 긍정
# --------------------
# 907. 재밋엇어요오오오오몽·으 : 긍정
# --------------------
# 908. 그래딱4점이다 : 부정
# --------------------
# 909. ^*^ 기대만발....ㅎ.ㅎㅎ : 긍정
# --------------------
# 910. 쇼미더 머니 ㅡㅡ왜하는건가요 힙합보여줄라고 하는거 아닌가요?롹하고 ㅡㅡ 롹이 힙합은 아니자나요 ㅡㅡ아.. 점점더 산으로 가는 쇼미더 머니 ㅡㅡ : 부정
# --------------------
# 911. 좋네요....저 밑에 우리나라 사형제도 폐지 됐다고 하는데폐지된거 아닙니다.... 다만, 형의 집행을 계속 시행하지 않고 있을뿐... : 긍정
# --------------------
# 912. 너무 좋아 우마소♡사랑스러워 : 긍정
# --------------------
# 913. 아진짜 문채원 이런 연기까지도 맘에드네요 이런영화 한편더찍었으면... 뭉클한영화였다 : 긍정
# --------------------
# 914. 넘 재밌다.ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ : 긍정
# --------------------
# 915. 화려한 휴가에서 웃겼다. ㅋㅋㅋ : 긍정
# --------------------
# 916. 독일 왕실 보석을 둘러싼 소소한 두뇌싸움 : 부정
# --------------------
# 917. 동화같은 내용이다. 트리스탄도 멋있었지만 난 개인적으로 셰익스피어 선장이 굉장히 좋았음. : 긍정
# --------------------
# 918. 아니 왜 우리나라 얘기는 없는거지? : 부정
# --------------------
# 919. 진짜 내용 유치하네 작가 발로쓰나.. 연기자들 대본보고 손발 오그라들겠다.. 초반스토리에서 가면갈수록 진부해지네 : 부정
# --------------------
# 920. 최오~~이렇게 잼나는 애니는 첨이예요 : 긍정
# --------------------
# 921. 47년 원작에 비해 캐릭터도, 이야기도, 따뜻한 가슴도 모두 부족하다. : 부정
# --------------------
# 922. 꿀잼진짜 개잼 꿀잼 핵잼 : 긍정
# --------------------
# 923. 바보연기를 정말 리얼하게 해낸 홍금보에게 박수를...^^ : 긍정
# --------------------
# 924. 송지효 짱ㅋ : 긍정
# --------------------
# 925. 예전이나 지금이나 별로인영화 신선한건 좋은데음향이 엉망 볼륨조절에 실패 송학림이 얘기할땐 볼륨 최대로 맞춰야하고 변희봉이나 장량이 말할땐 볼륨 50프로면 되고 사운드볼륨은 엄청크고 한국영화인데 한국말 자막이 필요한 실패작 : 부정
# --------------------
# 926. 흐하하 재밌다 제시카 알바는 왜이리 예뻐??? : 긍정
# --------------------
# 927. 소재만 신선하고..연출,연기,각본 모두 기대이하... 맥아리없는 영화 : 부정
# --------------------
# 928. 별달가치가업네 : 부정
# --------------------
# 929. 상상의 공간...하지만 별다른게 없다;; : 부정
# --------------------
# 930. 진짜 김신 아나운서하고 나미래하고 엮지말고 세주랑 나미래랑 엮이게 해주세요. : 긍정
# --------------------
# 931. 시간 아까웠다 : 부정
# --------------------
# 932. 에로틱환타지는무슨.난쟁이똥자루만한여배우하나나와서는.울마눌보다반의반도안섹시. : 부정
# --------------------
# 933. 꼭 한번 쯤 봐야 할 영화인 듯.. 현 우리 나라 상황과 보면서 오버랩 되네요. : 긍정
# --------------------
# 934. 부활 마니아가 이렇게나 많다니요~~^^ 하지만 그거에 비해 재방송은 거의 안하는 듯~34살 인생 전무후무 최고의 걸작~!! : 긍정
# --------------------
# 935. 진짜.. 손가락 안에 들 영화.. : 부정
# --------------------
# 936. 긴장감도 떨어지고, 반전의 힘도 약한 듯. : 부정
# --------------------
# 937. 잘만든 드라마 : 긍정
# --------------------
# 938. 약한 주제의식, 반전보다는 법정씬을 더 스릴있게 할 것이지 : 부정
# --------------------
# 939. ..Asdlflfpspspspspwowkwhwgfkcp : 부정
# --------------------
# 940. 과장된 연기와 장황한 서술에 점점 지쳐만가는 여정 : 부정
# --------------------
# 941. 작가분이 돌아가신 친구분 뜻이어서 작품 이어받아서 쓰고계신데 취지는 높게사는데요... 이작품을통해서 다시한번깨달은건요 남의작품은 받아쓰는게 아니라는거...대부분 다망쳐버림 아예 다른드라마가 되는거니깐. 끝으로갈수록 뭘말하려는지도 모르겠고 재미도없어짐 : 부정
# --------------------
# 942. 키티적이고 사소설적인 일본영화의 편견을 또다시 강하게 만들어준 영화. 다들 쉽게 긍정적으로 변하고 쉽게 희망을 찾는다. 희망을 강요받으니 괴롭기만하다. : 긍정
# --------------------
# 943. 결말에 다 침몰 했으면 10점 줄텐데. : 부정
# --------------------
# 944. 외계인 너무 바보같이 나온다 기술은 종나 좋은데 머리는 멍청이 : 부정
# --------------------
# 945. 그 어떤 영화보다도 쇼크였다.일생 동안, 두번 다시 보고 싶지 않은, 저주 받은 걸작. : 긍정
# --------------------
# 946. 최고에요 : 긍정
# --------------------
# 947. 보고싶어여.. 언제 개봉이죠?? : 긍정
# --------------------
# 948. 평점에 속았음..그냥 7점 정도의 애니... : 부정
# --------------------
# 949. 현실성있는영화. 나 자신을 알라! : 긍정
# --------------------
# 950. 나에게 동심따윈 없나보다 ㅜ : 부정
# --------------------
# 951. 그래도 이준기 실컷봐서 좋았음2 : 긍정
# --------------------
# 952. 이거시 박치기다! : 부정
# --------------------
# 953. 볼만한 코미디 영화 싼티나는 포스터와 제목때문에 안보게 됐었지만 : 긍정
# --------------------
# 954. 이렇게 명화가 평점 0점이라니 ㅠㅠ 제가 1점 올려주고 갑니다! : 부정
# --------------------
# 955. 영상미. 한여자의 성장. 크리스마스 : 긍정
# --------------------
# 956. 뭐야 이게 끝이야? 조금 지루하긴 하지만 곧 절정에서 재밌겠지.. 했는데 절정이 없잖아.... : 부정
# --------------------
# 957. 재미있어요 : 긍정
# --------------------
# 958. 영화니까~ㅋ. 나쁘지 않았어. : 긍정
# --------------------
# 959. 8.9나온게 신기하다~영화볼때잤냐?? 아무리수년이지났어도 이정도 도급영활 못만들어...그래서 믿고보는 베이감독이고~나쁜녀석들같은영환 알라나~줫만한 초딩들~ㅉㅉ : 부정
# --------------------
# 960. 예전에 우울하고 힘들때 새벽에 이 영화봤는데 정말 마음이 따듯해지고 완전 힐링되는 느낌이였어요 뜻밖의 장소에서 뜻밖의 인연.. 대리만족 제대로 했습니다 아주 재밌는 영화 ~ ㅋㅋ : 긍정
# --------------------
# 961. 찰리채플린이 생각나게 하는영화 ㅎㅎㅎ : 긍정
# --------------------
# 962. 이건 뭐 생략이 심한 영화인것 같다~!! : 부정
# --------------------
# 963. 재밋게봐는데... 자기주관대로 매겨야지 평점따라가는건 아닌지 에휴 ㅉㅉ : 긍정
# --------------------
# 964. 지금 TV.. 무슨내용인지 몰겠다만, 여자들 섹시하면서도 과격하게 싸우네. 그뿐 : 부정
# --------------------
# 965. 영화가 ost를 못따라간다 : 부정
# --------------------
# 966. 진짜 개졸작이다.. 뭐 이딴 영화가 있나.. 이야기도 허무맹랑하기만 할뿐.. : 부정
# --------------------
# 967. 음 안습 무플 : 부정
# --------------------
# 968. 무간도나 신세계나 각각의 장점이 있는거지 뭘 무간도에 비하면 쓰레기네 찌끄레기네 난리를 치냐? 그렇게보면 대부에 비하면 역시 이것도 찌꺼기에 불과해서 1점 주고간다. 이 영화의 최대단점은 삼합회보다 덜떨어진 빠들을 양산한다는 것. : 부정
# --------------------
# 969. ㅜ.ㅜ;;;;; 안습 : 부정
# --------------------
# 970. 다시 한번 되새김했지만, 여전히 좋다. 쿠보즈카의 눈빛 : 긍정
# --------------------
# 971. 솔직하게 씁니다, 호러공포 매니아로 안본게 거의 없는데요, 4점대가 맞는것 같습니다. 우선 너무 흔한 소재와 너무 흔한 귀신과 너무 흔한 구성으로 색다를게 전혀 없고, 귀신찍는 사람들이 귀신이 귓바람 한번 불었다고 패닉에 빠져 허둥대는꼴부터 망 : 부정
# --------------------
# 972. 이게 영화냐? 옛날에 비디오 영화랑 비슷하다. 연기 꽝..필름 아깝다...제대로 만들고 언플 좀 해라...짜증..눈버림... : 부정
# --------------------
# 973. 익숙함에 모든걸 잊고사는 사람들에게 보여줘야할영화다.. : 긍정
# --------------------
# 974. 더빙 배우를 잘못써서 괜찮았을 영화를 망친듯 : 부정
# --------------------
# 975. 극장에서 보세요..8-8 꼭! DVD이번에도 안나오겠죠..네..압니다..일판샀어요8-8..보실분들을 위해 스포일러는 자제합니다. 극장에서 꼭 보세요!! : 긍정
# --------------------
# 976. 우연히 보게된 영화, 부모님의 사랑이만든 기적을 보았습니다.누구든지 꼭꼭 보았으면 합니다! 짱짱 : 긍정
# --------------------
# 977. 정말재밌게봤었는데...... : 긍정
# --------------------
# 978. 두번째 에피소드만 약간부족함 : 긍정
# --------------------
# 979. 어릴적 추억이 담긴만화..어느새 어릴적 꿈을 실어준 추억이 되버렸네요 : 긍정
# --------------------
# 980. 영문모를 감독의 의도, 영 재미를 느낄 수 없는 나. : 부정
# --------------------
# 981. 웬만해선 1점은 안준다. : 부정
# --------------------
# 982. 교복찢고 했다는데..너무한다 고1인데..참..17살..하얀애를 : 부정
# --------------------
# 983. 1,2편에 비해서 위엄이 너무 떨어졌다. 1,2편은 간지좔좔이였는데.. 3편은 개그영화같음 : 부정
# --------------------
# 984. 비틀쥬스를 보는 느낌, 이런영화 좋아요. : 긍정
# --------------------
# 985. 마음이 따뜻해지는 영화네요ㅠ강추!! : 긍정
# --------------------
# 986. 1점도 아깝다. : 부정
# --------------------
# 987. 웃는게 웃는게 아니지만, 아니 웃을 수 없는 영화! 역시 킬리언 : 부정
# --------------------
# 988. 재미없다 별로 : 부정
# --------------------
# 989. 왠만한 재주로는 이 영화에 명함도 못 내민다 : 부정
# --------------------
# 990. 요근래 SF영화중에서 제일 잘 만든것 같다.. 그래픽도 화려하고 내용도 탄탄하다.... : 긍정
# --------------------
# 991. 정말 지루하고 쉽게 만든 영화 : 부정
# --------------------
# 992. 난 재밌던데 ㅋㅋ : 긍정
# --------------------
# 993. 객관적이고 관련 없는 사람이 감동받아야 잘만든건데 이건 도통.. 그들만의 잔치 : 부정
# --------------------
# 994. 베컴, 지단, 피구를 볼 수 있다는거에서 즐거웠다. 특히 두번째 이야기에서 나오는 여자축구선수 정말 너무너무 아름답더라..이 여성도 실제 축구선수였던걸로 기억하는데..ㅎㅎ 그나저나 평점은 바셀팬들이 깍고 간걸까? : 긍정
# --------------------
# 995. 장난 안까고 동네 양아치 고삐리 들한테 비디오 카메라 주고 영화 하나 찍어 오래도 이거보단 나을듯-- 이게 영화냐? 영화여?? ㅉㅉ : 부정
# --------------------
# 996. 긴박하다. 사람이 저래서 자살을 택하는 것이란걸 알았다. 그 무게를 견디고 스스로 목숨을 끊지 않은 주인공이 대단하단 생각 마저 든다. 나였으면 어땟을까라는 생각이 들었다. 그만큼 몰입될 수 있게 잘만든 20세기 마지막해의 영화다. : 긍정
# --------------------
# 997. 어색,유치. 소재는 좋았지만 결정적으로 재미가 없으니.. : 부정
# --------------------
# 998. 디젤, 개똥폼만잡고 디아블로란 존재도 멋지지도않고 : 부정
# --------------------
# 999. 밋밋하다고밖에 할말이 없다 : 부정
# --------------------
# 1000. 에로용으로도 못 쓰는 영화 : 부정
# --------------------
# Test Accuracy: 853 / 1000 = 0.8530

# %% [markdown]
# 학습 전 Accuracy : 0.699
#
#
# 학습 후 Accuracy : 0.853
#
#
# fine-tuning전에는 모델의 응답이 긍정과 부정을 분류하긴 하지만 문장형식으로 출력함.
#
# fine_tuning 후에는 학습 데이터와 같이 긍정 부정 두단어로 분류하여 응답함

# %% [markdown]
# ### 7.6. gemma chat
# - chatbot 형식의 감정분류 입니다.
# - '4.5. gemma chat' 섹션을 참고하세요.

# %%
def gen_prompt(pipe, doc):
    messages = [
        {
            "role": "user",
            "content": "다음 문장은 영화리뷰입니다. 긍정 또는 부정으로 분류해주세요:\n\n{}".format(doc)
        }
    ]
    prompt = pipe.tokenizer.apply_chat_template(messages,
                                                tokenize=False,
                                                add_generation_prompt=True)
    return prompt

# %%
def gen_response(pipe, doc):
    prompt = gen_prompt(pipe, doc)

    outputs = pipe(
        prompt,
        do_sample=True,
        temperature=0.2,
        top_k=50,
        top_p=0.95,
        add_special_tokens=True
    )
    return outputs[0]["generated_text"][len(prompt):]

# %%
while True:
    doc = input('문장 > ')
    doc = doc.strip()
    if len(doc) == 0:
        break
    result = gen_response(pipe, doc)
    print(f'감정 > {result}\n\n')
# Out:
# 문장 >
